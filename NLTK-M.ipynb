# %% [markdown]
# # NLTK

# %%
import nltk
import networkx as nx
import re
from nltk.tag import UnigramTagger
from nltk.tag import BigramTagger

# %%
with open('Data_Sample.txt', 'r', encoding="utf8") as myfile:
    data=myfile.read().replace('\n', '')

ps = PorterStemmer()

# %%
def ie_preprocess(document):
    sentences = nltk.sent_tokenize(document)
    sentences = [nltk.word_tokenize(sent) for sent in sentences]
    sentences = [nltk.pos_tag(sent) for sent in sentences]
    return sentences

# %%
sentences = ie_preprocess(data)
sentences
# Out:
# [[('\ufeffCHAPTER', 'RB'),
#   ('2', 'CD'),
#   ('The', 'DT'),
#   ('first', 'JJ'),
#   ('program', 'NN'),
#   (':', ':'),
#   ('Little', 'JJ'),
#   ('Crab', 'JJ'),
#   ('topics', 'NNS'),
#   (':', ':'),
#   ('writing', 'VBG'),
#   ('code', 'NN'),
#   (':', ':'),
#   ('movement', 'NN'),
#   (',', ','),
#   ('turning', 'VBG'),
#   (',', ','),
#   ('reacting', 'VBG'),
#   ('to', 'TO'),
#   ('the', 'DT'),
#   ('screen', 'NN'),
#   ('edges', 'VBZ'),
#   ('concepts', 'NNS'),
#   (':', ':'),
#   ('source', 'NN'),
#   ('code', 'NN'),
#   (',', ','),
#   ('method', 'NN'),
#   ('call', 'NN'),
#   (',', ','),
#   ('parameter', 'NN'),
#   (',', ','),
#   ('sequence', 'NN'),
#   (',', ','),
#   ('if-statement', 'JJ'),
#   ('Exercise', 'NN'),
#   ('2.1', 'CD'),
#   ('Start', 'NNP'),
#   ('Greenfoot', 'NNP'),
#   ('and', 'CC'),
#   ('open', 'VB'),
#   ('the', 'DT'),
#   ('little-crab', 'JJ'),
#   ('scenario', 'NN'),
#   ('.', '.')],
#  [('Place', 'NN'),
#   ('a', 'DT'),
#   ('crab', 'NN'),
#   ('into', 'IN'),
#   ('the', 'DT'),
#   ('world', 'NN'),
#   ('and', 'CC'),
#   ('run', 'VB'),
#   ('the', 'DT'),
#   ('program', 'NN'),
#   ('(', '('),
#   ('click', 'VB'),
#   ('the', 'DT'),
#   ('Run', 'NNP'),
#   ('button', 'NN'),
#   (')', ')'),
#   ('.', '.')],
#  [('What', 'WP'),
#   ('do', 'VBP'),
#   ('you', 'PRP'),
#   ('observe', 'VB'),
#   ('?', '.')],
#  [('(', '('),
#   ('Remember', 'VB'),
#   (':', ':'),
#   ('If', 'IN'),
#   ('the', 'DT'),
#   ('class', 'NN'),
#   ('icons', 'NNS'),
#   ('on', 'IN'),
#   ('the', 'DT'),
#   ('right', 'JJ'),
#   ('appear', 'NN'),
#   ('striped', 'VBD'),
#   (',', ','),
#   ('you', 'PRP'),
#   ('have', 'VBP'),
#   ('to', 'TO'),
#   ('compile', 'VB'),
#   ('the', 'DT'),
#   ('project', 'NN'),
#   ('first', 'RB'),
#   ('.', '.'),
#   (')', ')')],
#  [('On', 'IN'),
#   ('the', 'DT'),
#   ('right', 'NN'),
#   (',', ','),
#   ('you', 'PRP'),
#   ('see', 'VBP'),
#   ('the', 'DT'),
#   ('classes', 'NNS'),
#   ('in', 'IN'),
#   ('this', 'DT'),
#   ('scenario', 'NN'),
#   ('(', '('),
#   ('Figure', 'NNP'),
#   ('2.2', 'CD'),
#   (')', ')'),
#   ('.', '.')],
#  [('We', 'PRP'),
#   ('notice', 'VBP'),
#   ('that', 'IN'),
#   ('there', 'EX'),
#   ('is', 'VBZ'),
#   ('the', 'DT'),
#   ('usual', 'JJ'),
#   ('Greenfoot', 'NNP'),
#   ('Actor', 'NNP'),
#   ('class', 'NN'),
#   (',', ','),
#   ('a', 'DT'),
#   ('class', 'NN'),
#   ('called', 'VBN'),
#   ('Animal', 'NNP'),
#   (',', ','),
#   ('and', 'CC'),
#   ('the', 'DT'),
#   ('Crab', 'NNP'),
#   ('class', 'NN'),
#   ('.', '.')],
#  [('The', 'DT'),
#   ('hierarchy', 'NN'),
#   ('(', '('),
#   ('denoted', 'VBN'),
#   ('by', 'IN'),
#   ('the', 'DT'),
#   ('arrows', 'NNS'),
#   (')', ')'),
#   ('indicates', 'VBZ'),
#   ('an', 'DT'),
#   ('is-a', 'JJ'),
#   ('relationship', 'NN'),
#   ('(', '('),
#   ('also', 'RB'),
#   ('called', 'VBN'),
#   ('inheritance', 'NN'),
#   (')', ')'),
#   (':', ':'),
#   ('A', 'DT'),
#   ('crab', 'NN'),
#   ('is', 'VBZ'),
#   ('an', 'DT'),
#   ('animal', 'NN'),
#   (',', ','),
#   ('and', 'CC'),
#   ('an', 'DT'),
#   ('animal', 'NN'),
#   ('is', 'VBZ'),
#   ('an', 'DT'),
#   ('actor', 'NN'),
#   ('.', '.')],
#  [('(', '('),
#   ('It', 'PRP'),
#   ('follows', 'VBZ'),
#   ('then', 'RB'),
#   (',', ','),
#   ('that', 'IN'),
#   ('a', 'DT'),
#   ('crab', 'NN'),
#   ('also', 'RB'),
#   ('is', 'VBZ'),
#   ('an', 'DT'),
#   ('actor', 'NN'),
#   ('.', '.'),
#   (')', ')')],
#  [('Initially', 'RB'),
#   (',', ','),
#   ('we', 'PRP'),
#   ('will', 'MD'),
#   ('work', 'VB'),
#   ('only', 'RB'),
#   ('with', 'IN'),
#   ('the', 'DT'),
#   ('Crab', 'NNP'),
#   ('class', 'NN'),
#   ('.', '.')],
#  [('We', 'PRP'),
#   ('will', 'MD'),
#   ('talk', 'VB'),
#   ('a', 'DT'),
#   ('little', 'RB'),
#   ('more', 'RBR'),
#   ('about', 'IN'),
#   ('the', 'DT'),
#   ('Actor', 'NNP'),
#   ('and', 'CC'),
#   ('Animal', 'NNP'),
#   ('classes', 'NNS'),
#   ('later', 'RB'),
#   ('on', 'IN'),
#   ('.', '.')],
#  [('If', 'IN'),
#   ('you', 'PRP'),
#   ('have', 'VBP'),
#   ('done', 'VBN'),
#   ('the', 'DT'),
#   ('exercise', 'NN'),
#   ('above', 'IN'),
#   (',', ','),
#   ('then', 'RB'),
#   ('you', 'PRP'),
#   ('know', 'VBP'),
#   ('the', 'DT'),
#   ('answer', 'NN'),
#   ('to', 'TO'),
#   ('the', 'DT'),
#   ('question', 'NN'),
#   ('“What', 'WP'),
#   ('do', 'VBP'),
#   ('you', 'PRP'),
#   ('observe', 'VB'),
#   ('?', '.'),
#   ('”', 'VB'),
#   ('It', 'PRP'),
#   ('is', 'VBZ'),
#   (':', ':'),
#   ('“nothing”', 'NN'),
#   ('.', '.')],
#  [('2.1', 'CD'),
#   ('The', 'DT'),
#   ('Little', 'JJ'),
#   ('Crab', 'NNP'),
#   ('scenario', 'NN'),
#   ('|', 'VBZ'),
#   ('17', 'CD'),
#   ('Figure', 'NN'),
#   ('2.1', 'CD'),
#   ('The', 'DT'),
#   ('Little', 'JJ'),
#   ('Crab', 'NNP'),
#   ('scenario', 'NN'),
#   ('Figure', 'NNP'),
#   ('2.2', 'CD'),
#   ('The', 'DT'),
#   ('Little', 'NNP'),
#   ('Crab', 'NNP'),
#   ('actor', 'NN'),
#   ('classes', 'VBZ'),
#   ('The', 'DT'),
#   ('crab', 'NN'),
#   ('does', 'VBZ'),
#   ('not', 'RB'),
#   ('do', 'VB'),
#   ('anything', 'NN'),
#   ('when', 'WRB'),
#   ('Greenfoot', 'NNP'),
#   ('runs', 'VBZ'),
#   ('.', '.')],
#  [('This', 'DT'),
#   ('is', 'VBZ'),
#   ('because', 'IN'),
#   ('there', 'EX'),
#   ('is', 'VBZ'),
#   ('no', 'DT'),
#   ('source', 'NN'),
#   ('code', 'NN'),
#   ('in', 'IN'),
#   ('the', 'DT'),
#   ('definition', 'NN'),
#   ('of', 'IN'),
#   ('the', 'DT'),
#   ('Crab', 'NNP'),
#   ('class', 'NN'),
#   ('that', 'WDT'),
#   ('specifies', 'VBZ'),
#   ('what', 'WP'),
#   ('the', 'DT'),
#   ('crab', 'NN'),
#   ('should', 'MD'),
#   ('do', 'VB'),
#   ('.', '.')],
#  [('In', 'IN'),
#   ('this', 'DT'),
#   ('chapter', 'NN'),
#   (',', ','),
#   ('we', 'PRP'),
#   ('shall', 'MD'),
#   ('work', 'VB'),
#   ('on', 'IN'),
#   ('changing', 'VBG'),
#   ('this', 'DT'),
#   ('.', '.')],
#  [('The', 'DT'),
#   ('first', 'JJ'),
#   ('thing', 'NN'),
#   ('we', 'PRP'),
#   ('shall', 'MD'),
#   ('do', 'VB'),
#   ('is', 'VBZ'),
#   ('to', 'TO'),
#   ('make', 'VB'),
#   ('the', 'DT'),
#   ('crab', 'NN'),
#   ('move', 'NN'),
#   ('.', '.')],
#  [('2.2', 'CD'),
#   ('Making', 'VBG'),
#   ('the', 'DT'),
#   ('crab', 'NN'),
#   ('move', 'NN'),
#   ('Let', 'NNP'),
#   ('us', 'PRP'),
#   ('have', 'VB'),
#   ('a', 'DT'),
#   ('look', 'NN'),
#   ('at', 'IN'),
#   ('the', 'DT'),
#   ('source', 'NN'),
#   ('code', 'NN'),
#   ('of', 'IN'),
#   ('class', 'NN'),
#   ('Crab', 'NNP'),
#   ('.', '.')],
#  [('Open', 'VB'),
#   ('the', 'DT'),
#   ('editor', 'NN'),
#   ('to', 'TO'),
#   ('display', 'VB'),
#   ('the', 'DT'),
#   ('Crab', 'NNP'),
#   ('source', 'NN'),
#   ('.', '.')],
#  [('(', '('),
#   ('You', 'PRP'),
#   ('can', 'MD'),
#   ('do', 'VB'),
#   ('this', 'DT'),
#   ('by', 'IN'),
#   ('selecting', 'VBG'),
#   ('the', 'DT'),
#   ('Open', 'NNP'),
#   ('editor', 'NN'),
#   ('function', 'NN'),
#   ('from', 'IN'),
#   ('the', 'DT'),
#   ('class’s', 'NN'),
#   ('popup', 'NN'),
#   ('menu', 'NN'),
#   (',', ','),
#   ('or', 'CC'),
#   ('you', 'PRP'),
#   ('can', 'MD'),
#   ('just', 'RB'),
#   ('double-click', 'VB'),
#   ('the', 'DT'),
#   ('class', 'NN'),
#   ('.', '.'),
#   (')', ')')],
#  [('The', 'DT'),
#   ('source', 'NN'),
#   ('code', 'NN'),
#   ('you', 'PRP'),
#   ('see', 'VBP'),
#   ('is', 'VBZ'),
#   ('shown', 'VBN'),
#   ('in', 'IN'),
#   ('Code', 'NNP'),
#   ('2.1', 'CD'),
#   ('.', '.')],
#  [('18', 'CD'),
#   ('|', 'JJ'),
#   ('Chapter', 'NN'),
#   ('2', 'CD'),
#   ('■', 'IN'),
#   ('The', 'DT'),
#   ('first', 'JJ'),
#   ('program', 'NN'),
#   (':', ':'),
#   ('Little', 'JJ'),
#   ('Crab', 'NNP'),
#   ('Code', 'NNP'),
#   ('2.1', 'CD'),
#   ('The', 'DT'),
#   ('original', 'JJ'),
#   ('version', 'NN'),
#   ('of', 'IN'),
#   ('the', 'DT'),
#   ('Crab', 'NNP'),
#   ('class', 'NN'),
#   ('import', 'NN'),
#   ('greenfoot', 'NN'),
#   ('.', '.')],
#  [('*', 'NN'),
#   (';', ':'),
#   ('//', 'NNP'),
#   ('(', '('),
#   ('World', 'NNP'),
#   (',', ','),
#   ('Actor', 'NNP'),
#   (',', ','),
#   ('GreenfootImage', 'NNP'),
#   (',', ','),
#   ('and', 'CC'),
#   ('Greenfoot', 'NNP'),
#   (')', ')'),
#   ('/**', 'VBP'),
#   ('*', '$'),
#   ('This', 'DT'),
#   ('class', 'NN'),
#   ('defines', 'VBZ'),
#   ('a', 'DT'),
#   ('crab', 'NN'),
#   ('.', '.')],
#  [('Crabs', 'NNP'),
#   ('live', 'VBP'),
#   ('on', 'IN'),
#   ('the', 'DT'),
#   ('beach', 'NN'),
#   ('.', '.')],
#  [('*/', 'JJ'),
#   ('public', 'JJ'),
#   ('class', 'NN'),
#   ('Crab', 'NNP'),
#   ('extends', 'VBZ'),
#   ('Animal', 'NNP'),
#   ('{', '('),
#   ('public', 'JJ'),
#   ('void', 'NN'),
#   ('act', 'NN'),
#   ('(', '('),
#   (')', ')'),
#   ('{', '('),
#   ('//', 'JJ'),
#   ('Add', 'NNP'),
#   ('your', 'PRP$'),
#   ('action', 'NN'),
#   ('code', 'NN'),
#   ('here.', 'NN'),
#   ('}', ')')],
#  [('}', ')'),
#   ('This', 'DT'),
#   ('is', 'VBZ'),
#   ('a', 'DT'),
#   ('standard', 'JJ'),
#   ('Java', 'NNP'),
#   ('class', 'NN'),
#   ('definition', 'NN'),
#   ('.', '.')],
#  [('That', 'DT'),
#   ('is', 'VBZ'),
#   (',', ','),
#   ('this', 'DT'),
#   ('text', 'NN'),
#   ('defines', 'VBZ'),
#   ('what', 'WP'),
#   ('the', 'DT'),
#   ('crab', 'NN'),
#   ('can', 'MD'),
#   ('do', 'VB'),
#   ('.', '.')],
#  [('We', 'PRP'),
#   ('will', 'MD'),
#   ('look', 'VB'),
#   ('at', 'IN'),
#   ('it', 'PRP'),
#   ('in', 'IN'),
#   ('detail', 'NN'),
#   ('a', 'DT'),
#   ('little', 'JJ'),
#   ('later', 'RB'),
#   ('.', '.')],
#  [('For', 'IN'),
#   ('now', 'RB'),
#   (',', ','),
#   ('we', 'PRP'),
#   ('will', 'MD'),
#   ('concentrate', 'VB'),
#   ('on', 'IN'),
#   ('getting', 'VBG'),
#   ('the', 'DT'),
#   ('crab', 'NN'),
#   ('to', 'TO'),
#   ('move', 'VB'),
#   ('.', '.')],
#  [('Within', 'IN'),
#   ('this', 'DT'),
#   ('class', 'NN'),
#   ('definition', 'NN'),
#   (',', ','),
#   ('we', 'PRP'),
#   ('can', 'MD'),
#   ('see', 'VB'),
#   ('what', 'WP'),
#   ('is', 'VBZ'),
#   ('called', 'VBN'),
#   ('the', 'DT'),
#   ('act', 'NN'),
#   ('method', 'NN'),
#   ('.', '.')],
#  [('It', 'PRP'),
#   ('looks', 'VBZ'),
#   ('like', 'IN'),
#   ('this', 'DT'),
#   (':', ':'),
#   ('public', 'JJ'),
#   ('void', 'NN'),
#   ('act', 'NN'),
#   ('(', '('),
#   (')', ')'),
#   ('{', '('),
#   ('//', 'JJ'),
#   ('Add', 'NNP'),
#   ('your', 'PRP$'),
#   ('action', 'NN'),
#   ('code', 'NN'),
#   ('here.', 'NN'),
#   ('}', ')')],
#  [('The', 'DT'),
#   ('first', 'JJ'),
#   ('line', 'NN'),
#   ('is', 'VBZ'),
#   ('the', 'DT'),
#   ('signature', 'NN'),
#   ('of', 'IN'),
#   ('the', 'DT'),
#   ('method', 'NN'),
#   ('.', '.')],
#  [('The', 'DT'),
#   ('last', 'JJ'),
#   ('three', 'CD'),
#   ('lines—the', 'VBD'),
#   ('two', 'CD'),
#   ('curly', 'JJ'),
#   ('brackets', 'NNS'),
#   ('and', 'CC'),
#   ('anything', 'NN'),
#   ('between', 'IN'),
#   ('them—is', 'NN'),
#   ('called', 'VBN'),
#   ('the', 'DT'),
#   ('body', 'NN'),
#   ('of', 'IN'),
#   ('the', 'DT'),
#   ('method', 'NN'),
#   ('.', '.')],
#  [('Here', 'RB'),
#   (',', ','),
#   ('we', 'PRP'),
#   ('can', 'MD'),
#   ('add', 'VB'),
#   ('some', 'DT'),
#   ('code', 'NN'),
#   ('that', 'IN'),
#   ('determines', 'VBZ'),
#   ('the', 'DT'),
#   ('actions', 'NNS'),
#   ('of', 'IN'),
#   ('the', 'DT'),
#   ('crab', 'NN'),
#   ('.', '.')],
#  [('We', 'PRP'),
#   ('can', 'MD'),
#   ('replace', 'VB'),
#   ('the', 'DT'),
#   ('gray', 'JJ'),
#   ('text', 'NN'),
#   ('in', 'IN'),
#   ('the', 'DT'),
#   ('middle', 'NN'),
#   ('with', 'IN'),
#   ('a', 'DT'),
#   ('command', 'NN'),
#   ('.', '.')],
#  [('One', 'CD'),
#   ('such', 'JJ'),
#   ('command', 'NN'),
#   ('is', 'VBZ'),
#   ('move', 'NNP'),
#   ('(', '('),
#   (')', ')'),
#   (';', ':'),
#   ('Note', 'CC'),
#   ('that', 'IN'),
#   ('it', 'PRP'),
#   ('has', 'VBZ'),
#   ('to', 'TO'),
#   ('be', 'VB'),
#   ('written', 'VBN'),
#   ('exactly', 'RB'),
#   ('as', 'IN'),
#   ('shown', 'VBN'),
#   (',', ','),
#   ('including', 'VBG'),
#   ('the', 'DT'),
#   ('parentheses', 'NNS'),
#   ('and', 'CC'),
#   ('the', 'DT'),
#   ('semicolon', 'NN'),
#   ('.', '.')],
#  [('The', 'DT'),
#   ('act', 'NN'),
#   ('method', 'NN'),
#   ('should', 'MD'),
#   ('then', 'RB'),
#   ('look', 'VB'),
#   ('like', 'IN'),
#   ('this', 'DT'),
#   (':', ':'),
#   ('public', 'JJ'),
#   ('void', 'NN'),
#   ('act', 'NN'),
#   ('(', '('),
#   (')', ')'),
#   ('{', '('),
#   ('move', 'NN'),
#   ('(', '('),
#   (')', ')'),
#   (';', ':'),
#   ('}', ')'),
#   ('2.3', 'CD'),
#   ('Turning', 'VBG'),
#   ('|', 'JJ'),
#   ('19', 'CD'),
#   ('Exercise', 'NN'),
#   ('2.2', 'CD'),
#   ('Change', 'NNP'),
#   ('the', 'DT'),
#   ('act', 'NN'),
#   ('method', 'NN'),
#   ('in', 'IN'),
#   ('your', 'PRP$'),
#   ('crab', 'NN'),
#   ('class', 'NN'),
#   ('to', 'TO'),
#   ('include', 'VB'),
#   ('the', 'DT'),
#   ('move', 'NN'),
#   ('(', '('),
#   (')', ')'),
#   ('instruction', 'NN'),
#   (',', ','),
#   ('as', 'IN'),
#   ('shown', 'VBN'),
#   ('above', 'IN'),
#   ('.', '.')],
#  [('Compile', 'IN'),
#   ('the', 'DT'),
#   ('scenario', 'NN'),
#   ('(', '('),
#   ('by', 'IN'),
#   ('clicking', 'VBG'),
#   ('the', 'DT'),
#   ('Compile', 'NNP'),
#   ('All', 'NNP'),
#   ('button', 'NN'),
#   (')', ')'),
#   ('and', 'CC'),
#   ('place', 'NN'),
#   ('a', 'DT'),
#   ('crab', 'NN'),
#   ('into', 'IN'),
#   ('the', 'DT'),
#   ('world', 'NN'),
#   ('.', '.')],
#  [('Try', 'VB'),
#   ('clicking', 'VBG'),
#   ('the', 'DT'),
#   ('Act', 'NNP'),
#   ('and', 'CC'),
#   ('Run', 'NNP'),
#   ('buttons', 'NNS'),
#   ('.', '.')],
#  [('Exercise', 'NN'),
#   ('2.3', 'CD'),
#   ('Place', 'NN'),
#   ('multiple', 'JJ'),
#   ('crabs', 'NN'),
#   ('into', 'IN'),
#   ('the', 'DT'),
#   ('world', 'NN'),
#   ('.', '.')],
#  [('Run', 'VB'), ('the', 'DT'), ('scenario', 'NN'), ('.', '.')],
#  [('What', 'WP'),
#   ('do', 'VBP'),
#   ('you', 'PRP'),
#   ('observe', 'VB'),
#   ('?', '.')],
#  [('Concept', 'NN'),
#   (':', ':'),
#   ('A', 'DT'),
#   ('method', 'NN'),
#   ('call', 'NN'),
#   ('is', 'VBZ'),
#   ('an', 'DT'),
#   ('instruction', 'NN'),
#   ('that', 'WDT'),
#   ('tells', 'VBZ'),
#   ('an', 'DT'),
#   ('object', 'NN'),
#   ('to', 'TO'),
#   ('perform', 'VB'),
#   ('an', 'DT'),
#   ('action', 'NN'),
#   ('.', '.')],
#  [('The', 'DT'),
#   ('action', 'NN'),
#   ('is', 'VBZ'),
#   ('defined', 'VBN'),
#   ('by', 'IN'),
#   ('a', 'DT'),
#   ('method', 'NN'),
#   ('of', 'IN'),
#   ('the', 'DT'),
#   ('object', 'NN'),
#   ('.', '.')],
#  [('You', 'PRP'),
#   ('will', 'MD'),
#   ('see', 'VB'),
#   ('that', 'IN'),
#   ('the', 'DT'),
#   ('crab', 'NN'),
#   ('can', 'MD'),
#   ('now', 'RB'),
#   ('move', 'VB'),
#   ('across', 'IN'),
#   ('the', 'DT'),
#   ('screen', 'NN'),
#   ('.', '.')],
#  [('The', 'DT'),
#   ('move', 'NN'),
#   ('(', '('),
#   (')', ')'),
#   ('instruction', 'NN'),
#   ('makes', 'VBZ'),
#   ('the', 'DT'),
#   ('crab', 'JJ'),
#   ('move', 'NN'),
#   ('a', 'DT'),
#   ('little', 'JJ'),
#   ('bit', 'NN'),
#   ('to', 'TO'),
#   ('the', 'DT'),
#   ('right', 'NN'),
#   ('.', '.')],
#  [('When', 'WRB'),
#   ('we', 'PRP'),
#   ('click', 'VBP'),
#   ('the', 'DT'),
#   ('Act', 'NNP'),
#   ('button', 'NN'),
#   ('in', 'IN'),
#   ('the', 'DT'),
#   ('Greenfoot', 'NNP'),
#   ('main', 'JJ'),
#   ('window', 'NN'),
#   (',', ','),
#   ('the', 'DT'),
#   ('act', 'NN'),
#   ('method', 'NN'),
#   ('is', 'VBZ'),
#   ('executed', 'VBN'),
#   ('once', 'RB'),
#   ('.', '.')],
#  [('That', 'DT'),
#   ('is', 'VBZ'),
#   (',', ','),
#   ('the', 'DT'),
#   ('instruction', 'NN'),
#   ('that', 'IN'),
#   ('we', 'PRP'),
#   ('have', 'VBP'),
#   ('written', 'VBN'),
#   ('inside', 'IN'),
#   ('the', 'DT'),
#   ('act', 'NN'),
#   ('method', 'NN'),
#   ('(', '('),
#   ('move', 'VB'),
#   ('(', '('),
#   (')', ')'),
#   (')', ')'),
#   ('executes', 'VBZ'),
#   ('.', '.')],
#  [('Clicking', 'VBG'),
#   ('the', 'DT'),
#   ('Run', 'NNP'),
#   ('button', 'NN'),
#   ('is', 'VBZ'),
#   ('just', 'RB'),
#   ('like', 'IN'),
#   ('clicking', 'VBG'),
#   ('the', 'DT'),
#   ('Act', 'NNP'),
#   ('button', 'VBD'),
#   ('several', 'JJ'),
#   ('times', 'NNS'),
#   (',', ','),
#   ('very', 'RB'),
#   ('quickly', 'RB'),
#   ('.', '.')],
#  [('So', 'IN'),
#   ('the', 'DT'),
#   ('act', 'NN'),
#   ('method', 'NN'),
#   ('is', 'VBZ'),
#   ('executed', 'VBN'),
#   ('over', 'IN'),
#   ('and', 'CC'),
#   ('over', 'RB'),
#   ('again', 'RB'),
#   (',', ','),
#   ('until', 'IN'),
#   ('we', 'PRP'),
#   ('click', 'VBP'),
#   ('Pause', 'NNP'),
#   ('.', '.')],
#  [('Terminology', 'NNP'),
#   ('The', 'DT'),
#   ('instruction', 'NN'),
#   ('move', 'NN'),
#   ('(', '('),
#   (')', ')'),
#   ('is', 'VBZ'),
#   ('called', 'VBN'),
#   ('a', 'DT'),
#   ('method', 'NN'),
#   ('call', 'NN'),
#   ('.', '.')],
#  [('A', 'DT'),
#   ('method', 'NN'),
#   ('is', 'VBZ'),
#   ('an', 'DT'),
#   ('action', 'NN'),
#   ('that', 'IN'),
#   ('an', 'DT'),
#   ('object', 'NN'),
#   ('knows', 'VBZ'),
#   ('how', 'WRB'),
#   ('to', 'TO'),
#   ('do', 'VB'),
#   ('(', '('),
#   ('here', 'RB'),
#   (',', ','),
#   ('the', 'DT'),
#   ('object', 'NN'),
#   ('is', 'VBZ'),
#   ('the', 'DT'),
#   ('crab', 'NN'),
#   (')', ')'),
#   ('and', 'CC'),
#   ('a', 'DT'),
#   ('method', 'NN'),
#   ('call', 'NN'),
#   ('is', 'VBZ'),
#   ('an', 'DT'),
#   ('instruction', 'NN'),
#   ('telling', 'VBG'),
#   ('the', 'DT'),
#   ('crab', 'NN'),
#   ('to', 'TO'),
#   ('do', 'VB'),
#   ('it', 'PRP'),
#   ('.', '.')],
#  [('The', 'DT'),
#   ('parentheses', 'NNS'),
#   ('are', 'VBP'),
#   ('part', 'NN'),
#   ('of', 'IN'),
#   ('the', 'DT'),
#   ('method', 'NN'),
#   ('call', 'NN'),
#   ('.', '.')],
#  [('Instructions', 'NNS'),
#   ('like', 'IN'),
#   ('this', 'DT'),
#   ('end', 'NN'),
#   ('with', 'IN'),
#   ('a', 'DT'),
#   ('semicolon', 'NN'),
#   ('.', '.')],
#  [('Concept', 'NN'),
#   (':', ':'),
#   ('Additional', 'JJ'),
#   ('information', 'NN'),
#   ('can', 'MD'),
#   ('be', 'VB'),
#   ('passed', 'VBN'),
#   ('to', 'TO'),
#   ('some', 'DT'),
#   ('methods', 'NNS'),
#   ('within', 'IN'),
#   ('the', 'DT'),
#   ('parentheses', 'NNS'),
#   ('.', '.')],
#  [('The', 'DT'),
#   ('value', 'NN'),
#   ('passed', 'VBN'),
#   ('is', 'VBZ'),
#   ('called', 'VBN'),
#   ('a', 'DT'),
#   ('parameter', 'NN'),
#   ('.', '.')],
#  [('2.3', 'CD'),
#   ('Turning', 'VBG'),
#   ('Let', 'VB'),
#   ('us', 'PRP'),
#   ('see', 'VB'),
#   ('what', 'WP'),
#   ('other', 'JJ'),
#   ('instructions', 'NNS'),
#   ('we', 'PRP'),
#   ('can', 'MD'),
#   ('use', 'VB'),
#   ('.', '.')],
#  [('The', 'DT'),
#   ('crab', 'NN'),
#   ('also', 'RB'),
#   ('understands', 'VBZ'),
#   ('a', 'DT'),
#   ('turn', 'NN'),
#   ('instruction', 'NN'),
#   ('.', '.')],
#  [('Here', 'RB'),
#   ('is', 'VBZ'),
#   ('what', 'WP'),
#   ('it', 'PRP'),
#   ('looks', 'VBZ'),
#   ('like', 'IN'),
#   (':', ':'),
#   ('turn', 'NN'),
#   ('(', '('),
#   ('5', 'CD'),
#   (')', ')'),
#   (';', ':'),
#   ('The', 'DT'),
#   ('number', 'NN'),
#   ('5', 'CD'),
#   ('in', 'IN'),
#   ('the', 'DT'),
#   ('instruction', 'NN'),
#   ('specifies', 'VBZ'),
#   ('how', 'WRB'),
#   ('many', 'JJ'),
#   ('degrees', 'VBZ'),
#   ('the', 'DT'),
#   ('crab', 'NN'),
#   ('should', 'MD'),
#   ('turn', 'VB'),
#   ('.', '.')],
#  [('This', 'DT'),
#   ('is', 'VBZ'),
#   ('called', 'VBN'),
#   ('a', 'DT'),
#   ('parameter', 'NN'),
#   ('.', '.')],
#  [('We', 'PRP'),
#   ('can', 'MD'),
#   ('also', 'RB'),
#   ('use', 'VB'),
#   ('other', 'JJ'),
#   ('numbers', 'NNS'),
#   (',', ','),
#   ('for', 'IN'),
#   ('example', 'NN'),
#   (':', ':'),
#   ('turn', 'NN'),
#   ('(', '('),
#   ('23', 'CD'),
#   (')', ')'),
#   (';', ':'),
#   ('The', 'DT'),
#   ('degree', 'NN'),
#   ('value', 'NN'),
#   ('is', 'VBZ'),
#   ('specified', 'VBN'),
#   ('out', 'IN'),
#   ('of', 'IN'),
#   ('360', 'CD'),
#   ('degrees', 'NNS'),
#   (',', ','),
#   ('so', 'IN'),
#   ('any', 'DT'),
#   ('value', 'NN'),
#   ('between', 'IN'),
#   ('0', 'CD'),
#   ('and', 'CC'),
#   ('359', 'CD'),
#   ('can', 'MD'),
#   ('be', 'VB'),
#   ('used', 'VBN'),
#   ('.', '.')],
#  [('(', '('),
#   ('Turning', 'VBG'),
#   ('360', 'CD'),
#   ('degrees', 'NNS'),
#   ('would', 'MD'),
#   ('turn', 'VB'),
#   ('all', 'PDT'),
#   ('the', 'DT'),
#   ('way', 'NN'),
#   ('around', 'IN'),
#   (',', ','),
#   ('so', 'IN'),
#   ('it', 'PRP'),
#   ('is', 'VBZ'),
#   ('the', 'DT'),
#   ('same', 'JJ'),
#   ('as', 'IN'),
#   ('turning', 'VBG'),
#   ('0', 'CD'),
#   ('degrees', 'NNS'),
#   (',', ','),
#   ('or', 'CC'),
#   ('not', 'RB'),
#   ('turning', 'VBG'),
#   ('at', 'IN'),
#   ('all', 'DT'),
#   ('.', '.'),
#   (')', ')')],
#  [('If', 'IN'),
#   ('we', 'PRP'),
#   ('want', 'VBP'),
#   ('to', 'TO'),
#   ('turn', 'VB'),
#   ('instead', 'RB'),
#   ('of', 'IN'),
#   ('moving', 'VBG'),
#   (',', ','),
#   ('we', 'PRP'),
#   ('can', 'MD'),
#   ('replace', 'VB'),
#   ('the', 'DT'),
#   ('move', 'NN'),
#   ('(', '('),
#   (')', ')'),
#   ('instruction', 'NN'),
#   ('with', 'IN'),
#   ('a', 'DT'),
#   ('turn', 'NN'),
#   ('(', '('),
#   ('5', 'CD'),
#   (')', ')'),
#   ('instruction', 'NN'),
#   ('.', '.')],
#  [('The', 'DT'),
#   ('act', 'NN'),
#   ('method', 'NN'),
#   ('then', 'RB'),
#   ('looks', 'VBZ'),
#   ('like', 'IN'),
#   ('this', 'DT'),
#   (':', ':'),
#   ('public', 'JJ'),
#   ('void', 'NN'),
#   ('act', 'NN'),
#   ('(', '('),
#   (')', ')'),
#   ('{', '('),
#   ('turn', 'NN'),
#   ('(', '('),
#   ('5', 'CD'),
#   (')', ')'),
#   (';', ':'),
#   ('}', ')'),
#   ('Exercise', 'NNP'),
#   ('2.4', 'CD'),
#   ('Replace', 'NNP'),
#   ('move', 'NN'),
#   ('(', '('),
#   (')', ')'),
#   ('with', 'IN'),
#   ('turn', 'NN'),
#   ('(', '('),
#   ('5', 'CD'),
#   (')', ')'),
#   ('in', 'IN'),
#   ('your', 'PRP$'),
#   ('scenario', 'NN'),
#   ('.', '.')],
#  [('Try', 'VB'), ('it', 'PRP'), ('out', 'RP'), ('.', '.')],
#  [('Also', 'RB'),
#   (',', ','),
#   ('try', 'VB'),
#   ('values', 'NNS'),
#   ('other', 'JJ'),
#   ('than', 'IN'),
#   ('5', 'CD'),
#   ('and', 'CC'),
#   ('see', 'VB'),
#   ('what', 'WP'),
#   ('it', 'PRP'),
#   ('looks', 'VBZ'),
#   ('like', 'IN'),
#   ('.', '.')],
#  [('Remember', 'NNP'),
#   (':', ':'),
#   ('Every', 'DT'),
#   ('time', 'NN'),
#   ('you', 'PRP'),
#   ('change', 'VBP'),
#   ('your', 'PRP$'),
#   ('source', 'NN'),
#   ('code', 'NN'),
#   (',', ','),
#   ('you', 'PRP'),
#   ('must', 'MD'),
#   ('compile', 'VB'),
#   ('again', 'RB'),
#   ('.', '.')],
#  [('Exercise', 'NN'),
#   ('2.5', 'CD'),
#   ('How', 'WRB'),
#   ('can', 'MD'),
#   ('you', 'PRP'),
#   ('make', 'VB'),
#   ('the', 'DT'),
#   ('crab', 'NN'),
#   ('turn', 'NN'),
#   ('left', 'VBD'),
#   ('?', '.')],
#  [('Concept', 'NN'),
#   (':', ':'),
#   ('Multiple', 'JJ'),
#   ('instructions', 'NNS'),
#   ('are', 'VBP'),
#   ('executed', 'VBN'),
#   ('in', 'IN'),
#   ('sequence', 'NN'),
#   (',', ','),
#   ('one', 'CD'),
#   ('after', 'IN'),
#   ('the', 'DT'),
#   ('other', 'JJ'),
#   (',', ','),
#   ('in', 'IN'),
#   ('the', 'DT'),
#   ('order', 'NN'),
#   ('in', 'IN'),
#   ('which', 'WDT'),
#   ('they', 'PRP'),
#   ('are', 'VBP'),
#   ('written', 'VBN'),
#   ('.', '.')],
#  [('20', 'CD'),
#   ('|', 'JJ'),
#   ('Chapter', 'NN'),
#   ('2', 'CD'),
#   ('■', 'IN'),
#   ('The', 'DT'),
#   ('first', 'JJ'),
#   ('program', 'NN'),
#   (':', ':'),
#   ('Little', 'JJ'),
#   ('Crab', 'NNP'),
#   ('Code', 'NNP'),
#   ('2.2', 'CD'),
#   ('Making', 'VBG'),
#   ('the', 'DT'),
#   ('crab', 'NN'),
#   ('move', 'NN'),
#   ('and', 'CC'),
#   ('turn', 'NN'),
#   ('import', 'NN'),
#   ('greenfoot', 'NN'),
#   ('.', '.')],
#  [('*', 'NN'),
#   (';', ':'),
#   ('//', 'NNP'),
#   ('(', '('),
#   ('World', 'NNP'),
#   (',', ','),
#   ('Actor', 'NNP'),
#   (',', ','),
#   ('GreenfootImage', 'NNP'),
#   (',', ','),
#   ('and', 'CC'),
#   ('Greenfoot', 'NNP'),
#   (')', ')'),
#   ('/**', 'VBP'),
#   ('*', '$'),
#   ('This', 'DT'),
#   ('class', 'NN'),
#   ('defines', 'VBZ'),
#   ('a', 'DT'),
#   ('crab', 'NN'),
#   ('.', '.')],
#  [('Crabs', 'NNP'),
#   ('live', 'VBP'),
#   ('on', 'IN'),
#   ('the', 'DT'),
#   ('beach', 'NN'),
#   ('.', '.')],
#  [('*/', 'JJ'),
#   ('public', 'JJ'),
#   ('class', 'NN'),
#   ('Crab', 'NNP'),
#   ('extends', 'VBZ'),
#   ('Animal', 'NNP'),
#   ('{', '('),
#   ('public', 'JJ'),
#   ('void', 'NN'),
#   ('act', 'NN'),
#   ('(', '('),
#   (')', ')'),
#   ('{', '('),
#   ('move', 'NN'),
#   ('(', '('),
#   (')', ')'),
#   (';', ':'),
#   ('turn', 'NN'),
#   ('(', '('),
#   ('5', 'CD'),
#   (')', ')'),
#   (';', ':'),
#   ('}', ')'),
#   ('}', ')'),
#   ('The', 'DT'),
#   ('next', 'JJ'),
#   ('thing', 'NN'),
#   ('we', 'PRP'),
#   ('can', 'MD'),
#   ('try', 'VB'),
#   ('is', 'VBZ'),
#   ('to', 'TO'),
#   ('both', 'DT'),
#   ('move', 'NN'),
#   ('and', 'CC'),
#   ('turn', 'NN'),
#   ('.', '.')],
#  [('The', 'DT'),
#   ('act', 'NN'),
#   ('method', 'NN'),
#   ('can', 'MD'),
#   ('hold', 'VB'),
#   ('more', 'JJR'),
#   ('than', 'IN'),
#   ('one', 'CD'),
#   ('instruction—we', 'NN'),
#   ('can', 'MD'),
#   ('just', 'RB'),
#   ('write', 'VB'),
#   ('multiple', 'JJ'),
#   ('instructions', 'NNS'),
#   ('in', 'IN'),
#   ('a', 'DT'),
#   ('row', 'NN'),
#   ('.', '.')],
#  [('Code', 'NNP'),
#   ('2.2', 'CD'),
#   ('shows', 'VBZ'),
#   ('the', 'DT'),
#   ('complete', 'JJ'),
#   ('Crab', 'NNP'),
#   ('class', 'NN'),
#   (',', ','),
#   ('as', 'IN'),
#   ('it', 'PRP'),
#   ('looks', 'VBZ'),
#   ('when', 'WRB'),
#   ('we', 'PRP'),
#   ('move', 'VBP'),
#   ('and', 'CC'),
#   ('turn', 'VBP'),
#   ('.', '.')],
#  [('In', 'IN'),
#   ('this', 'DT'),
#   ('case', 'NN'),
#   (',', ','),
#   ('at', 'IN'),
#   ('every', 'DT'),
#   ('act', 'JJ'),
#   ('step', 'NN'),
#   (',', ','),
#   ('the', 'DT'),
#   ('crab', 'NN'),
#   ('will', 'MD'),
#   ('move', 'VB'),
#   ('and', 'CC'),
#   ('then', 'RB'),
#   ('turn', 'VB'),
#   ('(', '('),
#   ('but', 'CC'),
#   ('these', 'DT'),
#   ('actions', 'NNS'),
#   ('will', 'MD'),
#   ('happen', 'VB'),
#   ('so', 'RB'),
#   ('quickly', 'RB'),
#   ('after', 'IN'),
#   ('each', 'DT'),
#   ('other', 'JJ'),
#   ('that', 'IN'),
#   ('it', 'PRP'),
#   ('appears', 'VBZ'),
#   ('as', 'IN'),
#   ('if', 'IN'),
#   ('they', 'PRP'),
#   ('happen', 'VBP'),
#   ('at', 'IN'),
#   ('the', 'DT'),
#   ('same', 'JJ'),
#   ('time', 'NN'),
#   (')', ')'),
#   ('.', '.')],
#  [('Exercise', 'NN'),
#   ('2.6', 'CD'),
#   ('Use', 'NN'),
#   ('a', 'DT'),
#   ('move', 'NN'),
#   ('(', '('),
#   (')', ')'),
#   ('and', 'CC'),
#   ('turn', 'NN'),
#   ('(', '('),
#   ('N', 'NNP'),
#   (')', ')'),
#   ('instruction', 'NN'),
#   ('in', 'IN'),
#   ('your', 'PRP$'),
#   ('crab’s', 'NN'),
#   ('act', 'NN'),
#   ('method', 'NN'),
#   ('.', '.')],
#  [('Try', 'VB'),
#   ('different', 'JJ'),
#   ('values', 'NNS'),
#   ('for', 'IN'),
#   ('N.', 'NNP'),
#   ('Terminology', 'NNP'),
#   ('The', 'DT'),
#   ('number', 'NN'),
#   ('within', 'IN'),
#   ('the', 'DT'),
#   ('parentheses', 'NNS'),
#   ('in', 'IN'),
#   ('the', 'DT'),
#   ('turn', 'NN'),
#   ('instruction—that', 'NN'),
#   ('is', 'VBZ'),
#   (',', ','),
#   ('the', 'DT'),
#   ('5', 'CD'),
#   ('in', 'IN'),
#   ('turn', 'NN'),
#   ('(', '('),
#   ('5', 'CD'),
#   (')', ')'),
#   ('—is', 'NN'),
#   ('called', 'VBD'),
#   ('a', 'DT'),
#   ('parameter', 'NN'),
#   ('.', '.')],
#  [('A', 'DT'),
#   ('parameter', 'NN'),
#   ('is', 'VBZ'),
#   ('an', 'DT'),
#   ('additional', 'JJ'),
#   ('bit', 'NN'),
#   ('of', 'IN'),
#   ('information', 'NN'),
#   ('that', 'IN'),
#   ('we', 'PRP'),
#   ('have', 'VBP'),
#   ('to', 'TO'),
#   ('provide', 'VB'),
#   ('when', 'WRB'),
#   ('we', 'PRP'),
#   ('call', 'VBP'),
#   ('some', 'DT'),
#   ('methods', 'NNS'),
#   ('.', '.')],
#  [('Some', 'DT'),
#   ('methods', 'NNS'),
#   (',', ','),
#   ('like', 'IN'),
#   ('move', 'NN'),
#   (',', ','),
#   ('expect', 'VBP'),
#   ('no', 'DT'),
#   ('parameters', 'NNS'),
#   ('.', '.')],
#  [('They', 'PRP'),
#   ('are', 'VBP'),
#   ('happy', 'JJ'),
#   ('to', 'TO'),
#   ('just', 'RB'),
#   ('execute', 'VB'),
#   ('as', 'RB'),
#   ('soon', 'RB'),
#   ('as', 'IN'),
#   ('we', 'PRP'),
#   ('write', 'VBP'),
#   ('the', 'DT'),
#   ('move', 'NN'),
#   ('(', '('),
#   (')', ')'),
#   ('instruction', 'NN'),
#   ('.', '.')],
#  [('Other', 'JJ'),
#   ('methods', 'NNS'),
#   (',', ','),
#   ('such', 'JJ'),
#   ('as', 'IN'),
#   ('turn', 'NN'),
#   (',', ','),
#   ('want', 'VBP'),
#   ('more', 'JJR'),
#   ('information', 'NN'),
#   (':', ':'),
#   ('How', 'WRB'),
#   ('much', 'JJ'),
#   ('should', 'MD'),
#   ('I', 'PRP'),
#   ('turn', 'VB'),
#   ('?', '.')],
#  [('In', 'IN'),
#   ('this', 'DT'),
#   ('case', 'NN'),
#   (',', ','),
#   ('we', 'PRP'),
#   ('have', 'VBP'),
#   ('to', 'TO'),
#   ('provide', 'VB'),
#   ('that', 'DT'),
#   ('information', 'NN'),
#   ('in', 'IN'),
#   ('the', 'DT'),
#   ('form', 'NN'),
#   ('of', 'IN'),
#   ('a', 'DT'),
#   ('parameter', 'NN'),
#   ('value', 'NN'),
#   ('within', 'IN'),
#   ('the', 'DT'),
#   ('parentheses', 'NNS'),
#   (',', ','),
#   ('for', 'IN'),
#   ('instance', 'NN'),
#   (',', ','),
#   ('turn', 'NN'),
#   ('(', '('),
#   ('17', 'CD'),
#   (')', ')'),
#   ('.', '.')],
#  [('2.4', 'CD'),
#   ('Dealing', 'VBG'),
#   ('with', 'IN'),
#   ('screen', 'JJ'),
#   ('edges', 'NNS'),
#   ('|', 'VBP'),
#   ('21', 'CD'),
#   ('Concept', 'NN'),
#   (':', ':'),
#   ('When', 'WRB'),
#   ('a', 'DT'),
#   ('class', 'NN'),
#   ('is', 'VBZ'),
#   ('compiled', 'VBN'),
#   (',', ','),
#   ('the', 'DT'),
#   ('compiler', 'NN'),
#   ('checks', 'NNS'),
#   ('to', 'TO'),
#   ('see', 'VB'),
#   ('whether', 'IN'),
#   ('there', 'EX'),
#   ('are', 'VBP'),
#   ('any', 'DT'),
#   ('errors', 'NNS'),
#   ('.', '.')],
#  [('If', 'IN'),
#   ('an', 'DT'),
#   ('error', 'NN'),
#   ('is', 'VBZ'),
#   ('found', 'VBN'),
#   (',', ','),
#   ('an', 'DT'),
#   ('error', 'NN'),
#   ('message', 'NN'),
#   ('is', 'VBZ'),
#   ('displayed', 'VBN'),
#   ('.', '.')],
#  [('Side', 'JJ'),
#   ('note', 'NN'),
#   (':', ':'),
#   ('Errors', 'NNS'),
#   ('When', 'WRB'),
#   ('we', 'PRP'),
#   ('write', 'VBP'),
#   ('source', 'NN'),
#   ('code', 'NN'),
#   (',', ','),
#   ('we', 'PRP'),
#   ('have', 'VBP'),
#   ('to', 'TO'),
#   ('be', 'VB'),
#   ('very', 'RB'),
#   ('careful—every', 'JJ'),
#   ('single', 'JJ'),
#   ('character', 'NN'),
#   ('counts', 'NNS'),
#   ('.', '.')],
#  [('Getting', 'VBG'),
#   ('one', 'CD'),
#   ('small', 'JJ'),
#   ('thing', 'NN'),
#   ('wrong', 'JJ'),
#   ('will', 'MD'),
#   ('result', 'VB'),
#   ('in', 'IN'),
#   ('our', 'PRP$'),
#   ('program', 'NN'),
#   ('not', 'RB'),
#   ('working', 'VBG'),
#   ('.', '.')],
#  [('Usually', 'RB'),
#   (',', ','),
#   ('it', 'PRP'),
#   ('will', 'MD'),
#   ('not', 'RB'),
#   ('compile', 'VB'),
#   ('.', '.')],
#  [('This', 'DT'),
#   ('will', 'MD'),
#   ('happen', 'VB'),
#   ('to', 'TO'),
#   ('us', 'PRP'),
#   ('regularly', 'RB'),
#   (':', ':'),
#   ('When', 'WRB'),
#   ('we', 'PRP'),
#   ('write', 'VBP'),
#   ('programs', 'NNS'),
#   (',', ','),
#   ('we', 'PRP'),
#   ('inevitably', 'RB'),
#   ('make', 'VBP'),
#   ('mistakes', 'NNS'),
#   (',', ','),
#   ('and', 'CC'),
#   ('then', 'RB'),
#   ('we', 'PRP'),
#   ('have', 'VBP'),
#   ('to', 'TO'),
#   ('correct', 'VB'),
#   ('them', 'PRP'),
#   ('.', '.')],
#  [('Let', 'VB'),
#   ('us', 'PRP'),
#   ('try', 'VB'),
#   ('that', 'IN'),
#   ('out', 'RB'),
#   ('now', 'RB'),
#   ('.', '.')],
#  [('If', 'IN'),
#   (',', ','),
#   ('for', 'IN'),
#   ('example', 'NN'),
#   (',', ','),
#   ('we', 'PRP'),
#   ('forget', 'VBP'),
#   ('to', 'TO'),
#   ('write', 'VB'),
#   ('the', 'DT'),
#   ('semicolon', 'NN'),
#   ('after', 'IN'),
#   ('the', 'DT'),
#   ('move', 'NN'),
#   ('(', '('),
#   (')', ')'),
#   ('instruction', 'NN'),
#   (',', ','),
#   ('we', 'PRP'),
#   ('will', 'MD'),
#   ('be', 'VB'),
#   ('told', 'VBN'),
#   ('about', 'IN'),
#   ('it', 'PRP'),
#   ('when', 'WRB'),
#   ('we', 'PRP'),
#   ('try', 'VBP'),
#   ('to', 'TO'),
#   ('compile', 'VB'),
#   ('.', '.')],
#  [('Exercise', 'NN'),
#   ('2.7', 'CD'),
#   ('Open', 'NNP'),
#   ('your', 'PRP$'),
#   ('editor', 'NN'),
#   ('to', 'TO'),
#   ('show', 'VB'),
#   ('the', 'DT'),
#   ('crab’s', 'NN'),
#   ('source', 'NN'),
#   ('code', 'NN'),
#   (',', ','),
#   ('and', 'CC'),
#   ('remove', 'VB'),
#   ('the', 'DT'),
#   ('semicolon', 'NN'),
#   ('after', 'IN'),
#   ('move', 'NN'),
#   ('(', '('),
#   (')', ')'),
#   ('.', '.')],
#  [('Then', 'RB'), ('compile', 'NN'), ('.', '.')],
#  [('Also', 'RB'),
#   ('experiment', 'NN'),
#   ('with', 'IN'),
#   ('other', 'JJ'),
#   ('errors', 'NNS'),
#   (',', ','),
#   ('such', 'JJ'),
#   ('as', 'IN'),
#   ('misspelling', 'VBG'),
#   ('move', 'NN'),
#   ('or', 'CC'),
#   ('making', 'VBG'),
#   ('other', 'JJ'),
#   ('random', 'JJ'),
#   ('changes', 'NNS'),
#   ('to', 'TO'),
#   ('the', 'DT'),
#   ('code', 'NN'),
#   ('.', '.')],
#  [('Make', 'NNP'),
#   ('sure', 'JJ'),
#   ('to', 'TO'),
#   ('change', 'VB'),
#   ('it', 'PRP'),
#   ('all', 'DT'),
#   ('back', 'RB'),
#   ('after', 'IN'),
#   ('this', 'DT'),
#   ('exercise', 'NN'),
#   ('.', '.')],
#  [('Exercise', 'NN'),
#   ('2.8', 'CD'),
#   ('Make', 'NNP'),
#   ('various', 'JJ'),
#   ('changes', 'NNS'),
#   ('to', 'TO'),
#   ('cause', 'VB'),
#   ('different', 'JJ'),
#   ('error', 'NN'),
#   ('messages', 'NNS'),
#   ('.', '.')],
#  [('Find', 'NNP'),
#   ('at', 'IN'),
#   ('least', 'JJS'),
#   ('five', 'CD'),
#   ('different', 'JJ'),
#   ('error', 'NN'),
#   ('messages', 'NNS'),
#   ('.', '.')],
#  [('Write', 'NNP'),
#   ('down', 'RP'),
#   ('each', 'DT'),
#   ('error', 'NN'),
#   ('message', 'NN'),
#   ('and', 'CC'),
#   ('what', 'WP'),
#   ('change', 'NN'),
#   ('you', 'PRP'),
#   ('introduced', 'VBD'),
#   ('to', 'TO'),
#   ('provoke', 'VB'),
#   ('this', 'DT'),
#   ('error', 'NN'),
#   ('.', '.')],
#  [('Tip', 'NN'),
#   (':', ':'),
#   ('When', 'WRB'),
#   ('an', 'DT'),
#   ('error', 'NN'),
#   ('message', 'NN'),
#   ('appears', 'VBZ'),
#   ('at', 'IN'),
#   ('the', 'DT'),
#   ('bottom', 'NN'),
#   ('of', 'IN'),
#   ('the', 'DT'),
#   ('editor', 'NN'),
#   ('window', 'NN'),
#   (',', ','),
#   ('a', 'DT'),
#   ('question', 'NN'),
#   ('mark', 'NN'),
#   ('button', 'NN'),
#   ('appears', 'VBZ'),
#   ('to', 'TO'),
#   ('the', 'DT'),
#   ('right', 'NN'),
#   ('of', 'IN'),
#   ('it', 'PRP'),
#   ('.', '.')],
#  [('Clicking', 'VBG'),
#   ('this', 'DT'),
#   ('button', 'NN'),
#   ('displays', 'VBZ'),
#   ('some', 'DT'),
#   ('additional', 'JJ'),
#   ('information', 'NN'),
#   ('about', 'IN'),
#   ('the', 'DT'),
#   ('error', 'NN'),
#   ('message', 'NN'),
#   ('.', '.')],
#  [('As', 'IN'),
#   ('we', 'PRP'),
#   ('can', 'MD'),
#   ('see', 'VB'),
#   ('with', 'IN'),
#   ('this', 'DT'),
#   ('exercise', 'NN'),
#   (',', ','),
#   ('if', 'IN'),
#   ('we', 'PRP'),
#   ('get', 'VBP'),
#   ('one', 'CD'),
#   ('small', 'JJ'),
#   ('detail', 'NN'),
#   ('wrong', 'JJ'),
#   (',', ','),
#   ('Greenfoot', 'NNP'),
#   ('will', 'MD'),
#   ('open', 'VB'),
#   ('the', 'DT'),
#   ('editor', 'NN'),
#   (',', ','),
#   ('highlight', 'VBD'),
#   ('a', 'DT'),
#   ('line', 'NN'),
#   (',', ','),
#   ('and', 'CC'),
#   ('display', 'VB'),
#   ('a', 'DT'),
#   ('message', 'NN'),
#   ('at', 'IN'),
#   ('the', 'DT'),
#   ('bottom', 'NN'),
#   ('of', 'IN'),
#   ('the', 'DT'),
#   ('editor', 'NN'),
#   ('window', 'NN'),
#   ('.', '.')],
#  [('This', 'DT'),
#   ('message', 'NN'),
#   ('attempts', 'VBZ'),
#   ('to', 'TO'),
#   ('explain', 'VB'),
#   ('the', 'DT'),
#   ('error', 'NN'),
#   ('.', '.')],
#  [('The', 'DT'),
#   ('messages', 'NNS'),
#   (',', ','),
#   ('however', 'RB'),
#   (',', ','),
#   ('vary', 'JJ'),
#   ('considerably', 'RB'),
#   ('in', 'IN'),
#   ('their', 'PRP$'),
#   ('accuracy', 'NN'),
#   ('and', 'CC'),
#   ('usefulness', 'NN'),
#   ('.', '.')],
#  [('Sometimes', 'RB'),
#   ('they', 'PRP'),
#   ('tell', 'VBP'),
#   ('us', 'PRP'),
#   ('fairly', 'RB'),
#   ('accurately', 'RB'),
#   ('what', 'WP'),
#   ('the', 'DT'),
#   ('problem', 'NN'),
#   ('is', 'VBZ'),
#   (',', ','),
#   ('but', 'CC'),
#   ('sometimes', 'RB'),
#   ('they', 'PRP'),
#   ('are', 'VBP'),
#   ('cryptic', 'JJ'),
#   ('and', 'CC'),
#   ('hard', 'JJ'),
#   ('to', 'TO'),
#   ('understand', 'VB'),
#   ('.', '.')],
#  [('The', 'DT'),
#   ('line', 'NN'),
#   ('that', 'WDT'),
#   ('is', 'VBZ'),
#   ('highlighted', 'VBN'),
#   ('is', 'VBZ'),
#   ('often', 'RB'),
#   ('the', 'DT'),
#   ('line', 'NN'),
#   ('where', 'WRB'),
#   ('the', 'DT'),
#   ('problem', 'NN'),
#   ('is', 'VBZ'),
#   (',', ','),
#   ('but', 'CC'),
#   ('sometimes', 'VBZ'),
#   ('it', 'PRP'),
#   ('is', 'VBZ'),
#   ('the', 'DT'),
#   ('line', 'NN'),
#   ('after', 'IN'),
#   ('the', 'DT'),
#   ('problem', 'NN'),
#   ('.', '.')],
#  [('When', 'WRB'),
#   ('you', 'PRP'),
#   ('see', 'VBP'),
#   (',', ','),
#   ('for', 'IN'),
#   ('example', 'NN'),
#   (',', ','),
#   ('a', 'DT'),
#   ('“', 'NN'),
#   (';', ':'),
#   ('expected”', 'CC'),
#   ('message', 'NN'),
#   (',', ','),
#   ('it', 'PRP'),
#   ('is', 'VBZ'),
#   ('possible', 'JJ'),
#   ('that', 'IN'),
#   ('the', 'DT'),
#   ('semicolon', 'NN'),
#   ('is', 'VBZ'),
#   ('in', 'IN'),
#   ('fact', 'NN'),
#   ('missing', 'VBG'),
#   ('on', 'IN'),
#   ('the', 'DT'),
#   ('line', 'NN'),
#   ('above', 'IN'),
#   ('the', 'DT'),
#   ('highlighted', 'JJ'),
#   ('line', 'NN'),
#   ('.', '.')],
#  [('We', 'PRP'),
#   ('will', 'MD'),
#   ('learn', 'VB'),
#   ('to', 'TO'),
#   ('read', 'VB'),
#   ('these', 'DT'),
#   ('messages', 'NNS'),
#   ('a', 'DT'),
#   ('little', 'JJ'),
#   ('better', 'JJR'),
#   ('over', 'IN'),
#   ('time', 'NN'),
#   ('.', '.')],
#  [('For', 'IN'),
#   ('now', 'RB'),
#   (',', ','),
#   ('if', 'IN'),
#   ('you', 'PRP'),
#   ('get', 'VBP'),
#   ('a', 'DT'),
#   ('message', 'NN'),
#   ('and', 'CC'),
#   ('you', 'PRP'),
#   ('are', 'VBP'),
#   ('unsure', 'JJ'),
#   ('what', 'WP'),
#   ('it', 'PRP'),
#   ('means', 'VBZ'),
#   (',', ','),
#   ('look', 'VB'),
#   ('very', 'RB'),
#   ('carefully', 'RB'),
#   ('at', 'IN'),
#   ('your', 'PRP$'),
#   ('code', 'NN'),
#   ('and', 'CC'),
#   ('check', 'VB'),
#   ('that', 'IN'),
#   ('you', 'PRP'),
#   ('have', 'VBP'),
#   ('typed', 'VBN'),
#   ('everything', 'NN'),
#   ('correctly', 'RB'),
#   ('.', '.')],
#  [('2.4', 'CD'),
#   ('Dealing', 'VBG'),
#   ('with', 'IN'),
#   ('screen', 'JJ'),
#   ('edges', 'NNS'),
#   ('When', 'WRB'),
#   ('we', 'PRP'),
#   ('made', 'VBD'),
#   ('the', 'DT'),
#   ('crabs', 'JJ'),
#   ('move', 'NN'),
#   ('and', 'CC'),
#   ('turn', 'NN'),
#   ('in', 'IN'),
#   ('the', 'DT'),
#   ('previous', 'JJ'),
#   ('sections', 'NNS'),
#   (',', ','),
#   ('they', 'PRP'),
#   ('got', 'VBD'),
#   ('stuck', 'VBN'),
#   ('when', 'WRB'),
#   ('they', 'PRP'),
#   ('reached', 'VBD'),
#   ('the', 'DT'),
#   ('edge', 'NN'),
#   ('of', 'IN'),
#   ('the', 'DT'),
#   ('screen', 'NN'),
#   ('.', '.')],
#  [('(', '('),
#   ('Greenfoot', 'NNP'),
#   ('is', 'VBZ'),
#   ('designed', 'VBN'),
#   ('so', 'RB'),
#   ('that', 'IN'),
#   ('actors', 'NNS'),
#   ('can', 'MD'),
#   ('not', 'RB'),
#   ('leave', 'VB'),
#   ('the', 'DT'),
#   ('world', 'NN'),
#   ('and', 'CC'),
#   ('fall', 'VB'),
#   ('off', 'RP'),
#   ('its', 'PRP$'),
#   ('edge', 'NN'),
#   ('.', '.'),
#   (')', ')')],
#  [('Now', 'RB'),
#   (',', ','),
#   ('we', 'PRP'),
#   ('shall', 'MD'),
#   ('improve', 'VB'),
#   ('this', 'DT'),
#   ('behavior', 'NN'),
#   ('so', 'RB'),
#   ('that', 'IN'),
#   ('the', 'DT'),
#   ('crab', 'NN'),
#   ('notices', 'VBZ'),
#   ('that', 'IN'),
#   ('it', 'PRP'),
#   ('has', 'VBZ'),
#   ('reached', 'VBN'),
#   ('the', 'DT'),
#   ('world', 'NN'),
#   ('edge', 'NN'),
#   ('and', 'CC'),
#   ('turns', 'VBZ'),
#   ('around', 'RB'),
#   ('.', '.')],
#  [('The', 'DT'),
#   ('question', 'NN'),
#   ('is', 'VBZ'),
#   (',', ','),
#   ('How', 'WRB'),
#   ('can', 'MD'),
#   ('we', 'PRP'),
#   ('do', 'VB'),
#   ('that', 'DT'),
#   ('?', '.')],
#  [('22', 'CD'),
#   ('|', 'JJ'),
#   ('Chapter', 'NN'),
#   ('2', 'CD'),
#   ('■', 'IN'),
#   ('The', 'DT'),
#   ('first', 'JJ'),
#   ('program', 'NN'),
#   (':', ':'),
#   ('Little', 'JJ'),
#   ('Crab', 'NNP'),
#   ('Exercise', 'NNP'),
#   ('2.9', 'CD'),
#   ('Open', 'NNP'),
#   ('the', 'DT'),
#   ('editor', 'NN'),
#   ('for', 'IN'),
#   ('the', 'DT'),
#   ('Animal', 'NNP'),
#   ('class', 'NN'),
#   ('.', '.')],
#  [('Switch', 'NN'),
#   ('to', 'TO'),
#   ('Documentation', 'NNP'),
#   ('view', 'NN'),
#   ('.', '.')],
#  [('Find', 'IN'),
#   ('the', 'DT'),
#   ('list', 'NN'),
#   ('of', 'IN'),
#   ('methods', 'NNS'),
#   ('for', 'IN'),
#   ('this', 'DT'),
#   ('class', 'NN'),
#   ('(', '('),
#   ('the', 'DT'),
#   ('“Method', 'NNP'),
#   ('Summary”', 'NNP'),
#   (')', ')'),
#   ('.', '.')],
#  [('How', 'WRB'),
#   ('many', 'JJ'),
#   ('methods', 'NNS'),
#   ('does', 'VBZ'),
#   ('this', 'DT'),
#   ('class', 'NN'),
#   ('have', 'VB'),
#   ('?', '.')],
#  [('Above', 'NNP'),
#   (',', ','),
#   ('we', 'PRP'),
#   ('have', 'VBP'),
#   ('used', 'VBN'),
#   ('the', 'DT'),
#   ('move', 'NN'),
#   ('and', 'CC'),
#   ('turn', 'NN'),
#   ('methods', 'NNS'),
#   (',', ','),
#   ('so', 'IN'),
#   ('there', 'EX'),
#   ('might', 'MD'),
#   ('also', 'RB'),
#   ('be', 'VB'),
#   ('a', 'DT'),
#   ('method', 'NN'),
#   ('that', 'WDT'),
#   ('helps', 'VBZ'),
#   ('us', 'PRP'),
#   ('with', 'IN'),
#   ('our', 'PRP$'),
#   ('new', 'JJ'),
#   ('goal', 'NN'),
#   ('.', '.')],
#  [('(', '('),
#   ('In', 'IN'),
#   ('fact', 'NN'),
#   (',', ','),
#   ('there', 'EX'),
#   ('is', 'VBZ'),
#   ('.', '.'),
#   (')', ')')],
#  [('But', 'CC'),
#   ('how', 'WRB'),
#   ('do', 'VBP'),
#   ('we', 'PRP'),
#   ('find', 'VB'),
#   ('out', 'RP'),
#   ('what', 'WP'),
#   ('methods', 'IN'),
#   ('we', 'PRP'),
#   ('have', 'VBP'),
#   ('got', 'VBN'),
#   ('available', 'JJ'),
#   ('?', '.')],
#  [('The', 'DT'),
#   ('move', 'NN'),
#   ('and', 'CC'),
#   ('turn', 'NN'),
#   ('methods', 'NNS'),
#   ('we', 'PRP'),
#   ('have', 'VBP'),
#   ('used', 'VBN'),
#   ('so', 'RB'),
#   ('far', 'RB'),
#   ('come', 'VBN'),
#   ('from', 'IN'),
#   ('the', 'DT'),
#   ('Animal', 'NNP'),
#   ('class', 'NN'),
#   ('.', '.')],
#  [('A', 'DT'),
#   ('crab', 'NN'),
#   ('is', 'VBZ'),
#   ('an', 'DT'),
#   ('animal', 'NN'),
#   ('(', '('),
#   ('signified', 'VBN'),
#   ('by', 'IN'),
#   ('the', 'DT'),
#   ('arrow', 'NN'),
#   ('that', 'WDT'),
#   ('goes', 'VBZ'),
#   ('from', 'IN'),
#   ('Crab', 'NNP'),
#   ('to', 'TO'),
#   ('Animal', 'NNP'),
#   ('in', 'IN'),
#   ('the', 'DT'),
#   ('class', 'NN'),
#   ('diagram', 'NN'),
#   (')', ')'),
#   (',', ','),
#   ('therefore', 'IN'),
#   ('it', 'PRP'),
#   ('can', 'MD'),
#   ('do', 'VB'),
#   ('whatever', 'WDT'),
#   ('an', 'DT'),
#   ('animal', 'NN'),
#   ('can', 'MD'),
#   ('do', 'VB'),
#   ('.', '.')],
#  [('Our', 'PRP$'),
#   ('Animal', 'JJ'),
#   ('class', 'NN'),
#   ('knows', 'VBZ'),
#   ('how', 'WRB'),
#   ('to', 'TO'),
#   ('move', 'VB'),
#   ('and', 'CC'),
#   ('turn—that', 'DT'),
#   ('is', 'VBZ'),
#   ('why', 'WRB'),
#   ('our', 'PRP$'),
#   ('crab', 'NN'),
#   ('can', 'MD'),
#   ('also', 'RB'),
#   ('do', 'VB'),
#   ('it', 'PRP'),
#   ('.', '.')],
#  [('This', 'DT'),
#   ('is', 'VBZ'),
#   ('called', 'VBN'),
#   ('inheritance', 'NN'),
#   (':', ':'),
#   ('The', 'DT'),
#   ('Crab', 'NNP'),
#   ('class', 'NN'),
#   ('inherits', 'VBZ'),
#   ('all', 'PDT'),
#   ('the', 'DT'),
#   ('abilities', 'NNS'),
#   ('(', '('),
#   ('methods', 'NNS'),
#   (')', ')'),
#   ('from', 'IN'),
#   ('the', 'DT'),
#   ('Animal', 'NNP'),
#   ('class', 'NN'),
#   ('.', '.')],
#  [('The', 'DT'),
#   ('question', 'NN'),
#   ('now', 'RB'),
#   ('is', 'VBZ'),
#   (',', ','),
#   ('what', 'WP'),
#   ('else', 'RB'),
#   ('can', 'MD'),
#   ('our', 'PRP$'),
#   ('animals', 'NNS'),
#   ('do', 'VB'),
#   ('?', '.')],
#  [('To', 'TO'),
#   ('investigate', 'VB'),
#   ('this', 'DT'),
#   (',', ','),
#   ('we', 'PRP'),
#   ('can', 'MD'),
#   ('open', 'VB'),
#   ('the', 'DT'),
#   ('editor', 'NN'),
#   ('for', 'IN'),
#   ('the', 'DT'),
#   ('Animal', 'NNP'),
#   ('class', 'NN'),
#   ('.', '.')],
#  [('The', 'DT'),
#   ('editor', 'NN'),
#   ('can', 'MD'),
#   ('display', 'VB'),
#   ('two', 'CD'),
#   ('different', 'JJ'),
#   ('views', 'NNS'),
#   (':', ':'),
#   ('It', 'PRP'),
#   ('can', 'MD'),
#   ('show', 'VB'),
#   ('the', 'DT'),
#   ('source', 'NN'),
#   ('code', 'NN'),
#   ('(', '('),
#   ('as', 'IN'),
#   ('we', 'PRP'),
#   ('have', 'VBP'),
#   ('seen', 'VBN'),
#   ('for', 'IN'),
#   ('the', 'DT'),
#   ('Crab', 'NNP'),
#   ('class', 'NN'),
#   (')', ')'),
#   ('or', 'CC'),
#   ('it', 'PRP'),
#   ('can', 'MD'),
#   ('show', 'VB'),
#   ('the', 'DT'),
#   ('documentation', 'NN'),
#   ('.', '.')],
#  [('The', 'DT'),
#   ('view', 'NN'),
#   ('can', 'MD'),
#   ('be', 'VB'),
#   ('switched', 'VBN'),
#   ('using', 'VBG'),
#   ('a', 'DT'),
#   ('popup', 'JJ'),
#   ('selection', 'NN'),
#   ('menu', 'NN'),
#   ('in', 'IN'),
#   ('the', 'DT'),
#   ('top', 'JJ'),
#   ('right', 'NN'),
#   ('corner', 'NN'),
#   ('of', 'IN'),
#   ('the', 'DT'),
#   ('editor', 'NN'),
#   ('window', 'NN'),
#   ('.', '.')],
#  [('We', 'PRP'),
#   ('now', 'RB'),
#   ('want', 'VBP'),
#   ('to', 'TO'),
#   ('look', 'VB'),
#   ('at', 'IN'),
#   ('the', 'DT'),
#   ('Animal', 'NNP'),
#   ('class', 'NN'),
#   ('in', 'IN'),
#   ('the', 'DT'),
#   ('Documentation', 'NNP'),
#   ('view', 'NN'),
#   ('(', '('),
#   ('Figure', 'NNP'),
#   ('2.3', 'CD'),
#   (')', ')'),
#   ('.', '.')],
#  [('Method', 'NNP'),
#   ('summary', 'JJ'),
#   ('View', 'NNP'),
#   ('switch', 'NN'),
#   ('Figure', 'NN'),
#   ('2.3', 'CD'),
#   ('Documentation', 'NNP'),
#   ('view', 'NN'),
#   ('(', '('),
#   ('with', 'IN'),
#   ('method', 'NN'),
#   ('summary', 'NN'),
#   (')', ')'),
#   ('of', 'IN'),
#   ('the', 'DT'),
#   ('Animal', 'NNP'),
#   ('class', 'NN'),
#   ('Concept', 'NNP'),
#   (':', ':'),
#   ('A', 'DT'),
#   ('subclass', 'NN'),
#   ('inherits', 'VBZ'),
#   ('all', 'PDT'),
#   ('the', 'DT'),
#   ('methods', 'NNS'),
#   ('from', 'IN'),
#   ('its', 'PRP$'),
#   ('superclass', 'NN'),
#   ('.', '.')],
#  [('That', 'DT'),
#   ('means', 'VBZ'),
#   ('that', 'IN'),
#   ('it', 'PRP'),
#   ('has', 'VBZ'),
#   ('and', 'CC'),
#   ('can', 'MD'),
#   ('use', 'VB'),
#   ('all', 'DT'),
#   ('methods', 'NNS'),
#   ('that', 'IN'),
#   ('its', 'PRP$'),
#   ('superclass', 'NN'),
#   ('defines', 'NNS'),
#   ('.', '.')],
#  [('2.4', 'CD'),
#   ('Dealing', 'VBG'),
#   ('with', 'IN'),
#   ('screen', 'JJ'),
#   ('edges', 'NNS'),
#   ('|', 'VBP'),
#   ('23', 'CD'),
#   ('If', 'IN'),
#   ('we', 'PRP'),
#   ('look', 'VBP'),
#   ('at', 'IN'),
#   ('the', 'DT'),
#   ('method', 'NN'),
#   ('summary', 'NN'),
#   (',', ','),
#   ('we', 'PRP'),
#   ('can', 'MD'),
#   ('see', 'VB'),
#   ('all', 'PDT'),
#   ('the', 'DT'),
#   ('methods', 'NNS'),
#   ('that', 'IN'),
#   ('the', 'DT'),
#   ('Animal', 'NNP'),
#   ('class', 'NN'),
#   ('provides', 'VBZ'),
#   ('.', '.')],
#  [('Among', 'IN'),
#   ('them', 'PRP'),
#   ('are', 'VBP'),
#   ('three', 'CD'),
#   ('methods', 'NNS'),
#   ('that', 'WDT'),
#   ('are', 'VBP'),
#   ('especially', 'RB'),
#   ('interesting', 'VBG'),
#   ('to', 'TO'),
#   ('us', 'PRP'),
#   ('at', 'IN'),
#   ('the', 'DT'),
#   ('moment', 'NN'),
#   ('.', '.')],
#  [('They', 'PRP'),
#   ('are', 'VBP'),
#   (':', ':'),
#   ('boolean', 'JJ'),
#   ('atWorldEdge', 'NN'),
#   ('(', '('),
#   (')', ')'),
#   ('Test', 'VBP'),
#   ('if', 'IN'),
#   ('we', 'PRP'),
#   ('are', 'VBP'),
#   ('close', 'JJ'),
#   ('to', 'TO'),
#   ('one', 'CD'),
#   ('of', 'IN'),
#   ('the', 'DT'),
#   ('edges', 'NNS'),
#   ('of', 'IN'),
#   ('the', 'DT'),
#   ('world', 'NN'),
#   ('.', '.')],
#  [('void', 'JJ'),
#   ('move', 'NN'),
#   ('(', '('),
#   (')', ')'),
#   ('Move', 'NNP'),
#   ('forward', 'RB'),
#   ('in', 'IN'),
#   ('the', 'DT'),
#   ('current', 'JJ'),
#   ('direction', 'NN'),
#   ('.', '.')],
#  [('void', 'JJ'),
#   ('turn', 'NN'),
#   ('(', '('),
#   ('int', 'JJ'),
#   ('angle', 'NN'),
#   (')', ')'),
#   ('Turn', 'NNP'),
#   ('“angle”', 'NNP'),
#   ('degrees', 'VBZ'),
#   ('toward', 'IN'),
#   ('the', 'DT'),
#   ('right', 'NN'),
#   ('(', '('),
#   ('clockwise', 'NN'),
#   (')', ')'),
#   ('.', '.')],
#  [('Here', 'RB'),
#   ('we', 'PRP'),
#   ('see', 'VBP'),
#   ('the', 'DT'),
#   ('signatures', 'NNS'),
#   ('for', 'IN'),
#   ('three', 'CD'),
#   ('methods', 'NNS'),
#   (',', ','),
#   ('as', 'IN'),
#   ('we', 'PRP'),
#   ('first', 'RB'),
#   ('encountered', 'VBD'),
#   ('them', 'PRP'),
#   ('in', 'IN'),
#   ('Chapter', 'NN'),
#   ('1', 'CD'),
#   ('.', '.')],
#  [('Each', 'DT'),
#   ('method', 'NN'),
#   ('signature', 'NN'),
#   ('starts', 'VBZ'),
#   ('with', 'IN'),
#   ('a', 'DT'),
#   ('return', 'NN'),
#   ('type', 'NN'),
#   ('and', 'CC'),
#   ('is', 'VBZ'),
#   ('followed', 'VBN'),
#   ('by', 'IN'),
#   ('the', 'DT'),
#   ('method', 'NN'),
#   ('name', 'NN'),
#   ('and', 'CC'),
#   ('the', 'DT'),
#   ('parameter', 'NN'),
#   ('list', 'NN'),
#   ('.', '.')],
#  [('Below', 'IN'),
#   ('it', 'PRP'),
#   (',', ','),
#   ('we', 'PRP'),
#   ('see', 'VBP'),
#   ('a', 'DT'),
#   ('comment', 'NN'),
#   ('describing', 'VBG'),
#   ('what', 'WP'),
#   ('the', 'DT'),
#   ('method', 'NN'),
#   ('does', 'VBZ'),
#   ('.', '.')],
#  [('We', 'PRP'),
#   ('can', 'MD'),
#   ('see', 'VB'),
#   ('that', 'IN'),
#   ('the', 'DT'),
#   ('three', 'CD'),
#   ('method', 'NN'),
#   ('names', 'NNS'),
#   ('are', 'VBP'),
#   ('atWorldEdge', 'NN'),
#   (',', ','),
#   ('move', 'NN'),
#   (',', ','),
#   ('and', 'CC'),
#   ('turn', 'NN'),
#   ('.', '.')],
#  [('The', 'DT'),
#   ('move', 'NN'),
#   ('and', 'CC'),
#   ('turn', 'NN'),
#   ('methods', 'NNS'),
#   ('are', 'VBP'),
#   ('the', 'DT'),
#   ('ones', 'NNS'),
#   ('we', 'PRP'),
#   ('used', 'VBD'),
#   ('in', 'IN'),
#   ('the', 'DT'),
#   ('previous', 'JJ'),
#   ('sections', 'NNS'),
#   ('.', '.')],
#  [('If', 'IN'),
#   ('we', 'PRP'),
#   ('look', 'VBP'),
#   ('at', 'IN'),
#   ('their', 'PRP$'),
#   ('parameter', 'NN'),
#   ('lists', 'NNS'),
#   (',', ','),
#   ('we', 'PRP'),
#   ('can', 'MD'),
#   ('see', 'VB'),
#   ('what', 'WP'),
#   ('we', 'PRP'),
#   ('observed', 'VBD'),
#   ('before', 'IN'),
#   (':', ':'),
#   ('move', 'NN'),
#   ('has', 'VBZ'),
#   ('no', 'DT'),
#   ('parameters', 'NNS'),
#   ('(', '('),
#   ('the', 'DT'),
#   ('parentheses', 'NNS'),
#   ('are', 'VBP'),
#   ('empty', 'JJ'),
#   (')', ')'),
#   (',', ','),
#   ('and', 'CC'),
#   ('turn', 'VB'),
#   ('expects', 'VBZ'),
#   ('one', 'CD'),
#   ('parameter', 'NN'),
#   ('of', 'IN'),
#   ('type', 'NN'),
#   ('int', 'NN'),
#   ('(', '('),
#   ('a', 'DT'),
#   ('whole', 'JJ'),
#   ('number', 'NN'),
#   (')', ')'),
#   ('for', 'IN'),
#   ('the', 'DT'),
#   ('angle', 'NN'),
#   ('.', '.')],
#  [('(', '('),
#   ('Read', 'JJ'),
#   ('Section', 'NN'),
#   ('1.5', 'CD'),
#   ('again', 'RB'),
#   ('if', 'IN'),
#   ('you', 'PRP'),
#   ('are', 'VBP'),
#   ('unsure', 'JJ'),
#   ('about', 'IN'),
#   ('parameter', 'NN'),
#   ('lists', 'NNS'),
#   ('.', '.'),
#   (')', ')')],
#  [('We', 'PRP'),
#   ('can', 'MD'),
#   ('also', 'RB'),
#   ('see', 'VB'),
#   ('that', 'IN'),
#   ('the', 'DT'),
#   ('move', 'NN'),
#   ('and', 'CC'),
#   ('turn', 'NN'),
#   ('methods', 'NNS'),
#   ('have', 'VBP'),
#   ('void', 'VBN'),
#   ('as', 'IN'),
#   ('their', 'PRP$'),
#   ('return', 'NN'),
#   ('type', 'NN'),
#   ('.', '.')],
#  [('This', 'DT'),
#   ('means', 'VBZ'),
#   ('that', 'IN'),
#   ('neither', 'DT'),
#   ('method', 'NN'),
#   ('returns', 'VBZ'),
#   ('a', 'DT'),
#   ('value', 'NN'),
#   ('.', '.')],
#  [('We', 'PRP'),
#   ('are', 'VBP'),
#   ('commanding', 'VBG'),
#   ('or', 'CC'),
#   ('instructing', 'VBG'),
#   ('the', 'DT'),
#   ('object', 'NN'),
#   ('to', 'TO'),
#   ('move', 'VB'),
#   ('or', 'CC'),
#   ('to', 'TO'),
#   ('turn', 'VB'),
#   ('.', '.')],
#  [('The', 'DT'),
#   ('animal', 'NN'),
#   ('will', 'MD'),
#   ('just', 'RB'),
#   ('obey', 'VB'),
#   ('the', 'DT'),
#   ('command', 'NN'),
#   ('but', 'CC'),
#   ('not', 'RB'),
#   ('respond', 'VB'),
#   ('with', 'IN'),
#   ('an', 'DT'),
#   ('answer', 'NN'),
#   ('to', 'TO'),
#   ('us', 'PRP'),
#   ('.', '.')],
#  [('The', 'DT'),
#   ('signature', 'NN'),
#   ('for', 'IN'),
#   ('atWorldEdge', 'NN'),
#   ('is', 'VBZ'),
#   ('a', 'DT'),
#   ('little', 'JJ'),
#   ('different', 'JJ'),
#   ('.', '.')],
#  [('It', 'PRP'),
#   ('is', 'VBZ'),
#   ('boolean', 'JJ'),
#   ('atWorldEdge', 'NN'),
#   ('(', '('),
#   (')', ')'),
#   ('This', 'DT'),
#   ('method', 'NN'),
#   ('has', 'VBZ'),
#   ('no', 'DT'),
#   ('parameters', 'NNS'),
#   ('(', '('),
#   ('there', 'EX'),
#   ('is', 'VBZ'),
#   ('nothing', 'NN'),
#   ('within', 'IN'),
#   ('the', 'DT'),
#   ('parentheses', 'NNS'),
#   (')', ')'),
#   (',', ','),
#   ('but', 'CC'),
#   ('it', 'PRP'),
#   ('specifies', 'VBZ'),
#   ('a', 'DT'),
#   ('return', 'NN'),
#   ('value', 'NN'),
#   (':', ':'),
#   ('boolean', 'NN'),
#   ('.', '.')],
#  [('We', 'PRP'),
#   ('have', 'VBP'),
#   ('briefly', 'VBN'),
#   ('encountered', 'VBD'),
#   ('the', 'DT'),
#   ('boolean', 'JJ'),
#   ('type', 'NN'),
#   ('in', 'IN'),
#   ('Section', 'NNP'),
#   ('1.4—it', 'CD'),
#   ('is', 'VBZ'),
#   ('a', 'DT'),
#   ('type', 'NN'),
#   ('that', 'WDT'),
#   ('can', 'MD'),
#   ('hold', 'VB'),
#   ('two', 'CD'),
#   ('possible', 'JJ'),
#   ('values', 'NNS'),
#   (':', ':'),
#   ('true', 'JJ'),
#   ('or', 'CC'),
#   ('false', 'JJ'),
#   ('.', '.')],
#  [('Calling', 'VBG'),
#   ('methods', 'NNS'),
#   ('that', 'WDT'),
#   ('have', 'VBP'),
#   ('return', 'VBN'),
#   ('values', 'NNS'),
#   ('(', '('),
#   ('where', 'WRB'),
#   ('the', 'DT'),
#   ('return', 'NN'),
#   ('type', 'NN'),
#   ('is', 'VBZ'),
#   ('not', 'RB'),
#   ('void', 'JJ'),
#   (')', ')'),
#   ('is', 'VBZ'),
#   ('not', 'RB'),
#   ('like', 'IN'),
#   ('issuing', 'VBG'),
#   ('a', 'DT'),
#   ('command', 'NN'),
#   (',', ','),
#   ('but', 'CC'),
#   ('asking', 'VBG'),
#   ('a', 'DT'),
#   ('question', 'NN'),
#   ('.', '.')],
# ...
#   ('only', 'RB'),
#   ('if', 'IN'),
#   ('the', 'DT'),
#   ('condition', 'NN'),
#   ('is', 'VBZ'),
#   ('true', 'JJ'),
#   ('.', '.')],
#  [('There', 'EX'),
#   ('can', 'MD'),
#   ('be', 'VB'),
#   ('one', 'CD'),
#   ('or', 'CC'),
#   ('more', 'JJR'),
#   ('instructions', 'NNS'),
#   ('.', '.')],
#  [('If', 'IN'),
#   ('the', 'DT'),
#   ('condition', 'NN'),
#   ('is', 'VBZ'),
#   ('false', 'JJ'),
#   (',', ','),
#   ('the', 'DT'),
#   ('instructions', 'NNS'),
#   ('are', 'VBP'),
#   ('just', 'RB'),
#   ('skipped', 'VBN'),
#   (',', ','),
#   ('and', 'CC'),
#   ('execution', 'NN'),
#   ('continues', 'VBZ'),
#   ('under', 'IN'),
#   ('the', 'DT'),
#   ('closing', 'NN'),
#   ('curly', 'JJ'),
#   ('bracket', 'NN'),
#   ('of', 'IN'),
#   ('the', 'DT'),
#   ('if-statement', 'NN'),
#   ('.', '.')],
#  [('Note', 'NN'),
#   ('that', 'IN'),
#   ('our', 'PRP$'),
#   ('move', 'NN'),
#   ('(', '('),
#   (')', ')'),
#   ('method', 'NN'),
#   ('call', 'NN'),
#   ('is', 'VBZ'),
#   ('outside', 'IN'),
#   ('the', 'DT'),
#   ('if-statement', 'JJ'),
#   (',', ','),
#   ('so', 'IN'),
#   ('it', 'PRP'),
#   ('will', 'MD'),
#   ('be', 'VB'),
#   ('executed', 'VBN'),
#   ('in', 'IN'),
#   ('any', 'DT'),
#   ('case', 'NN'),
#   ('.', '.')],
#  [('In', 'IN'),
#   ('other', 'JJ'),
#   ('words', 'NNS'),
#   (':', ':'),
#   ('If', 'IN'),
#   ('we', 'PRP'),
#   ('are', 'VBP'),
#   ('at', 'IN'),
#   ('the', 'DT'),
#   ('edge', 'NN'),
#   ('of', 'IN'),
#   ('the', 'DT'),
#   ('world', 'NN'),
#   (',', ','),
#   ('we', 'PRP'),
#   ('turn', 'VBP'),
#   ('and', 'CC'),
#   ('then', 'RB'),
#   ('move', 'VB'),
#   (';', ':'),
#   ('if', 'IN'),
#   ('we', 'PRP'),
#   ('are', 'VBP'),
#   ('not', 'RB'),
#   ('at', 'IN'),
#   ('the', 'DT'),
#   ('edge', 'NN'),
#   ('of', 'IN'),
#   ('the', 'DT'),
#   ('world', 'NN'),
#   (',', ','),
#   ('we', 'PRP'),
#   ('just', 'RB'),
#   ('move', 'VB'),
#   ('.', '.')],
#  [('We', 'PRP'),
#   ('can', 'MD'),
#   ('now', 'RB'),
#   ('combine', 'VB'),
#   ('this', 'DT'),
#   ('method', 'NN'),
#   ('with', 'IN'),
#   ('an', 'DT'),
#   ('if-statement', 'JJ'),
#   ('to', 'TO'),
#   ('write', 'VB'),
#   ('the', 'DT'),
#   ('code', 'NN'),
#   ('shown', 'VBN'),
#   ('in', 'IN'),
#   ('Code', 'NNP'),
#   ('2.3', 'CD'),
#   ('.', '.')],
#  [('2.5', 'CD'),
#   ('Summary', 'NNP'),
#   ('of', 'IN'),
#   ('programming', 'VBG'),
#   ('techniques', 'NNS'),
#   ('|', '$'),
#   ('25', 'CD'),
#   ('Exercise', 'NNP'),
#   ('2.12', 'CD'),
#   ('Try', 'NNP'),
#   ('it', 'PRP'),
#   ('out', 'RP'),
#   ('!', '.')],
#  [('Type', 'NN'),
#   ('in', 'IN'),
#   ('the', 'DT'),
#   ('code', 'NN'),
#   ('discussed', 'VBN'),
#   ('above', 'IN'),
#   ('and', 'CC'),
#   ('see', 'VB'),
#   ('if', 'IN'),
#   ('you', 'PRP'),
#   ('can', 'MD'),
#   ('make', 'VB'),
#   ('your', 'PRP$'),
#   ('crabs', 'NN'),
#   ('turn', 'NN'),
#   ('at', 'IN'),
#   ('the', 'DT'),
#   ('edge', 'NN'),
#   ('of', 'IN'),
#   ('the', 'DT'),
#   ('screen', 'NN'),
#   ('.', '.')],
#  [('Pay', 'NNP'),
#   ('close', 'JJ'),
#   ('attention', 'NN'),
#   ('to', 'TO'),
#   ('the', 'DT'),
#   ('opening', 'NN'),
#   ('and', 'CC'),
#   ('closing', 'NN'),
#   ('brackets—it', 'NN'),
#   ('is', 'VBZ'),
#   ('easy', 'JJ'),
#   ('to', 'TO'),
#   ('miss', 'VB'),
#   ('one', 'CD'),
#   ('or', 'CC'),
#   ('have', 'VB'),
#   ('too', 'RB'),
#   ('many', 'JJ'),
#   ('.', '.')],
#  [('Exercise', 'NN'),
#   ('2.13', 'CD'),
#   ('Experiment', 'NN'),
#   ('with', 'IN'),
#   ('different', 'JJ'),
#   ('values', 'NNS'),
#   ('for', 'IN'),
#   ('the', 'DT'),
#   ('parameter', 'NN'),
#   ('to', 'TO'),
#   ('the', 'DT'),
#   ('turn', 'NN'),
#   ('method', 'NN'),
#   ('.', '.')],
#  [('Find', 'VB'),
#   ('one', 'NN'),
#   ('that', 'WDT'),
#   ('looks', 'VBZ'),
#   ('good', 'JJ'),
#   ('.', '.')],
#  [('Exercise', 'NN'),
#   ('2.14', 'CD'),
#   ('Place', 'NN'),
#   ('the', 'DT'),
#   ('move', 'NN'),
#   ('(', '('),
#   (')', ')'),
#   ('statement', 'NN'),
#   ('inside', 'IN'),
#   ('the', 'DT'),
#   ('if-statement', 'JJ'),
#   (',', ','),
#   ('rather', 'RB'),
#   ('than', 'IN'),
#   ('after', 'IN'),
#   ('it', 'PRP'),
#   ('.', '.')],
#  [('Find', 'VB'),
#   ('out', 'RP'),
#   ('what', 'WP'),
#   ('is', 'VBZ'),
#   ('the', 'DT'),
#   ('effect', 'NN'),
#   ('and', 'CC'),
#   ('explain', 'VB'),
#   ('the', 'DT'),
#   ('behavior', 'NN'),
#   ('you', 'PRP'),
#   ('observe', 'VBP'),
#   ('.', '.')],
#  [('(', '('),
#   ('Then', 'RB'),
#   (',', ','),
#   ('fix', 'VB'),
#   ('it', 'PRP'),
#   ('again', 'RB'),
#   ('by', 'IN'),
#   ('moving', 'VBG'),
#   ('it', 'PRP'),
#   ('back', 'RB'),
#   ('where', 'WRB'),
#   ('it', 'PRP'),
#   ('was', 'VBD'),
#   ('.', '.'),
#   (')', ')')],
#  [('Tip', 'NN'),
#   (':', ':'),
#   ('In', 'IN'),
#   ('the', 'DT'),
#   ('Greenfoot', 'NNP'),
#   ('editor', 'NN'),
#   (',', ','),
#   ('when', 'WRB'),
#   ('you', 'PRP'),
#   ('place', 'VBP'),
#   ('the', 'DT'),
#   ('cursor', 'NN'),
#   ('behind', 'IN'),
#   ('an', 'DT'),
#   ('opening', 'NN'),
#   ('or', 'CC'),
#   ('closing', 'NN'),
#   ('bracket', 'NN'),
#   (',', ','),
#   ('Greenfoot', 'NNP'),
#   ('will', 'MD'),
#   ('mark', 'VB'),
#   ('the', 'DT'),
#   ('matching', 'VBG'),
#   ('closing', 'NN'),
#   ('or', 'CC'),
#   ('opening', 'VBG'),
#   ('bracket', 'NN'),
#   ('.', '.')],
#  [('This', 'DT'),
#   ('can', 'MD'),
#   ('be', 'VB'),
#   ('used', 'VBN'),
#   ('to', 'TO'),
#   ('check', 'VB'),
#   ('whether', 'IN'),
#   ('your', 'PRP$'),
#   ('brackets', 'NNS'),
#   ('match', 'VBP'),
#   ('up', 'RP'),
#   ('as', 'IN'),
#   ('they', 'PRP'),
#   ('should', 'MD'),
#   ('.', '.')],
#  [('Note', 'NN'),
#   (':', ':'),
#   ('Indentation', 'NN'),
#   ('In', 'IN'),
#   ('all', 'PDT'),
#   ('the', 'DT'),
#   ('code', 'NN'),
#   ('examples', 'VBZ'),
#   ('you', 'PRP'),
#   ('have', 'VBP'),
#   ('seen', 'VBN'),
#   ('so', 'RB'),
#   ('far', 'RB'),
#   ('(', '('),
#   ('for', 'IN'),
#   ('instance', 'NN'),
#   (',', ','),
#   ('Code', 'NNP'),
#   ('2.3', 'CD'),
#   (')', ')'),
#   (',', ','),
#   ('you', 'PRP'),
#   ('may', 'MD'),
#   ('have', 'VB'),
#   ('noticed', 'VBN'),
#   ('some', 'DT'),
#   ('careful', 'JJ'),
#   ('indentation', 'NN'),
#   ('being', 'VBG'),
#   ('used', 'VBN'),
#   ('.', '.')],
#  [('Every', 'DT'),
#   ('time', 'NN'),
#   ('a', 'DT'),
#   ('curly', 'JJ'),
#   ('bracket', 'NN'),
#   ('opens', 'NNS'),
#   (',', ','),
#   ('the', 'DT'),
#   ('following', 'JJ'),
#   ('lines', 'NNS'),
#   ('are', 'VBP'),
#   ('indented', 'JJ'),
#   ('one', 'CD'),
#   ('level', 'NN'),
#   ('more', 'JJR'),
#   ('than', 'IN'),
#   ('the', 'DT'),
#   ('previous', 'JJ'),
#   ('ones', 'NNS'),
#   ('.', '.')],
#  [('When', 'WRB'),
#   ('a', 'DT'),
#   ('curly', 'RB'),
#   ('bracket', 'NN'),
#   ('closes', 'NNS'),
#   (',', ','),
#   ('the', 'DT'),
#   ('indentation', 'NN'),
#   ('goes', 'VBZ'),
#   ('back', 'RB'),
#   ('one', 'CD'),
#   ('level', 'NN'),
#   (',', ','),
#   ('so', 'IN'),
#   ('that', 'IN'),
#   ('the', 'DT'),
#   ('closing', 'NN'),
#   ('curly', 'JJ'),
#   ('bracket', 'NN'),
#   ('is', 'VBZ'),
#   ('directly', 'RB'),
#   ('below', 'IN'),
#   ('the', 'DT'),
#   ('matching', 'VBG'),
#   ('opening', 'NN'),
#   ('bracket', 'NN'),
#   ('.', '.')],
#  [('This', 'DT'),
#   ('makes', 'VBZ'),
#   ('it', 'PRP'),
#   ('easy', 'JJ'),
#   ('to', 'TO'),
#   ('find', 'VB'),
#   ('the', 'DT'),
#   ('matching', 'NN'),
#   ('bracket', 'NN'),
#   ('.', '.')],
#  [('We', 'PRP'),
#   ('use', 'VBP'),
#   ('four', 'CD'),
#   ('spaces', 'NNS'),
#   ('for', 'IN'),
#   ('one', 'CD'),
#   ('level', 'NN'),
#   ('of', 'IN'),
#   ('indentation', 'NN'),
#   ('.', '.')],
#  [('The', 'DT'),
#   ('Tab', 'NNP'),
#   ('key', 'NN'),
#   ('will', 'MD'),
#   ('insert', 'VB'),
#   ('spaces', 'NNS'),
#   ('in', 'IN'),
#   ('your', 'PRP$'),
#   ('editor', 'NN'),
#   ('for', 'IN'),
#   ('one', 'CD'),
#   ('level', 'NN'),
#   ('of', 'IN'),
#   ('indentation', 'NN'),
#   ('as', 'IN'),
#   ('well', 'RB'),
#   ('.', '.')],
#  [('Taking', 'VBG'),
#   ('care', 'NN'),
#   ('with', 'IN'),
#   ('indentation', 'NN'),
#   ('in', 'IN'),
#   ('your', 'PRP$'),
#   ('own', 'JJ'),
#   ('code', 'NN'),
#   ('is', 'VBZ'),
#   ('very', 'RB'),
#   ('important', 'JJ'),
#   ('.', '.')],
#  [('If', 'IN'),
#   ('you', 'PRP'),
#   ('do', 'VBP'),
#   ('not', 'RB'),
#   ('indent', 'VB'),
#   ('carefully', 'RB'),
#   (',', ','),
#   ('some', 'DT'),
#   ('errors', 'NNS'),
#   ('(', '('),
#   ('particularly', 'RB'),
#   ('misplaced', 'VBN'),
#   ('or', 'CC'),
#   ('mismatched', 'VBN'),
#   ('curly', 'JJ'),
#   ('brackets', 'NNS'),
#   (')', ')'),
#   ('are', 'VBP'),
#   ('very', 'RB'),
#   ('hard', 'JJ'),
#   ('to', 'TO'),
#   ('spot', 'VB'),
#   ('.', '.')],
#  [('Proper', 'JJ'),
#   ('indentation', 'NN'),
#   ('makes', 'VBZ'),
#   ('code', 'RB'),
#   ('much', 'JJ'),
#   ('easier', 'JJR'),
#   ('to', 'TO'),
#   ('read', 'VB'),
#   (',', ','),
#   ('and', 'CC'),
#   ('thus', 'RB'),
#   ('avoid', 'VB'),
#   ('potential', 'JJ'),
#   ('errors', 'NNS'),
#   ('.', '.')],
#  [('2.5', 'CD'),
#   ('Summary', 'NNP'),
#   ('of', 'IN'),
#   ('programming', 'VBG'),
#   ('techniques', 'NNS'),
#   ('In', 'IN'),
#   ('this', 'DT'),
#   ('book', 'NN'),
#   (',', ','),
#   ('we', 'PRP'),
#   ('are', 'VBP'),
#   ('discussing', 'VBG'),
#   ('programming', 'VBG'),
#   ('from', 'IN'),
#   ('a', 'DT'),
#   ('very', 'RB'),
#   ('example-driven', 'JJ'),
#   ('perspective', 'NN'),
#   ('.', '.')],
#  [('We', 'PRP'),
#   ('introduce', 'VBP'),
#   ('general', 'JJ'),
#   ('programming', 'NN'),
#   ('techniques', 'NNS'),
#   ('as', 'IN'),
#   ('we', 'PRP'),
#   ('need', 'VBP'),
#   ('them', 'PRP'),
#   ('to', 'TO'),
#   ('improve', 'VB'),
#   ('our', 'PRP$'),
#   ('scenarios', 'NNS'),
#   ('.', '.')],
#  [('We', 'PRP'),
#   ('shall', 'MD'),
#   ('summarize', 'VB'),
#   ('the', 'DT'),
#   ('important', 'JJ'),
#   ('programming', 'NN'),
#   ('techniques', 'NNS'),
#   ('at', 'IN'),
#   ('the', 'DT'),
#   ('end', 'NN'),
#   ('of', 'IN'),
#   ('each', 'DT'),
#   ('chapter', 'NN'),
#   ('to', 'TO'),
#   ('make', 'VB'),
#   ('it', 'PRP'),
#   ('clear', 'JJ'),
#   ('what', 'WP'),
#   ('you', 'PRP'),
#   ('really', 'RB'),
#   ('need', 'VB'),
#   ('to', 'TO'),
#   ('take', 'VB'),
#   ('away', 'RP'),
#   ('from', 'IN'),
#   ('the', 'DT'),
#   ('discussion', 'NN'),
#   ('in', 'IN'),
#   ('order', 'NN'),
#   ('to', 'TO'),
#   ('progress', 'VB'),
#   ('well', 'RB'),
#   ('.', '.')],
#  [('In', 'IN'),
#   ('this', 'DT'),
#   ('chapter', 'NN'),
#   (',', ','),
#   ('we', 'PRP'),
#   ('have', 'VBP'),
#   ('seen', 'VBN'),
#   ('how', 'WRB'),
#   ('to', 'TO'),
#   ('call', 'VB'),
#   ('methods', 'NNS'),
#   ('(', '('),
#   ('such', 'JJ'),
#   ('as', 'IN'),
#   ('move', 'NN'),
#   ('(', '('),
#   (')', ')'),
#   (')', ')'),
#   (',', ','),
#   ('with', 'IN'),
#   ('and', 'CC'),
#   ('without', 'IN'),
#   ('parameters', 'NNS'),
#   ('.', '.')],
#  [('This', 'DT'),
#   ('will', 'MD'),
#   ('form', 'VB'),
#   ('the', 'DT'),
#   ('basis', 'NN'),
#   ('for', 'IN'),
#   ('all', 'DT'),
#   ('further', 'JJ'),
#   ('Java', 'NNP'),
#   ('programming', 'NN'),
#   ('.', '.')],
#  [('We', 'PRP'),
#   ('have', 'VBP'),
#   ('also', 'RB'),
#   ('learnt', 'VBN'),
#   ('to', 'TO'),
#   ('identify', 'VB'),
#   ('the', 'DT'),
#   ('body', 'NN'),
#   ('of', 'IN'),
#   ('the', 'DT'),
#   ('act', 'NN'),
#   ('method—this', 'NN'),
#   ('is', 'VBZ'),
#   ('where', 'WRB'),
#   ('we', 'PRP'),
#   ('start', 'VBP'),
#   ('writing', 'VBG'),
#   ('our', 'PRP$'),
#   ('instructions', 'NNS'),
#   ('.', '.')],
#  [('You', 'PRP'),
#   ('have', 'VBP'),
#   ('encountered', 'VBN'),
#   ('some', 'DT'),
#   ('error', 'NN'),
#   ('messages', 'NNS'),
#   ('.', '.')],
#  [('This', 'DT'),
#   ('will', 'MD'),
#   ('continue', 'VB'),
#   ('throughout', 'IN'),
#   ('all', 'DT'),
#   ('your', 'PRP$'),
#   ('programming', 'NN'),
#   ('endeavors', 'NNS'),
#   ('.', '.')],
#  [('We', 'PRP'),
#   ('all', 'DT'),
#   ('make', 'VBP'),
#   ('mistakes', 'NNS'),
#   (',', ','),
#   ('and', 'CC'),
#   ('we', 'PRP'),
#   ('all', 'DT'),
#   ('encounter', 'VBP'),
#   ('error', 'NN'),
#   ('messages', 'NNS'),
#   ('.', '.')],
#  [('This', 'DT'),
#   ('is', 'VBZ'),
#   ('not', 'RB'),
#   ('a', 'DT'),
#   ('sign', 'NN'),
#   ('of', 'IN'),
#   ('a', 'DT'),
#   ('bad', 'JJ'),
#   ('programmer—it', 'NN'),
#   ('is', 'VBZ'),
#   ('a', 'DT'),
#   ('normal', 'JJ'),
#   ('part', 'NN'),
#   ('of', 'IN'),
#   ('programming', 'NN'),
#   ('.', '.')],
#  [('We', 'PRP'),
#   ('have', 'VBP'),
#   ('encountered', 'VBN'),
#   ('a', 'DT'),
#   ('first', 'JJ'),
#   ('glimpse', 'NN'),
#   ('of', 'IN'),
#   ('inheritance', 'NN'),
#   (':', ':'),
#   ('Classes', 'NNS'),
#   ('inherit', 'VBP'),
#   ('the', 'DT'),
#   ('methods', 'NNS'),
#   ('from', 'IN'),
#   ('their', 'PRP$'),
#   ('superclasses', 'NNS'),
#   ('.', '.')],
#  [('The', 'DT'),
#   ('Documentation', 'NNP'),
#   ('view', 'NN'),
#   ('of', 'IN'),
#   ('a', 'DT'),
#   ('class', 'NN'),
#   ('gives', 'VBZ'),
#   ('us', 'PRP'),
#   ('a', 'DT'),
#   ('summary', 'NN'),
#   ('of', 'IN'),
#   ('the', 'DT'),
#   ('methods', 'NNS'),
#   ('available', 'JJ'),
#   ('.', '.')],
#  [('And', 'CC'),
#   (',', ','),
#   ('very', 'RB'),
#   ('importantly', 'RB'),
#   (',', ','),
#   ('we', 'PRP'),
#   ('have', 'VBP'),
#   ('seen', 'VBN'),
#   ('how', 'WRB'),
#   ('to', 'TO'),
#   ('make', 'VB'),
#   ('decisions', 'NNS'),
#   (':', ':'),
#   ('We', 'PRP'),
#   ('have', 'VBP'),
#   ('used', 'VBN'),
#   ('an', 'DT'),
#   ('if-statement', 'JJ'),
#   ('for', 'IN'),
#   ('conditional', 'JJ'),
#   ('execution', 'NN'),
#   ('.', '.')],
#  [('This', 'DT'),
#   ('went', 'VBD'),
#   ('hand', 'NN'),
#   ('in', 'IN'),
#   ('hand', 'NN'),
#   ('with', 'IN'),
#   ('the', 'DT'),
#   ('appearance', 'NN'),
#   ('of', 'IN'),
#   ('the', 'DT'),
#   ('type', 'NN'),
#   ('boolean', 'NN'),
#   (',', ','),
#   ('a', 'DT'),
#   ('value', 'NN'),
#   ('that', 'WDT'),
#   ('can', 'MD'),
#   ('be', 'VB'),
#   ('true', 'JJ'),
#   ('or', 'CC'),
#   ('false', 'JJ'),
#   ('.', '.')],
#  [('26', 'CD'),
#   ('|', 'JJ'),
#   ('Chapter', 'NN'),
#   ('2', 'CD'),
#   ('■', 'IN'),
#   ('The', 'DT'),
#   ('first', 'JJ'),
#   ('program', 'NN'),
#   (':', ':'),
#   ('Little', 'JJ'),
#   ('Crab', 'NNP'),
#   ('Concept', 'NNP'),
#   ('summary', 'JJ'),
#   ('■', 'VBD'),
#   ('A', 'DT'),
#   ('method', 'NN'),
#   ('call', 'NN'),
#   ('is', 'VBZ'),
#   ('an', 'DT'),
#   ('instruction', 'NN'),
#   ('that', 'WDT'),
#   ('tells', 'VBZ'),
#   ('an', 'DT'),
#   ('object', 'NN'),
#   ('to', 'TO'),
#   ('perform', 'VB'),
#   ('an', 'DT'),
#   ('action', 'NN'),
#   ('.', '.')],
#  [('The', 'DT'),
#   ('action', 'NN'),
#   ('is', 'VBZ'),
#   ('defined', 'VBN'),
#   ('by', 'IN'),
#   ('a', 'DT'),
#   ('method', 'NN'),
#   ('of', 'IN'),
#   ('the', 'DT'),
#   ('object', 'NN'),
#   ('.', '.')],
#  [('■', 'JJ'),
#   ('Additional', 'NNP'),
#   ('information', 'NN'),
#   ('can', 'MD'),
#   ('be', 'VB'),
#   ('passed', 'VBN'),
#   ('to', 'TO'),
#   ('some', 'DT'),
#   ('methods', 'NNS'),
#   ('within', 'IN'),
#   ('the', 'DT'),
#   ('parentheses', 'NNS'),
#   ('.', '.')],
#  [('The', 'DT'),
#   ('value', 'NN'),
#   ('passed', 'VBN'),
#   ('is', 'VBZ'),
#   ('called', 'VBN'),
#   ('a', 'DT'),
#   ('parameter', 'NN'),
#   ('.', '.')],
#  [('■', 'JJ'),
#   ('Multiple', 'NNP'),
#   ('instructions', 'NNS'),
#   ('are', 'VBP'),
#   ('executed', 'VBN'),
#   ('in', 'IN'),
#   ('sequence', 'NN'),
#   (',', ','),
#   ('one', 'CD'),
#   ('after', 'IN'),
#   ('the', 'DT'),
#   ('other', 'JJ'),
#   (',', ','),
#   ('in', 'IN'),
#   ('the', 'DT'),
#   ('order', 'NN'),
#   ('in', 'IN'),
#   ('which', 'WDT'),
#   ('they', 'PRP'),
#   ('are', 'VBP'),
#   ('written', 'VBN'),
#   ('.', '.')],
#  [('■', 'NN'),
#   ('When', 'WRB'),
#   ('a', 'DT'),
#   ('class', 'NN'),
#   ('is', 'VBZ'),
#   ('compiled', 'VBN'),
#   (',', ','),
#   ('the', 'DT'),
#   ('compiler', 'NN'),
#   ('checks', 'NNS'),
#   ('to', 'TO'),
#   ('see', 'VB'),
#   ('whether', 'IN'),
#   ('there', 'EX'),
#   ('are', 'VBP'),
#   ('any', 'DT'),
#   ('errors', 'NNS'),
#   ('.', '.')],
#  [('If', 'IN'),
#   ('an', 'DT'),
#   ('error', 'NN'),
#   ('is', 'VBZ'),
#   ('found', 'VBN'),
#   (',', ','),
#   ('an', 'DT'),
#   ('error', 'NN'),
#   ('message', 'NN'),
#   ('is', 'VBZ'),
#   ('displayed', 'VBN'),
#   ('.', '.')],
#  [('■', 'VB'),
#   ('A', 'NNP'),
#   ('subclass', 'NN'),
#   ('inherits', 'VBZ'),
#   ('all', 'PDT'),
#   ('the', 'DT'),
#   ('methods', 'NNS'),
#   ('from', 'IN'),
#   ('its', 'PRP$'),
#   ('superclass', 'NN'),
#   ('.', '.')],
#  [('That', 'DT'),
#   ('means', 'VBZ'),
#   ('that', 'IN'),
#   ('it', 'PRP'),
#   ('has', 'VBZ'),
#   (',', ','),
#   ('and', 'CC'),
#   ('can', 'MD'),
#   ('use', 'VB'),
#   (',', ','),
#   ('all', 'DT'),
#   ('methods', 'NNS'),
#   ('that', 'IN'),
#   ('its', 'PRP$'),
#   ('superclass', 'NN'),
#   ('defines', 'NNS'),
#   ('.', '.')],
#  [('■', 'NN'),
#   ('Calling', 'VBG'),
#   ('a', 'DT'),
#   ('method', 'NN'),
#   ('with', 'IN'),
#   ('a', 'DT'),
#   ('void', 'JJ'),
#   ('return', 'NN'),
#   ('type', 'NN'),
#   ('issues', 'NNS'),
#   ('a', 'DT'),
#   ('command', 'NN'),
#   ('.', '.')],
#  [('Calling', 'VBG'),
#   ('a', 'DT'),
#   ('method', 'NN'),
#   ('with', 'IN'),
#   ('a', 'DT'),
#   ('non-void', 'JJ'),
#   ('return', 'NN'),
#   ('type', 'NN'),
#   ('asks', 'VBZ'),
#   ('a', 'DT'),
#   ('question', 'NN'),
#   ('.', '.')],
#  [('■', 'VB'),
#   ('An', 'DT'),
#   ('if-statement', 'JJ'),
#   ('can', 'MD'),
#   ('be', 'VB'),
#   ('used', 'VBN'),
#   ('to', 'TO'),
#   ('write', 'VB'),
#   ('instructions', 'NNS'),
#   ('that', 'WDT'),
#   ('are', 'VBP'),
#   ('executed', 'VBN'),
#   ('only', 'RB'),
#   ('when', 'WRB'),
#   ('a', 'DT'),
#   ('certain', 'JJ'),
#   ('condition', 'NN'),
#   ('is', 'VBZ'),
#   ('true', 'JJ'),
#   ('.', '.')]]

# %%
grammar = "NP: {<DT>?<JJ>*<NN>}"
cp = nltk.RegexpParser(grammar)
for s in sentences:
    result = cp.parse(s)
    print(result)
# Out:
# (S
#   ﻿CHAPTER/RB
#   2/CD
#   (NP The/DT first/JJ program/NN)
#   :/:
#   Little/JJ
#   Crab/JJ
#   topics/NNS
#   :/:
#   writing/VBG
#   (NP code/NN)
#   :/:
#   (NP movement/NN)
#   ,/,
#   turning/VBG
#   ,/,
#   reacting/VBG
#   to/TO
#   (NP the/DT screen/NN)
#   edges/VBZ
#   concepts/NNS
#   :/:
#   (NP source/NN)
#   (NP code/NN)
#   ,/,
#   (NP method/NN)
#   (NP call/NN)
#   ,/,
#   (NP parameter/NN)
#   ,/,
#   (NP sequence/NN)
#   ,/,
#   (NP if-statement/JJ Exercise/NN)
#   2.1/CD
#   Start/NNP
#   Greenfoot/NNP
#   and/CC
#   open/VB
#   (NP the/DT little-crab/JJ scenario/NN)
#   ./.)
# (S
#   (NP Place/NN)
#   (NP a/DT crab/NN)
#   into/IN
#   (NP the/DT world/NN)
#   and/CC
#   run/VB
#   (NP the/DT program/NN)
#   (/(
#   click/VB
#   the/DT
#   Run/NNP
#   (NP button/NN)
#   )/)
#   ./.)
# (S What/WP do/VBP you/PRP observe/VB ?/.)
# (S
#   (/(
#   Remember/VB
#   :/:
#   If/IN
#   (NP the/DT class/NN)
#   icons/NNS
#   on/IN
#   (NP the/DT right/JJ appear/NN)
#   striped/VBD
#   ,/,
#   you/PRP
#   have/VBP
#   to/TO
#   compile/VB
#   (NP the/DT project/NN)
#   first/RB
#   ./.
#   )/))
# (S
#   On/IN
#   (NP the/DT right/NN)
#   ,/,
#   you/PRP
#   see/VBP
#   the/DT
#   classes/NNS
#   in/IN
#   (NP this/DT scenario/NN)
#   (/(
#   Figure/NNP
#   2.2/CD
#   )/)
#   ./.)
# (S
#   We/PRP
#   notice/VBP
#   that/IN
#   there/EX
#   is/VBZ
#   the/DT
#   usual/JJ
#   Greenfoot/NNP
#   Actor/NNP
#   (NP class/NN)
#   ,/,
#   (NP a/DT class/NN)
#   called/VBN
#   Animal/NNP
#   ,/,
#   and/CC
#   the/DT
#   Crab/NNP
#   (NP class/NN)
#   ./.)
# (S
#   (NP The/DT hierarchy/NN)
#   (/(
#   denoted/VBN
#   by/IN
#   the/DT
#   arrows/NNS
#   )/)
#   indicates/VBZ
#   (NP an/DT is-a/JJ relationship/NN)
#   (/(
#   also/RB
#   called/VBN
#   (NP inheritance/NN)
#   )/)
#   :/:
#   (NP A/DT crab/NN)
#   is/VBZ
#   (NP an/DT animal/NN)
#   ,/,
#   and/CC
#   (NP an/DT animal/NN)
#   is/VBZ
#   (NP an/DT actor/NN)
#   ./.)
# (S
#   (/(
#   It/PRP
#   follows/VBZ
#   then/RB
#   ,/,
#   that/IN
#   (NP a/DT crab/NN)
#   also/RB
#   is/VBZ
#   (NP an/DT actor/NN)
#   ./.
#   )/))
# (S
#   Initially/RB
#   ,/,
#   we/PRP
#   will/MD
#   work/VB
#   only/RB
#   with/IN
#   the/DT
#   Crab/NNP
#   (NP class/NN)
#   ./.)
# (S
#   We/PRP
#   will/MD
#   talk/VB
#   a/DT
#   little/RB
#   more/RBR
#   about/IN
#   the/DT
#   Actor/NNP
#   and/CC
#   Animal/NNP
#   classes/NNS
#   later/RB
#   on/IN
#   ./.)
# (S
#   If/IN
#   you/PRP
#   have/VBP
#   done/VBN
#   (NP the/DT exercise/NN)
#   above/IN
#   ,/,
#   then/RB
#   you/PRP
#   know/VBP
#   (NP the/DT answer/NN)
#   to/TO
#   (NP the/DT question/NN)
#   “What/WP
#   do/VBP
#   you/PRP
#   observe/VB
#   ?/.
#   ”/VB
#   It/PRP
#   is/VBZ
#   :/:
#   (NP “nothing”/NN)
#   ./.)
# (S
#   2.1/CD
#   The/DT
#   Little/JJ
#   Crab/NNP
#   (NP scenario/NN)
#   |/VBZ
#   17/CD
#   (NP Figure/NN)
#   2.1/CD
#   The/DT
#   Little/JJ
#   Crab/NNP
#   (NP scenario/NN)
#   Figure/NNP
#   2.2/CD
#   The/DT
#   Little/NNP
#   Crab/NNP
#   (NP actor/NN)
#   classes/VBZ
#   (NP The/DT crab/NN)
#   does/VBZ
#   not/RB
#   do/VB
#   (NP anything/NN)
#   when/WRB
#   Greenfoot/NNP
#   runs/VBZ
#   ./.)
# (S
#   This/DT
#   is/VBZ
#   because/IN
#   there/EX
#   is/VBZ
#   (NP no/DT source/NN)
#   (NP code/NN)
#   in/IN
#   (NP the/DT definition/NN)
#   of/IN
#   the/DT
#   Crab/NNP
#   (NP class/NN)
#   that/WDT
#   specifies/VBZ
#   what/WP
#   (NP the/DT crab/NN)
#   should/MD
#   do/VB
#   ./.)
# (S
#   In/IN
#   (NP this/DT chapter/NN)
#   ,/,
#   we/PRP
#   shall/MD
#   work/VB
#   on/IN
#   changing/VBG
#   this/DT
#   ./.)
# (S
#   (NP The/DT first/JJ thing/NN)
#   we/PRP
#   shall/MD
#   do/VB
#   is/VBZ
#   to/TO
#   make/VB
#   (NP the/DT crab/NN)
#   (NP move/NN)
#   ./.)
# (S
#   2.2/CD
#   Making/VBG
#   (NP the/DT crab/NN)
#   (NP move/NN)
#   Let/NNP
#   us/PRP
#   have/VB
#   (NP a/DT look/NN)
#   at/IN
#   (NP the/DT source/NN)
#   (NP code/NN)
#   of/IN
#   (NP class/NN)
#   Crab/NNP
#   ./.)
# (S
#   Open/VB
#   (NP the/DT editor/NN)
#   to/TO
#   display/VB
#   the/DT
#   Crab/NNP
#   (NP source/NN)
#   ./.)
# (S
#   (/(
#   You/PRP
#   can/MD
#   do/VB
#   this/DT
#   by/IN
#   selecting/VBG
#   the/DT
#   Open/NNP
#   (NP editor/NN)
#   (NP function/NN)
#   from/IN
#   (NP the/DT class’s/NN)
#   (NP popup/NN)
#   (NP menu/NN)
#   ,/,
#   or/CC
#   you/PRP
#   can/MD
#   just/RB
#   double-click/VB
#   (NP the/DT class/NN)
#   ./.
#   )/))
# (S
#   (NP The/DT source/NN)
#   (NP code/NN)
#   you/PRP
#   see/VBP
#   is/VBZ
#   shown/VBN
#   in/IN
#   Code/NNP
#   2.1/CD
#   ./.)
# (S
#   18/CD
#   (NP |/JJ Chapter/NN)
#   2/CD
#   ■/IN
#   (NP The/DT first/JJ program/NN)
#   :/:
#   Little/JJ
#   Crab/NNP
#   Code/NNP
#   2.1/CD
#   (NP The/DT original/JJ version/NN)
#   of/IN
#   the/DT
#   Crab/NNP
#   (NP class/NN)
#   (NP import/NN)
#   (NP greenfoot/NN)
#   ./.)
# (S
#   (NP */NN)
#   ;/:
#   ///NNP
#   (/(
#   World/NNP
#   ,/,
#   Actor/NNP
#   ,/,
#   GreenfootImage/NNP
#   ,/,
#   and/CC
#   Greenfoot/NNP
#   )/)
#   /**/VBP
#   */$
#   (NP This/DT class/NN)
#   defines/VBZ
#   (NP a/DT crab/NN)
#   ./.)
# (S Crabs/NNP live/VBP on/IN (NP the/DT beach/NN) ./.)
# (S
#   (NP *//JJ public/JJ class/NN)
#   Crab/NNP
#   extends/VBZ
#   Animal/NNP
#   {/(
#   (NP public/JJ void/NN)
#   (NP act/NN)
#   (/(
#   )/)
#   {/(
#   ///JJ
#   Add/NNP
#   your/PRP$
#   (NP action/NN)
#   (NP code/NN)
#   (NP here./NN)
#   }/))
# (S
#   }/)
#   This/DT
#   is/VBZ
#   a/DT
#   standard/JJ
#   Java/NNP
#   (NP class/NN)
#   (NP definition/NN)
#   ./.)
# (S
#   That/DT
#   is/VBZ
#   ,/,
#   (NP this/DT text/NN)
#   defines/VBZ
#   what/WP
#   (NP the/DT crab/NN)
#   can/MD
#   do/VB
#   ./.)
# (S
#   We/PRP
#   will/MD
#   look/VB
#   at/IN
#   it/PRP
#   in/IN
#   (NP detail/NN)
#   a/DT
#   little/JJ
#   later/RB
#   ./.)
# (S
#   For/IN
#   now/RB
#   ,/,
#   we/PRP
#   will/MD
#   concentrate/VB
#   on/IN
#   getting/VBG
#   (NP the/DT crab/NN)
#   to/TO
#   move/VB
#   ./.)
# (S
#   Within/IN
#   (NP this/DT class/NN)
#   (NP definition/NN)
#   ,/,
#   we/PRP
#   can/MD
#   see/VB
#   what/WP
#   is/VBZ
#   called/VBN
#   (NP the/DT act/NN)
#   (NP method/NN)
#   ./.)
# (S
#   It/PRP
#   looks/VBZ
#   like/IN
#   this/DT
#   :/:
#   (NP public/JJ void/NN)
#   (NP act/NN)
#   (/(
#   )/)
#   {/(
#   ///JJ
#   Add/NNP
#   your/PRP$
#   (NP action/NN)
#   (NP code/NN)
#   (NP here./NN)
#   }/))
# (S
#   (NP The/DT first/JJ line/NN)
#   is/VBZ
#   (NP the/DT signature/NN)
#   of/IN
#   (NP the/DT method/NN)
#   ./.)
# (S
#   The/DT
#   last/JJ
#   three/CD
#   lines—the/VBD
#   two/CD
#   curly/JJ
#   brackets/NNS
#   and/CC
#   (NP anything/NN)
#   between/IN
#   (NP them—is/NN)
#   called/VBN
#   (NP the/DT body/NN)
#   of/IN
#   (NP the/DT method/NN)
#   ./.)
# (S
#   Here/RB
#   ,/,
#   we/PRP
#   can/MD
#   add/VB
#   (NP some/DT code/NN)
#   that/IN
#   determines/VBZ
#   the/DT
#   actions/NNS
#   of/IN
#   (NP the/DT crab/NN)
#   ./.)
# (S
#   We/PRP
#   can/MD
#   replace/VB
#   (NP the/DT gray/JJ text/NN)
#   in/IN
#   (NP the/DT middle/NN)
#   with/IN
#   (NP a/DT command/NN)
#   ./.)
# (S
#   One/CD
#   (NP such/JJ command/NN)
#   is/VBZ
#   move/NNP
#   (/(
#   )/)
#   ;/:
#   Note/CC
#   that/IN
#   it/PRP
#   has/VBZ
#   to/TO
#   be/VB
#   written/VBN
#   exactly/RB
#   as/IN
#   shown/VBN
#   ,/,
#   including/VBG
#   the/DT
#   parentheses/NNS
#   and/CC
#   (NP the/DT semicolon/NN)
#   ./.)
# (S
#   (NP The/DT act/NN)
#   (NP method/NN)
#   should/MD
#   then/RB
#   look/VB
#   like/IN
#   this/DT
#   :/:
#   (NP public/JJ void/NN)
#   (NP act/NN)
#   (/(
#   )/)
#   {/(
#   (NP move/NN)
#   (/(
#   )/)
#   ;/:
#   }/)
#   2.3/CD
#   Turning/VBG
#   |/JJ
#   19/CD
#   (NP Exercise/NN)
#   2.2/CD
#   Change/NNP
#   (NP the/DT act/NN)
#   (NP method/NN)
#   in/IN
#   your/PRP$
#   (NP crab/NN)
#   (NP class/NN)
#   to/TO
#   include/VB
#   (NP the/DT move/NN)
#   (/(
#   )/)
#   (NP instruction/NN)
#   ,/,
#   as/IN
#   shown/VBN
#   above/IN
#   ./.)
# (S
#   Compile/IN
#   (NP the/DT scenario/NN)
#   (/(
#   by/IN
#   clicking/VBG
#   the/DT
#   Compile/NNP
#   All/NNP
#   (NP button/NN)
#   )/)
#   and/CC
#   (NP place/NN)
#   (NP a/DT crab/NN)
#   into/IN
#   (NP the/DT world/NN)
#   ./.)
# (S Try/VB clicking/VBG the/DT Act/NNP and/CC Run/NNP buttons/NNS ./.)
# (S
#   (NP Exercise/NN)
#   2.3/CD
#   (NP Place/NN)
#   (NP multiple/JJ crabs/NN)
#   into/IN
#   (NP the/DT world/NN)
#   ./.)
# (S Run/VB (NP the/DT scenario/NN) ./.)
# (S What/WP do/VBP you/PRP observe/VB ?/.)
# (S
#   (NP Concept/NN)
#   :/:
#   (NP A/DT method/NN)
#   (NP call/NN)
#   is/VBZ
#   (NP an/DT instruction/NN)
#   that/WDT
#   tells/VBZ
#   (NP an/DT object/NN)
#   to/TO
#   perform/VB
#   (NP an/DT action/NN)
#   ./.)
# (S
#   (NP The/DT action/NN)
#   is/VBZ
#   defined/VBN
#   by/IN
#   (NP a/DT method/NN)
#   of/IN
#   (NP the/DT object/NN)
#   ./.)
# (S
#   You/PRP
#   will/MD
#   see/VB
#   that/IN
#   (NP the/DT crab/NN)
#   can/MD
#   now/RB
#   move/VB
#   across/IN
#   (NP the/DT screen/NN)
#   ./.)
# (S
#   (NP The/DT move/NN)
#   (/(
#   )/)
#   (NP instruction/NN)
#   makes/VBZ
#   (NP the/DT crab/JJ move/NN)
#   (NP a/DT little/JJ bit/NN)
#   to/TO
#   (NP the/DT right/NN)
#   ./.)
# (S
#   When/WRB
#   we/PRP
#   click/VBP
#   the/DT
#   Act/NNP
#   (NP button/NN)
#   in/IN
#   the/DT
#   Greenfoot/NNP
#   (NP main/JJ window/NN)
#   ,/,
#   (NP the/DT act/NN)
#   (NP method/NN)
#   is/VBZ
#   executed/VBN
#   once/RB
#   ./.)
# (S
#   That/DT
#   is/VBZ
#   ,/,
#   (NP the/DT instruction/NN)
#   that/IN
#   we/PRP
#   have/VBP
#   written/VBN
#   inside/IN
#   (NP the/DT act/NN)
#   (NP method/NN)
#   (/(
#   move/VB
#   (/(
#   )/)
#   )/)
#   executes/VBZ
#   ./.)
# (S
#   Clicking/VBG
#   the/DT
#   Run/NNP
#   (NP button/NN)
#   is/VBZ
#   just/RB
#   like/IN
#   clicking/VBG
#   the/DT
#   Act/NNP
#   button/VBD
#   several/JJ
#   times/NNS
#   ,/,
#   very/RB
#   quickly/RB
#   ./.)
# (S
#   So/IN
#   (NP the/DT act/NN)
#   (NP method/NN)
#   is/VBZ
#   executed/VBN
#   over/IN
#   and/CC
#   over/RB
#   again/RB
#   ,/,
#   until/IN
#   we/PRP
#   click/VBP
#   Pause/NNP
#   ./.)
# (S
#   Terminology/NNP
#   (NP The/DT instruction/NN)
#   (NP move/NN)
#   (/(
#   )/)
#   is/VBZ
#   called/VBN
#   (NP a/DT method/NN)
#   (NP call/NN)
#   ./.)
# (S
#   (NP A/DT method/NN)
#   is/VBZ
#   (NP an/DT action/NN)
#   that/IN
#   (NP an/DT object/NN)
#   knows/VBZ
#   how/WRB
#   to/TO
#   do/VB
#   (/(
#   here/RB
#   ,/,
#   (NP the/DT object/NN)
#   is/VBZ
#   (NP the/DT crab/NN)
#   )/)
#   and/CC
#   (NP a/DT method/NN)
#   (NP call/NN)
#   is/VBZ
#   (NP an/DT instruction/NN)
#   telling/VBG
#   (NP the/DT crab/NN)
#   to/TO
#   do/VB
#   it/PRP
#   ./.)
# (S
#   The/DT
#   parentheses/NNS
#   are/VBP
#   (NP part/NN)
#   of/IN
#   (NP the/DT method/NN)
#   (NP call/NN)
#   ./.)
# (S
#   Instructions/NNS
#   like/IN
#   (NP this/DT end/NN)
#   with/IN
#   (NP a/DT semicolon/NN)
#   ./.)
# (S
#   (NP Concept/NN)
#   :/:
#   (NP Additional/JJ information/NN)
#   can/MD
#   be/VB
#   passed/VBN
#   to/TO
#   some/DT
#   methods/NNS
#   within/IN
#   the/DT
#   parentheses/NNS
#   ./.)
# (S
#   (NP The/DT value/NN)
#   passed/VBN
#   is/VBZ
#   called/VBN
#   (NP a/DT parameter/NN)
#   ./.)
# (S
#   2.3/CD
#   Turning/VBG
#   Let/VB
#   us/PRP
#   see/VB
#   what/WP
#   other/JJ
#   instructions/NNS
#   we/PRP
#   can/MD
#   use/VB
#   ./.)
# (S
#   (NP The/DT crab/NN)
#   also/RB
#   understands/VBZ
#   (NP a/DT turn/NN)
#   (NP instruction/NN)
#   ./.)
# (S
#   Here/RB
#   is/VBZ
#   what/WP
#   it/PRP
#   looks/VBZ
#   like/IN
#   :/:
#   (NP turn/NN)
#   (/(
#   5/CD
#   )/)
#   ;/:
#   (NP The/DT number/NN)
#   5/CD
#   in/IN
#   (NP the/DT instruction/NN)
#   specifies/VBZ
#   how/WRB
#   many/JJ
#   degrees/VBZ
#   (NP the/DT crab/NN)
#   should/MD
#   turn/VB
#   ./.)
# (S This/DT is/VBZ called/VBN (NP a/DT parameter/NN) ./.)
# (S
#   We/PRP
#   can/MD
#   also/RB
#   use/VB
#   other/JJ
#   numbers/NNS
#   ,/,
#   for/IN
#   (NP example/NN)
#   :/:
#   (NP turn/NN)
#   (/(
#   23/CD
#   )/)
#   ;/:
#   (NP The/DT degree/NN)
#   (NP value/NN)
#   is/VBZ
#   specified/VBN
#   out/IN
#   of/IN
#   360/CD
#   degrees/NNS
#   ,/,
#   so/IN
#   (NP any/DT value/NN)
#   between/IN
#   0/CD
#   and/CC
#   359/CD
#   can/MD
#   be/VB
#   used/VBN
#   ./.)
# (S
#   (/(
#   Turning/VBG
#   360/CD
#   degrees/NNS
#   would/MD
#   turn/VB
#   all/PDT
#   (NP the/DT way/NN)
#   around/IN
#   ,/,
#   so/IN
#   it/PRP
#   is/VBZ
#   the/DT
#   same/JJ
#   as/IN
#   turning/VBG
#   0/CD
#   degrees/NNS
#   ,/,
#   or/CC
#   not/RB
#   turning/VBG
#   at/IN
#   all/DT
#   ./.
#   )/))
# (S
#   If/IN
#   we/PRP
#   want/VBP
#   to/TO
#   turn/VB
#   instead/RB
#   of/IN
#   moving/VBG
#   ,/,
#   we/PRP
#   can/MD
#   replace/VB
#   (NP the/DT move/NN)
#   (/(
#   )/)
#   (NP instruction/NN)
#   with/IN
#   (NP a/DT turn/NN)
#   (/(
#   5/CD
#   )/)
#   (NP instruction/NN)
#   ./.)
# (S
#   (NP The/DT act/NN)
#   (NP method/NN)
#   then/RB
#   looks/VBZ
#   like/IN
#   this/DT
#   :/:
#   (NP public/JJ void/NN)
#   (NP act/NN)
#   (/(
#   )/)
#   {/(
#   (NP turn/NN)
#   (/(
#   5/CD
#   )/)
#   ;/:
#   }/)
#   Exercise/NNP
#   2.4/CD
#   Replace/NNP
#   (NP move/NN)
#   (/(
#   )/)
#   with/IN
#   (NP turn/NN)
#   (/(
#   5/CD
#   )/)
#   in/IN
#   your/PRP$
#   (NP scenario/NN)
#   ./.)
# (S Try/VB it/PRP out/RP ./.)
# (S
#   Also/RB
#   ,/,
#   try/VB
#   values/NNS
#   other/JJ
#   than/IN
#   5/CD
#   and/CC
#   see/VB
#   what/WP
#   it/PRP
#   looks/VBZ
#   like/IN
#   ./.)
# (S
#   Remember/NNP
#   :/:
#   (NP Every/DT time/NN)
#   you/PRP
#   change/VBP
#   your/PRP$
#   (NP source/NN)
#   (NP code/NN)
#   ,/,
#   you/PRP
#   must/MD
#   compile/VB
#   again/RB
#   ./.)
# (S
#   (NP Exercise/NN)
#   2.5/CD
#   How/WRB
#   can/MD
#   you/PRP
#   make/VB
#   (NP the/DT crab/NN)
#   (NP turn/NN)
#   left/VBD
#   ?/.)
# (S
#   (NP Concept/NN)
#   :/:
#   Multiple/JJ
#   instructions/NNS
#   are/VBP
#   executed/VBN
#   in/IN
#   (NP sequence/NN)
#   ,/,
#   one/CD
#   after/IN
#   the/DT
#   other/JJ
#   ,/,
#   in/IN
#   (NP the/DT order/NN)
#   in/IN
#   which/WDT
#   they/PRP
#   are/VBP
#   written/VBN
#   ./.)
# (S
#   20/CD
#   (NP |/JJ Chapter/NN)
#   2/CD
#   ■/IN
#   (NP The/DT first/JJ program/NN)
#   :/:
#   Little/JJ
#   Crab/NNP
#   Code/NNP
#   2.2/CD
#   Making/VBG
#   (NP the/DT crab/NN)
#   (NP move/NN)
#   and/CC
#   (NP turn/NN)
#   (NP import/NN)
#   (NP greenfoot/NN)
#   ./.)
# (S
#   (NP */NN)
#   ;/:
#   ///NNP
#   (/(
#   World/NNP
#   ,/,
#   Actor/NNP
#   ,/,
#   GreenfootImage/NNP
#   ,/,
#   and/CC
#   Greenfoot/NNP
#   )/)
#   /**/VBP
#   */$
#   (NP This/DT class/NN)
#   defines/VBZ
#   (NP a/DT crab/NN)
#   ./.)
# (S Crabs/NNP live/VBP on/IN (NP the/DT beach/NN) ./.)
# (S
#   (NP *//JJ public/JJ class/NN)
#   Crab/NNP
#   extends/VBZ
#   Animal/NNP
#   {/(
#   (NP public/JJ void/NN)
#   (NP act/NN)
#   (/(
#   )/)
#   {/(
#   (NP move/NN)
#   (/(
#   )/)
#   ;/:
#   (NP turn/NN)
#   (/(
#   5/CD
#   )/)
#   ;/:
#   }/)
#   }/)
#   (NP The/DT next/JJ thing/NN)
#   we/PRP
#   can/MD
#   try/VB
#   is/VBZ
#   to/TO
#   (NP both/DT move/NN)
#   and/CC
#   (NP turn/NN)
#   ./.)
# (S
#   (NP The/DT act/NN)
#   (NP method/NN)
#   can/MD
#   hold/VB
#   more/JJR
#   than/IN
#   one/CD
#   (NP instruction—we/NN)
#   can/MD
#   just/RB
#   write/VB
#   multiple/JJ
#   instructions/NNS
#   in/IN
#   (NP a/DT row/NN)
#   ./.)
# (S
#   Code/NNP
#   2.2/CD
#   shows/VBZ
#   the/DT
#   complete/JJ
#   Crab/NNP
#   (NP class/NN)
#   ,/,
#   as/IN
#   it/PRP
#   looks/VBZ
#   when/WRB
#   we/PRP
#   move/VBP
#   and/CC
#   turn/VBP
#   ./.)
# (S
#   In/IN
#   (NP this/DT case/NN)
#   ,/,
#   at/IN
#   (NP every/DT act/JJ step/NN)
#   ,/,
#   (NP the/DT crab/NN)
#   will/MD
#   move/VB
#   and/CC
#   then/RB
#   turn/VB
#   (/(
#   but/CC
#   these/DT
#   actions/NNS
#   will/MD
#   happen/VB
#   so/RB
#   quickly/RB
#   after/IN
#   each/DT
#   other/JJ
#   that/IN
#   it/PRP
#   appears/VBZ
#   as/IN
#   if/IN
#   they/PRP
#   happen/VBP
#   at/IN
#   (NP the/DT same/JJ time/NN)
#   )/)
#   ./.)
# (S
#   (NP Exercise/NN)
#   2.6/CD
#   (NP Use/NN)
#   (NP a/DT move/NN)
#   (/(
#   )/)
#   and/CC
#   (NP turn/NN)
#   (/(
#   N/NNP
#   )/)
#   (NP instruction/NN)
#   in/IN
#   your/PRP$
#   (NP crab’s/NN)
#   (NP act/NN)
#   (NP method/NN)
#   ./.)
# (S
#   Try/VB
#   different/JJ
#   values/NNS
#   for/IN
#   N./NNP
#   Terminology/NNP
#   (NP The/DT number/NN)
#   within/IN
#   the/DT
#   parentheses/NNS
#   in/IN
#   (NP the/DT turn/NN)
#   (NP instruction—that/NN)
#   is/VBZ
#   ,/,
#   the/DT
#   5/CD
#   in/IN
#   (NP turn/NN)
#   (/(
#   5/CD
#   )/)
#   (NP —is/NN)
#   called/VBD
#   (NP a/DT parameter/NN)
#   ./.)
# (S
#   (NP A/DT parameter/NN)
#   is/VBZ
#   (NP an/DT additional/JJ bit/NN)
#   of/IN
#   (NP information/NN)
#   that/IN
#   we/PRP
#   have/VBP
#   to/TO
#   provide/VB
#   when/WRB
#   we/PRP
#   call/VBP
#   some/DT
#   methods/NNS
#   ./.)
# (S
#   Some/DT
#   methods/NNS
#   ,/,
#   like/IN
#   (NP move/NN)
#   ,/,
#   expect/VBP
#   no/DT
#   parameters/NNS
#   ./.)
# (S
#   They/PRP
#   are/VBP
#   happy/JJ
#   to/TO
#   just/RB
#   execute/VB
#   as/RB
#   soon/RB
#   as/IN
#   we/PRP
#   write/VBP
#   (NP the/DT move/NN)
#   (/(
#   )/)
#   (NP instruction/NN)
#   ./.)
# (S
#   Other/JJ
#   methods/NNS
#   ,/,
#   such/JJ
#   as/IN
#   (NP turn/NN)
#   ,/,
#   want/VBP
#   more/JJR
#   (NP information/NN)
#   :/:
#   How/WRB
#   much/JJ
#   should/MD
#   I/PRP
#   turn/VB
#   ?/.)
# (S
#   In/IN
#   (NP this/DT case/NN)
#   ,/,
#   we/PRP
#   have/VBP
#   to/TO
#   provide/VB
#   (NP that/DT information/NN)
#   in/IN
#   (NP the/DT form/NN)
#   of/IN
#   (NP a/DT parameter/NN)
#   (NP value/NN)
#   within/IN
#   the/DT
#   parentheses/NNS
#   ,/,
#   for/IN
#   (NP instance/NN)
#   ,/,
#   (NP turn/NN)
#   (/(
#   17/CD
#   )/)
#   ./.)
# (S
#   2.4/CD
#   Dealing/VBG
#   with/IN
#   screen/JJ
#   edges/NNS
#   |/VBP
#   21/CD
#   (NP Concept/NN)
#   :/:
#   When/WRB
#   (NP a/DT class/NN)
#   is/VBZ
#   compiled/VBN
#   ,/,
#   (NP the/DT compiler/NN)
#   checks/NNS
#   to/TO
#   see/VB
#   whether/IN
#   there/EX
#   are/VBP
#   any/DT
#   errors/NNS
#   ./.)
# (S
#   If/IN
#   (NP an/DT error/NN)
#   is/VBZ
#   found/VBN
#   ,/,
#   (NP an/DT error/NN)
#   (NP message/NN)
#   is/VBZ
#   displayed/VBN
#   ./.)
# (S
#   (NP Side/JJ note/NN)
#   :/:
#   Errors/NNS
#   When/WRB
#   we/PRP
#   write/VBP
#   (NP source/NN)
#   (NP code/NN)
#   ,/,
#   we/PRP
#   have/VBP
#   to/TO
#   be/VB
#   very/RB
#   (NP careful—every/JJ single/JJ character/NN)
#   counts/NNS
#   ./.)
# (S
#   Getting/VBG
#   one/CD
#   (NP small/JJ thing/NN)
#   wrong/JJ
#   will/MD
#   result/VB
#   in/IN
#   our/PRP$
#   (NP program/NN)
#   not/RB
#   working/VBG
#   ./.)
# (S Usually/RB ,/, it/PRP will/MD not/RB compile/VB ./.)
# (S
#   This/DT
#   will/MD
#   happen/VB
#   to/TO
#   us/PRP
#   regularly/RB
#   :/:
#   When/WRB
#   we/PRP
#   write/VBP
#   programs/NNS
#   ,/,
#   we/PRP
#   inevitably/RB
#   make/VBP
#   mistakes/NNS
#   ,/,
#   and/CC
#   then/RB
#   we/PRP
#   have/VBP
#   to/TO
#   correct/VB
#   them/PRP
#   ./.)
# (S Let/VB us/PRP try/VB that/IN out/RB now/RB ./.)
# (S
#   If/IN
#   ,/,
#   for/IN
#   (NP example/NN)
#   ,/,
#   we/PRP
#   forget/VBP
#   to/TO
#   write/VB
#   (NP the/DT semicolon/NN)
#   after/IN
#   (NP the/DT move/NN)
#   (/(
#   )/)
#   (NP instruction/NN)
#   ,/,
#   we/PRP
#   will/MD
#   be/VB
#   told/VBN
#   about/IN
#   it/PRP
#   when/WRB
#   we/PRP
#   try/VBP
#   to/TO
#   compile/VB
#   ./.)
# (S
#   (NP Exercise/NN)
#   2.7/CD
#   Open/NNP
#   your/PRP$
#   (NP editor/NN)
#   to/TO
#   show/VB
#   (NP the/DT crab’s/NN)
#   (NP source/NN)
#   (NP code/NN)
#   ,/,
#   and/CC
#   remove/VB
#   (NP the/DT semicolon/NN)
#   after/IN
#   (NP move/NN)
#   (/(
#   )/)
#   ./.)
# (S Then/RB (NP compile/NN) ./.)
# (S
#   Also/RB
#   (NP experiment/NN)
#   with/IN
#   other/JJ
#   errors/NNS
#   ,/,
#   such/JJ
#   as/IN
#   misspelling/VBG
#   (NP move/NN)
#   or/CC
#   making/VBG
#   other/JJ
#   random/JJ
#   changes/NNS
#   to/TO
#   (NP the/DT code/NN)
#   ./.)
# (S
#   Make/NNP
#   sure/JJ
#   to/TO
#   change/VB
#   it/PRP
#   all/DT
#   back/RB
#   after/IN
#   (NP this/DT exercise/NN)
#   ./.)
# (S
#   (NP Exercise/NN)
#   2.8/CD
#   Make/NNP
#   various/JJ
#   changes/NNS
#   to/TO
#   cause/VB
#   (NP different/JJ error/NN)
#   messages/NNS
#   ./.)
# (S
#   Find/NNP
#   at/IN
#   least/JJS
#   five/CD
#   (NP different/JJ error/NN)
#   messages/NNS
#   ./.)
# (S
#   Write/NNP
#   down/RP
#   (NP each/DT error/NN)
#   (NP message/NN)
#   and/CC
#   what/WP
#   (NP change/NN)
#   you/PRP
#   introduced/VBD
#   to/TO
#   provoke/VB
#   (NP this/DT error/NN)
#   ./.)
# (S
#   (NP Tip/NN)
#   :/:
#   When/WRB
#   (NP an/DT error/NN)
#   (NP message/NN)
#   appears/VBZ
#   at/IN
#   (NP the/DT bottom/NN)
#   of/IN
#   (NP the/DT editor/NN)
#   (NP window/NN)
#   ,/,
#   (NP a/DT question/NN)
#   (NP mark/NN)
#   (NP button/NN)
#   appears/VBZ
#   to/TO
#   (NP the/DT right/NN)
#   of/IN
#   it/PRP
#   ./.)
# (S
#   Clicking/VBG
#   (NP this/DT button/NN)
#   displays/VBZ
#   (NP some/DT additional/JJ information/NN)
#   about/IN
#   (NP the/DT error/NN)
#   (NP message/NN)
#   ./.)
# (S
#   As/IN
#   we/PRP
#   can/MD
#   see/VB
#   with/IN
#   (NP this/DT exercise/NN)
#   ,/,
#   if/IN
#   we/PRP
#   get/VBP
#   one/CD
#   (NP small/JJ detail/NN)
#   wrong/JJ
#   ,/,
#   Greenfoot/NNP
#   will/MD
#   open/VB
#   (NP the/DT editor/NN)
#   ,/,
#   highlight/VBD
#   (NP a/DT line/NN)
#   ,/,
#   and/CC
#   display/VB
#   (NP a/DT message/NN)
#   at/IN
#   (NP the/DT bottom/NN)
#   of/IN
#   (NP the/DT editor/NN)
#   (NP window/NN)
#   ./.)
# (S
#   (NP This/DT message/NN)
#   attempts/VBZ
#   to/TO
#   explain/VB
#   (NP the/DT error/NN)
#   ./.)
# (S
#   The/DT
#   messages/NNS
#   ,/,
#   however/RB
#   ,/,
#   vary/JJ
#   considerably/RB
#   in/IN
#   their/PRP$
#   (NP accuracy/NN)
#   and/CC
#   (NP usefulness/NN)
#   ./.)
# (S
#   Sometimes/RB
#   they/PRP
#   tell/VBP
#   us/PRP
#   fairly/RB
#   accurately/RB
#   what/WP
#   (NP the/DT problem/NN)
#   is/VBZ
#   ,/,
#   but/CC
#   sometimes/RB
#   they/PRP
#   are/VBP
#   cryptic/JJ
#   and/CC
#   hard/JJ
#   to/TO
#   understand/VB
#   ./.)
# (S
#   (NP The/DT line/NN)
#   that/WDT
#   is/VBZ
#   highlighted/VBN
#   is/VBZ
#   often/RB
#   (NP the/DT line/NN)
#   where/WRB
#   (NP the/DT problem/NN)
#   is/VBZ
#   ,/,
#   but/CC
#   sometimes/VBZ
#   it/PRP
#   is/VBZ
#   (NP the/DT line/NN)
#   after/IN
#   (NP the/DT problem/NN)
#   ./.)
# (S
#   When/WRB
#   you/PRP
#   see/VBP
#   ,/,
#   for/IN
#   (NP example/NN)
#   ,/,
#   (NP a/DT “/NN)
#   ;/:
#   expected”/CC
#   (NP message/NN)
#   ,/,
#   it/PRP
#   is/VBZ
#   possible/JJ
#   that/IN
#   (NP the/DT semicolon/NN)
#   is/VBZ
#   in/IN
#   (NP fact/NN)
#   missing/VBG
#   on/IN
#   (NP the/DT line/NN)
#   above/IN
#   (NP the/DT highlighted/JJ line/NN)
#   ./.)
# (S
#   We/PRP
#   will/MD
#   learn/VB
#   to/TO
#   read/VB
#   these/DT
#   messages/NNS
#   a/DT
#   little/JJ
#   better/JJR
#   over/IN
#   (NP time/NN)
#   ./.)
# (S
#   For/IN
#   now/RB
#   ,/,
#   if/IN
#   you/PRP
#   get/VBP
#   (NP a/DT message/NN)
#   and/CC
#   you/PRP
#   are/VBP
#   unsure/JJ
#   what/WP
#   it/PRP
#   means/VBZ
#   ,/,
#   look/VB
#   very/RB
#   carefully/RB
#   at/IN
#   your/PRP$
#   (NP code/NN)
#   and/CC
#   check/VB
#   that/IN
#   you/PRP
#   have/VBP
#   typed/VBN
#   (NP everything/NN)
#   correctly/RB
#   ./.)
# (S
#   2.4/CD
#   Dealing/VBG
#   with/IN
#   screen/JJ
#   edges/NNS
#   When/WRB
#   we/PRP
#   made/VBD
#   (NP the/DT crabs/JJ move/NN)
#   and/CC
#   (NP turn/NN)
#   in/IN
#   the/DT
#   previous/JJ
#   sections/NNS
#   ,/,
#   they/PRP
#   got/VBD
#   stuck/VBN
#   when/WRB
#   they/PRP
#   reached/VBD
#   (NP the/DT edge/NN)
#   of/IN
#   (NP the/DT screen/NN)
#   ./.)
# (S
#   (/(
#   Greenfoot/NNP
#   is/VBZ
#   designed/VBN
#   so/RB
#   that/IN
#   actors/NNS
#   can/MD
#   not/RB
#   leave/VB
#   (NP the/DT world/NN)
#   and/CC
#   fall/VB
#   off/RP
#   its/PRP$
#   (NP edge/NN)
#   ./.
#   )/))
# (S
#   Now/RB
#   ,/,
#   we/PRP
#   shall/MD
#   improve/VB
#   (NP this/DT behavior/NN)
#   so/RB
#   that/IN
#   (NP the/DT crab/NN)
#   notices/VBZ
#   that/IN
#   it/PRP
#   has/VBZ
#   reached/VBN
#   (NP the/DT world/NN)
#   (NP edge/NN)
#   and/CC
#   turns/VBZ
#   around/RB
#   ./.)
# (S
#   (NP The/DT question/NN)
#   is/VBZ
#   ,/,
#   How/WRB
#   can/MD
#   we/PRP
#   do/VB
#   that/DT
#   ?/.)
# (S
#   22/CD
#   (NP |/JJ Chapter/NN)
#   2/CD
#   ■/IN
#   (NP The/DT first/JJ program/NN)
#   :/:
#   Little/JJ
#   Crab/NNP
#   Exercise/NNP
#   2.9/CD
#   Open/NNP
#   (NP the/DT editor/NN)
#   for/IN
#   the/DT
#   Animal/NNP
#   (NP class/NN)
#   ./.)
# (S (NP Switch/NN) to/TO Documentation/NNP (NP view/NN) ./.)
# (S
#   Find/IN
#   (NP the/DT list/NN)
#   of/IN
#   methods/NNS
#   for/IN
#   (NP this/DT class/NN)
#   (/(
#   the/DT
#   “Method/NNP
#   Summary”/NNP
#   )/)
#   ./.)
# (S
#   How/WRB
#   many/JJ
#   methods/NNS
#   does/VBZ
#   (NP this/DT class/NN)
#   have/VB
#   ?/.)
# (S
#   Above/NNP
#   ,/,
#   we/PRP
#   have/VBP
#   used/VBN
#   (NP the/DT move/NN)
#   and/CC
#   (NP turn/NN)
#   methods/NNS
#   ,/,
#   so/IN
#   there/EX
#   might/MD
#   also/RB
#   be/VB
#   (NP a/DT method/NN)
#   that/WDT
#   helps/VBZ
#   us/PRP
#   with/IN
#   our/PRP$
#   (NP new/JJ goal/NN)
#   ./.)
# (S (/( In/IN (NP fact/NN) ,/, there/EX is/VBZ ./. )/))
# (S
#   But/CC
#   how/WRB
#   do/VBP
#   we/PRP
#   find/VB
#   out/RP
#   what/WP
#   methods/IN
#   we/PRP
#   have/VBP
#   got/VBN
#   available/JJ
#   ?/.)
# (S
#   (NP The/DT move/NN)
#   and/CC
#   (NP turn/NN)
#   methods/NNS
#   we/PRP
#   have/VBP
#   used/VBN
#   so/RB
#   far/RB
#   come/VBN
#   from/IN
#   the/DT
#   Animal/NNP
#   (NP class/NN)
#   ./.)
# (S
#   (NP A/DT crab/NN)
#   is/VBZ
#   (NP an/DT animal/NN)
#   (/(
#   signified/VBN
#   by/IN
#   (NP the/DT arrow/NN)
#   that/WDT
#   goes/VBZ
#   from/IN
#   Crab/NNP
#   to/TO
#   Animal/NNP
#   in/IN
#   (NP the/DT class/NN)
#   (NP diagram/NN)
#   )/)
#   ,/,
#   therefore/IN
#   it/PRP
#   can/MD
#   do/VB
#   whatever/WDT
#   (NP an/DT animal/NN)
#   can/MD
#   do/VB
#   ./.)
# (S
#   Our/PRP$
#   (NP Animal/JJ class/NN)
#   knows/VBZ
#   how/WRB
#   to/TO
#   move/VB
#   and/CC
#   turn—that/DT
#   is/VBZ
#   why/WRB
#   our/PRP$
#   (NP crab/NN)
#   can/MD
#   also/RB
#   do/VB
#   it/PRP
#   ./.)
# (S
#   This/DT
#   is/VBZ
#   called/VBN
#   (NP inheritance/NN)
#   :/:
#   The/DT
#   Crab/NNP
#   (NP class/NN)
#   inherits/VBZ
#   all/PDT
#   the/DT
#   abilities/NNS
#   (/(
#   methods/NNS
#   )/)
#   from/IN
#   the/DT
#   Animal/NNP
#   (NP class/NN)
#   ./.)
# (S
#   (NP The/DT question/NN)
#   now/RB
#   is/VBZ
#   ,/,
#   what/WP
#   else/RB
#   can/MD
#   our/PRP$
#   animals/NNS
#   do/VB
#   ?/.)
# (S
#   To/TO
#   investigate/VB
#   this/DT
#   ,/,
#   we/PRP
#   can/MD
#   open/VB
#   (NP the/DT editor/NN)
#   for/IN
#   the/DT
#   Animal/NNP
#   (NP class/NN)
#   ./.)
# (S
#   (NP The/DT editor/NN)
#   can/MD
#   display/VB
#   two/CD
#   different/JJ
#   views/NNS
#   :/:
#   It/PRP
#   can/MD
#   show/VB
#   (NP the/DT source/NN)
#   (NP code/NN)
#   (/(
#   as/IN
#   we/PRP
#   have/VBP
#   seen/VBN
#   for/IN
#   the/DT
#   Crab/NNP
#   (NP class/NN)
#   )/)
#   or/CC
#   it/PRP
#   can/MD
#   show/VB
#   (NP the/DT documentation/NN)
#   ./.)
# (S
#   (NP The/DT view/NN)
#   can/MD
#   be/VB
#   switched/VBN
#   using/VBG
#   (NP a/DT popup/JJ selection/NN)
#   (NP menu/NN)
#   in/IN
#   (NP the/DT top/JJ right/NN)
#   (NP corner/NN)
#   of/IN
#   (NP the/DT editor/NN)
#   (NP window/NN)
#   ./.)
# (S
#   We/PRP
#   now/RB
#   want/VBP
#   to/TO
#   look/VB
#   at/IN
#   the/DT
#   Animal/NNP
#   (NP class/NN)
#   in/IN
#   the/DT
#   Documentation/NNP
#   (NP view/NN)
#   (/(
#   Figure/NNP
#   2.3/CD
#   )/)
#   ./.)
# (S
#   Method/NNP
#   summary/JJ
#   View/NNP
#   (NP switch/NN)
#   (NP Figure/NN)
#   2.3/CD
#   Documentation/NNP
#   (NP view/NN)
#   (/(
#   with/IN
#   (NP method/NN)
#   (NP summary/NN)
#   )/)
#   of/IN
#   the/DT
#   Animal/NNP
#   (NP class/NN)
#   Concept/NNP
#   :/:
#   (NP A/DT subclass/NN)
#   inherits/VBZ
#   all/PDT
#   the/DT
#   methods/NNS
#   from/IN
#   its/PRP$
#   (NP superclass/NN)
#   ./.)
# (S
#   That/DT
#   means/VBZ
#   that/IN
#   it/PRP
#   has/VBZ
#   and/CC
#   can/MD
#   use/VB
#   all/DT
#   methods/NNS
#   that/IN
#   its/PRP$
#   (NP superclass/NN)
#   defines/NNS
#   ./.)
# (S
#   2.4/CD
#   Dealing/VBG
#   with/IN
#   screen/JJ
#   edges/NNS
#   |/VBP
#   23/CD
#   If/IN
#   we/PRP
#   look/VBP
#   at/IN
#   (NP the/DT method/NN)
#   (NP summary/NN)
#   ,/,
#   we/PRP
#   can/MD
#   see/VB
#   all/PDT
#   the/DT
#   methods/NNS
#   that/IN
#   the/DT
#   Animal/NNP
#   (NP class/NN)
#   provides/VBZ
#   ./.)
# (S
#   Among/IN
#   them/PRP
#   are/VBP
#   three/CD
#   methods/NNS
#   that/WDT
#   are/VBP
#   especially/RB
#   interesting/VBG
#   to/TO
#   us/PRP
#   at/IN
#   (NP the/DT moment/NN)
#   ./.)
# (S
#   They/PRP
#   are/VBP
#   :/:
#   (NP boolean/JJ atWorldEdge/NN)
#   (/(
#   )/)
#   Test/VBP
#   if/IN
#   we/PRP
#   are/VBP
#   close/JJ
#   to/TO
#   one/CD
#   of/IN
#   the/DT
#   edges/NNS
#   of/IN
#   (NP the/DT world/NN)
#   ./.)
# (S
#   (NP void/JJ move/NN)
#   (/(
#   )/)
#   Move/NNP
#   forward/RB
#   in/IN
#   (NP the/DT current/JJ direction/NN)
#   ./.)
# (S
#   (NP void/JJ turn/NN)
#   (/(
#   (NP int/JJ angle/NN)
#   )/)
#   Turn/NNP
#   “angle”/NNP
#   degrees/VBZ
#   toward/IN
#   (NP the/DT right/NN)
#   (/(
#   (NP clockwise/NN)
#   )/)
#   ./.)
# (S
#   Here/RB
#   we/PRP
#   see/VBP
#   the/DT
#   signatures/NNS
#   for/IN
#   three/CD
#   methods/NNS
#   ,/,
#   as/IN
#   we/PRP
#   first/RB
#   encountered/VBD
#   them/PRP
#   in/IN
#   (NP Chapter/NN)
#   1/CD
#   ./.)
# (S
#   (NP Each/DT method/NN)
#   (NP signature/NN)
#   starts/VBZ
#   with/IN
#   (NP a/DT return/NN)
#   (NP type/NN)
#   and/CC
#   is/VBZ
#   followed/VBN
#   by/IN
#   (NP the/DT method/NN)
#   (NP name/NN)
#   and/CC
#   (NP the/DT parameter/NN)
#   (NP list/NN)
#   ./.)
# (S
#   Below/IN
#   it/PRP
#   ,/,
#   we/PRP
#   see/VBP
#   (NP a/DT comment/NN)
#   describing/VBG
#   what/WP
#   (NP the/DT method/NN)
#   does/VBZ
#   ./.)
# (S
#   We/PRP
#   can/MD
#   see/VB
#   that/IN
#   the/DT
#   three/CD
#   (NP method/NN)
#   names/NNS
#   are/VBP
#   (NP atWorldEdge/NN)
#   ,/,
#   (NP move/NN)
#   ,/,
#   and/CC
#   (NP turn/NN)
#   ./.)
# (S
#   (NP The/DT move/NN)
#   and/CC
#   (NP turn/NN)
#   methods/NNS
#   are/VBP
#   the/DT
#   ones/NNS
#   we/PRP
#   used/VBD
#   in/IN
#   the/DT
#   previous/JJ
#   sections/NNS
#   ./.)
# (S
#   If/IN
#   we/PRP
#   look/VBP
#   at/IN
#   their/PRP$
#   (NP parameter/NN)
#   lists/NNS
#   ,/,
#   we/PRP
#   can/MD
#   see/VB
#   what/WP
#   we/PRP
#   observed/VBD
#   before/IN
#   :/:
#   (NP move/NN)
#   has/VBZ
#   no/DT
#   parameters/NNS
#   (/(
#   the/DT
#   parentheses/NNS
#   are/VBP
#   empty/JJ
#   )/)
#   ,/,
#   and/CC
#   turn/VB
#   expects/VBZ
#   one/CD
#   (NP parameter/NN)
#   of/IN
#   (NP type/NN)
#   (NP int/NN)
#   (/(
#   (NP a/DT whole/JJ number/NN)
#   )/)
#   for/IN
#   (NP the/DT angle/NN)
#   ./.)
# (S
#   (/(
#   (NP Read/JJ Section/NN)
#   1.5/CD
#   again/RB
#   if/IN
#   you/PRP
#   are/VBP
#   unsure/JJ
#   about/IN
#   (NP parameter/NN)
#   lists/NNS
#   ./.
#   )/))
# (S
#   We/PRP
#   can/MD
#   also/RB
#   see/VB
#   that/IN
#   (NP the/DT move/NN)
#   and/CC
#   (NP turn/NN)
#   methods/NNS
#   have/VBP
#   void/VBN
#   as/IN
#   their/PRP$
#   (NP return/NN)
#   (NP type/NN)
#   ./.)
# (S
#   This/DT
#   means/VBZ
#   that/IN
#   (NP neither/DT method/NN)
#   returns/VBZ
#   (NP a/DT value/NN)
#   ./.)
# (S
#   We/PRP
#   are/VBP
#   commanding/VBG
#   or/CC
#   instructing/VBG
#   (NP the/DT object/NN)
#   to/TO
#   move/VB
#   or/CC
#   to/TO
#   turn/VB
#   ./.)
# (S
#   (NP The/DT animal/NN)
#   will/MD
#   just/RB
#   obey/VB
#   (NP the/DT command/NN)
#   but/CC
#   not/RB
#   respond/VB
#   with/IN
#   (NP an/DT answer/NN)
#   to/TO
#   us/PRP
#   ./.)
# (S
#   (NP The/DT signature/NN)
#   for/IN
#   (NP atWorldEdge/NN)
#   is/VBZ
#   a/DT
#   little/JJ
#   different/JJ
#   ./.)
# (S
#   It/PRP
#   is/VBZ
#   (NP boolean/JJ atWorldEdge/NN)
#   (/(
#   )/)
#   (NP This/DT method/NN)
#   has/VBZ
#   no/DT
#   parameters/NNS
#   (/(
#   there/EX
#   is/VBZ
#   (NP nothing/NN)
#   within/IN
#   the/DT
#   parentheses/NNS
#   )/)
#   ,/,
#   but/CC
#   it/PRP
#   specifies/VBZ
#   (NP a/DT return/NN)
#   (NP value/NN)
#   :/:
#   (NP boolean/NN)
#   ./.)
# (S
#   We/PRP
#   have/VBP
#   briefly/VBN
#   encountered/VBD
#   (NP the/DT boolean/JJ type/NN)
#   in/IN
#   Section/NNP
#   1.4—it/CD
#   is/VBZ
#   (NP a/DT type/NN)
#   that/WDT
#   can/MD
#   hold/VB
#   two/CD
#   possible/JJ
#   values/NNS
#   :/:
#   true/JJ
#   or/CC
#   false/JJ
#   ./.)
# (S
#   Calling/VBG
#   methods/NNS
#   that/WDT
#   have/VBP
#   return/VBN
#   values/NNS
#   (/(
#   where/WRB
#   (NP the/DT return/NN)
#   (NP type/NN)
#   is/VBZ
#   not/RB
#   void/JJ
#   )/)
#   is/VBZ
#   not/RB
#   like/IN
#   issuing/VBG
#   (NP a/DT command/NN)
#   ,/,
#   but/CC
#   asking/VBG
#   (NP a/DT question/NN)
#   ./.)
# (S
#   If/IN
#   we/PRP
#   use/VBP
#   (NP the/DT atWorldEdge/NN)
#   (/(
#   )/)
#   (NP method/NN)
#   ,/,
#   (NP the/DT method/NN)
#   will/MD
#   respond/VB
#   with/IN
#   either/DT
#   true/JJ
#   (/(
#   Yes/UH
#   !/.
#   )/))
# (S or/CC false/JJ (/( No/UH !/. )/) ./.)
# (S
#   Thus/RB
#   ,/,
#   we/PRP
#   can/MD
#   use/VB
#   (NP this/DT method/NN)
#   to/TO
#   check/VB
#   whether/IN
#   we/PRP
#   are/VBP
#   at/IN
#   (NP the/DT edge/NN)
#   of/IN
#   (NP the/DT world/NN)
#   ./.)
# (S Exercise/RB 2.10/CD Create/NNP (NP a/DT crab/NN) ./.)
# (S
#   Right-click/JJ
#   it/PRP
#   ,/,
#   and/CC
#   find/VB
#   (NP the/DT boolean/JJ atWorldEdge/NN)
#   (/(
#   )/)
#   (NP method/NN)
#   (/(
#   it/PRP
#   is/VBZ
#   in/IN
#   the/DT
#   inherited/VBN
#   from/IN
#   Animal/NNP
#   (NP submenu/NN)
#   ,/,
#   since/IN
#   (NP the/DT crab/NN)
#   inherited/VBD
#   (NP this/DT method/NN)
#   from/IN
#   the/DT
#   Animal/NNP
#   (NP class/NN)
#   )/)
#   ./.)
# (S Call/VB (NP this/DT method/NN) ./.)
# (S What/WP does/VBZ it/PRP return/VB ?/.)
# (S
#   (NP Exercise/NN)
#   2.11/CD
#   Let/VBD
#   (NP the/DT crab/NN)
#   (NP run/NN)
#   to/TO
#   (NP the/DT edge/NN)
#   of/IN
#   (NP the/DT screen/NN)
#   (/(
#   or/CC
#   move/VB
#   it/PRP
#   there/RB
#   manually/RB
#   )/)
#   ,/,
#   and/CC
#   then/RB
#   call/VB
#   (NP the/DT atWorldEdge/NN)
#   (/(
#   )/)
#   (NP method/NN)
#   again/RB
#   ./.)
# (S What/WP does/VBZ it/PRP return/VB now/RB ?/.)
# (S
#   (NP Concept/NN)
#   :/:
#   Calling/VBG
#   (NP a/DT method/NN)
#   with/IN
#   (NP a/DT void/JJ return/NN)
#   (NP type/NN)
#   issues/NNS
#   (NP a/DT command/NN)
#   ./.)
# (S
#   Calling/VBG
#   (NP a/DT method/NN)
#   with/IN
#   (NP a/DT non-void/JJ return/NN)
#   (NP type/NN)
#   asks/VBZ
#   (NP a/DT question/NN)
#   ./.)
# (S
#   (NP Concept/NN)
#   :/:
#   An/DT
#   if-statement/JJ
#   can/MD
#   be/VB
#   used/VBN
#   to/TO
#   write/VB
#   instructions/NNS
#   that/WDT
#   are/VBP
#   executed/VBN
#   only/RB
#   when/WRB
#   (NP a/DT certain/JJ condition/NN)
#   is/VBZ
#   true/JJ
#   ./.)
# (S
#   24/CD
#   (NP |/JJ Chapter/NN)
#   2/CD
#   ■/IN
#   (NP The/DT first/JJ program/NN)
#   :/:
#   Little/JJ
#   Crab/NNP
#   Code/NNP
#   2.3/CD
#   Turning/VBG
#   around/RB
#   at/IN
#   (NP the/DT edge/NN)
#   of/IN
#   (NP the/DT world/NN)
#   (NP import/NN)
#   (NP greenfoot/NN)
#   ./.)
# (S
#   (NP */NN)
#   ;/:
#   ///NNP
#   (/(
#   World/NNP
#   ,/,
#   Actor/NNP
#   ,/,
#   GreenfootImage/NNP
#   ,/,
#   and/CC
#   Greenfoot/NNP
#   )/)
#   /**/VBP
#   */$
#   (NP This/DT class/NN)
#   defines/VBZ
#   (NP a/DT crab/NN)
#   ./.)
# (S Crabs/NNP live/VBP on/IN (NP the/DT beach/NN) ./.)
# (S
#   (NP *//JJ public/JJ class/NN)
#   Crab/NNP
#   extends/VBZ
#   Animal/NNP
#   {/(
#   (NP public/JJ void/NN)
#   (NP act/NN)
#   (/(
#   )/)
#   {/(
#   if/IN
#   (/(
#   (NP atWorldEdge/NN)
#   (/(
#   )/)
#   )/)
#   {/(
#   (NP turn/NN)
#   (/(
#   17/CD
#   )/)
#   ;/:
#   }/)
#   move/FW
#   (/(
#   )/)
#   ;/:
#   }/)
#   }/)
#   The/DT
#   if-statement/JJ
#   is/VBZ
#   (NP a/DT part/NN)
#   of/IN
#   the/DT
#   Java/NNP
#   (NP language/NN)
#   that/WDT
#   makes/VBZ
#   it/PRP
#   possible/JJ
#   to/TO
#   execute/VB
#   commands/NNS
#   only/RB
#   if/IN
#   (NP some/DT condition/NN)
#   is/VBZ
#   true/JJ
#   ./.)
# (S
#   For/IN
#   (NP example/NN)
#   ,/,
#   here/RB
#   we/PRP
#   want/VBP
#   to/TO
#   turn/VB
#   only/RB
#   if/IN
#   we/PRP
#   are/VBP
#   near/IN
#   (NP the/DT edge/NN)
#   of/IN
#   (NP the/DT world/NN)
#   ./.)
# (S
#   (NP The/DT code/NN)
#   we/PRP
#   have/VBP
#   written/VBN
#   is/VBZ
#   :/:
#   if/IN
#   (/(
#   (NP atWorldEdge/NN)
#   (/(
#   )/)
#   )/)
#   {/(
#   (NP turn/NN)
#   (/(
#   17/CD
#   )/)
#   ;/:
#   }/)
#   move/FW
#   (/(
#   )/)
#   ;/:
#   (NP The/DT general/JJ form/NN)
#   of/IN
#   (NP an/DT if-statement/NN)
#   is/VBZ
#   this/DT
#   :/:
#   if/IN
#   (/(
#   (NP condition/NN)
#   )/)
#   {/(
#   (NP instruction/NN)
#   ;/:
#   (NP instruction/NN)
#   ;/:
#   .../:
#   }/)
#   In/IN
#   (NP place/NN)
#   of/IN
#   (NP the/DT condition/NN)
#   can/MD
#   be/VB
#   (NP any/DT expression/NN)
#   that/WDT
#   is/VBZ
#   either/DT
#   true/JJ
#   or/CC
#   false/JJ
#   (/(
#   such/JJ
#   as/IN
#   our/PRP$
#   (NP atWorldEdge/NN)
#   (/(
#   )/)
#   method/VBP
#   (NP call/NN)
#   )/)
#   ,/,
#   and/CC
#   the/DT
#   instructions/NNS
#   will/MD
#   be/VB
#   executed/VBN
#   only/RB
#   if/IN
#   (NP the/DT condition/NN)
#   is/VBZ
#   true/JJ
#   ./.)
# (S There/EX can/MD be/VB one/CD or/CC more/JJR instructions/NNS ./.)
# (S
#   If/IN
#   (NP the/DT condition/NN)
#   is/VBZ
#   false/JJ
#   ,/,
#   the/DT
#   instructions/NNS
#   are/VBP
#   just/RB
#   skipped/VBN
#   ,/,
#   and/CC
#   (NP execution/NN)
#   continues/VBZ
#   under/IN
#   (NP the/DT closing/NN)
#   (NP curly/JJ bracket/NN)
#   of/IN
#   (NP the/DT if-statement/NN)
#   ./.)
# (S
#   (NP Note/NN)
#   that/IN
#   our/PRP$
#   (NP move/NN)
#   (/(
#   )/)
#   (NP method/NN)
#   (NP call/NN)
#   is/VBZ
#   outside/IN
#   the/DT
#   if-statement/JJ
#   ,/,
#   so/IN
#   it/PRP
#   will/MD
#   be/VB
#   executed/VBN
#   in/IN
#   (NP any/DT case/NN)
#   ./.)
# (S
#   In/IN
#   other/JJ
#   words/NNS
#   :/:
#   If/IN
#   we/PRP
#   are/VBP
#   at/IN
#   (NP the/DT edge/NN)
#   of/IN
#   (NP the/DT world/NN)
#   ,/,
#   we/PRP
#   turn/VBP
#   and/CC
#   then/RB
#   move/VB
#   ;/:
#   if/IN
#   we/PRP
#   are/VBP
#   not/RB
#   at/IN
#   (NP the/DT edge/NN)
#   of/IN
#   (NP the/DT world/NN)
#   ,/,
#   we/PRP
#   just/RB
#   move/VB
#   ./.)
# (S
#   We/PRP
#   can/MD
#   now/RB
#   combine/VB
#   (NP this/DT method/NN)
#   with/IN
#   an/DT
#   if-statement/JJ
#   to/TO
#   write/VB
#   (NP the/DT code/NN)
#   shown/VBN
#   in/IN
#   Code/NNP
#   2.3/CD
#   ./.)
# (S
#   2.5/CD
#   Summary/NNP
#   of/IN
#   programming/VBG
#   techniques/NNS
#   |/$
#   25/CD
#   Exercise/NNP
#   2.12/CD
#   Try/NNP
#   it/PRP
#   out/RP
#   !/.)
# (S
#   (NP Type/NN)
#   in/IN
#   (NP the/DT code/NN)
#   discussed/VBN
#   above/IN
#   and/CC
#   see/VB
#   if/IN
#   you/PRP
#   can/MD
#   make/VB
#   your/PRP$
#   (NP crabs/NN)
#   (NP turn/NN)
#   at/IN
#   (NP the/DT edge/NN)
#   of/IN
#   (NP the/DT screen/NN)
#   ./.)
# (S
#   Pay/NNP
#   (NP close/JJ attention/NN)
#   to/TO
#   (NP the/DT opening/NN)
#   and/CC
#   (NP closing/NN)
#   (NP brackets—it/NN)
#   is/VBZ
#   easy/JJ
#   to/TO
#   miss/VB
#   one/CD
#   or/CC
#   have/VB
#   too/RB
#   many/JJ
#   ./.)
# (S
#   (NP Exercise/NN)
#   2.13/CD
#   (NP Experiment/NN)
#   with/IN
#   different/JJ
#   values/NNS
#   for/IN
#   (NP the/DT parameter/NN)
#   to/TO
#   (NP the/DT turn/NN)
#   (NP method/NN)
#   ./.)
# (S Find/VB (NP one/NN) that/WDT looks/VBZ good/JJ ./.)
# (S
#   (NP Exercise/NN)
#   2.14/CD
#   (NP Place/NN)
#   (NP the/DT move/NN)
#   (/(
#   )/)
#   (NP statement/NN)
#   inside/IN
#   the/DT
#   if-statement/JJ
#   ,/,
#   rather/RB
#   than/IN
#   after/IN
#   it/PRP
#   ./.)
# (S
#   Find/VB
#   out/RP
#   what/WP
#   is/VBZ
#   (NP the/DT effect/NN)
#   and/CC
#   explain/VB
#   (NP the/DT behavior/NN)
#   you/PRP
#   observe/VBP
#   ./.)
# (S
#   (/(
#   Then/RB
#   ,/,
#   fix/VB
#   it/PRP
#   again/RB
#   by/IN
#   moving/VBG
#   it/PRP
#   back/RB
#   where/WRB
#   it/PRP
#   was/VBD
#   ./.
#   )/))
# (S
#   (NP Tip/NN)
#   :/:
#   In/IN
#   the/DT
#   Greenfoot/NNP
#   (NP editor/NN)
#   ,/,
#   when/WRB
#   you/PRP
#   place/VBP
#   (NP the/DT cursor/NN)
#   behind/IN
#   (NP an/DT opening/NN)
#   or/CC
#   (NP closing/NN)
#   (NP bracket/NN)
#   ,/,
#   Greenfoot/NNP
#   will/MD
#   mark/VB
#   the/DT
#   matching/VBG
#   (NP closing/NN)
#   or/CC
#   opening/VBG
#   (NP bracket/NN)
#   ./.)
# (S
#   This/DT
#   can/MD
#   be/VB
#   used/VBN
#   to/TO
#   check/VB
#   whether/IN
#   your/PRP$
#   brackets/NNS
#   match/VBP
#   up/RP
#   as/IN
#   they/PRP
#   should/MD
#   ./.)
# (S
#   (NP Note/NN)
#   :/:
#   (NP Indentation/NN)
#   In/IN
#   all/PDT
#   (NP the/DT code/NN)
#   examples/VBZ
#   you/PRP
#   have/VBP
#   seen/VBN
#   so/RB
#   far/RB
#   (/(
#   for/IN
#   (NP instance/NN)
#   ,/,
#   Code/NNP
#   2.3/CD
#   )/)
#   ,/,
#   you/PRP
#   may/MD
#   have/VB
#   noticed/VBN
#   (NP some/DT careful/JJ indentation/NN)
#   being/VBG
#   used/VBN
#   ./.)
# (S
#   (NP Every/DT time/NN)
#   (NP a/DT curly/JJ bracket/NN)
#   opens/NNS
#   ,/,
#   the/DT
#   following/JJ
#   lines/NNS
#   are/VBP
#   indented/JJ
#   one/CD
#   (NP level/NN)
#   more/JJR
#   than/IN
#   the/DT
#   previous/JJ
#   ones/NNS
#   ./.)
# (S
#   When/WRB
#   a/DT
#   curly/RB
#   (NP bracket/NN)
#   closes/NNS
#   ,/,
#   (NP the/DT indentation/NN)
#   goes/VBZ
#   back/RB
#   one/CD
#   (NP level/NN)
#   ,/,
#   so/IN
#   that/IN
#   (NP the/DT closing/NN)
#   (NP curly/JJ bracket/NN)
#   is/VBZ
#   directly/RB
#   below/IN
#   the/DT
#   matching/VBG
#   (NP opening/NN)
#   (NP bracket/NN)
#   ./.)
# (S
#   This/DT
#   makes/VBZ
#   it/PRP
#   easy/JJ
#   to/TO
#   find/VB
#   (NP the/DT matching/NN)
#   (NP bracket/NN)
#   ./.)
# (S
#   We/PRP
#   use/VBP
#   four/CD
#   spaces/NNS
#   for/IN
#   one/CD
#   (NP level/NN)
#   of/IN
#   (NP indentation/NN)
#   ./.)
# (S
#   The/DT
#   Tab/NNP
#   (NP key/NN)
#   will/MD
#   insert/VB
#   spaces/NNS
#   in/IN
#   your/PRP$
#   (NP editor/NN)
#   for/IN
#   one/CD
#   (NP level/NN)
#   of/IN
#   (NP indentation/NN)
#   as/IN
#   well/RB
#   ./.)
# (S
#   Taking/VBG
#   (NP care/NN)
#   with/IN
#   (NP indentation/NN)
#   in/IN
#   your/PRP$
#   (NP own/JJ code/NN)
#   is/VBZ
#   very/RB
#   important/JJ
#   ./.)
# (S
#   If/IN
#   you/PRP
#   do/VBP
#   not/RB
#   indent/VB
#   carefully/RB
#   ,/,
#   some/DT
#   errors/NNS
#   (/(
#   particularly/RB
#   misplaced/VBN
#   or/CC
#   mismatched/VBN
#   curly/JJ
#   brackets/NNS
#   )/)
#   are/VBP
#   very/RB
#   hard/JJ
#   to/TO
#   spot/VB
#   ./.)
# (S
#   (NP Proper/JJ indentation/NN)
#   makes/VBZ
#   code/RB
#   much/JJ
#   easier/JJR
#   to/TO
#   read/VB
#   ,/,
#   and/CC
#   thus/RB
#   avoid/VB
#   potential/JJ
#   errors/NNS
#   ./.)
# (S
#   2.5/CD
#   Summary/NNP
#   of/IN
#   programming/VBG
#   techniques/NNS
#   In/IN
#   (NP this/DT book/NN)
#   ,/,
#   we/PRP
#   are/VBP
#   discussing/VBG
#   programming/VBG
#   from/IN
#   a/DT
#   very/RB
#   (NP example-driven/JJ perspective/NN)
#   ./.)
# (S
#   We/PRP
#   introduce/VBP
#   (NP general/JJ programming/NN)
#   techniques/NNS
#   as/IN
#   we/PRP
#   need/VBP
#   them/PRP
#   to/TO
#   improve/VB
#   our/PRP$
#   scenarios/NNS
#   ./.)
# (S
#   We/PRP
#   shall/MD
#   summarize/VB
#   (NP the/DT important/JJ programming/NN)
#   techniques/NNS
#   at/IN
#   (NP the/DT end/NN)
#   of/IN
#   (NP each/DT chapter/NN)
#   to/TO
#   make/VB
#   it/PRP
#   clear/JJ
#   what/WP
#   you/PRP
#   really/RB
#   need/VB
#   to/TO
#   take/VB
#   away/RP
#   from/IN
#   (NP the/DT discussion/NN)
#   in/IN
#   (NP order/NN)
#   to/TO
#   progress/VB
#   well/RB
#   ./.)
# (S
#   In/IN
#   (NP this/DT chapter/NN)
#   ,/,
#   we/PRP
#   have/VBP
#   seen/VBN
#   how/WRB
#   to/TO
#   call/VB
#   methods/NNS
#   (/(
#   such/JJ
#   as/IN
#   (NP move/NN)
#   (/(
#   )/)
#   )/)
#   ,/,
#   with/IN
#   and/CC
#   without/IN
#   parameters/NNS
#   ./.)
# (S
#   This/DT
#   will/MD
#   form/VB
#   (NP the/DT basis/NN)
#   for/IN
#   all/DT
#   further/JJ
#   Java/NNP
#   (NP programming/NN)
#   ./.)
# (S
#   We/PRP
#   have/VBP
#   also/RB
#   learnt/VBN
#   to/TO
#   identify/VB
#   (NP the/DT body/NN)
#   of/IN
#   (NP the/DT act/NN)
#   (NP method—this/NN)
#   is/VBZ
#   where/WRB
#   we/PRP
#   start/VBP
#   writing/VBG
#   our/PRP$
#   instructions/NNS
#   ./.)
# (S
#   You/PRP
#   have/VBP
#   encountered/VBN
#   (NP some/DT error/NN)
#   messages/NNS
#   ./.)
# (S
#   This/DT
#   will/MD
#   continue/VB
#   throughout/IN
#   all/DT
#   your/PRP$
#   (NP programming/NN)
#   endeavors/NNS
#   ./.)
# (S
#   We/PRP
#   all/DT
#   make/VBP
#   mistakes/NNS
#   ,/,
#   and/CC
#   we/PRP
#   all/DT
#   encounter/VBP
#   (NP error/NN)
#   messages/NNS
#   ./.)
# (S
#   This/DT
#   is/VBZ
#   not/RB
#   (NP a/DT sign/NN)
#   of/IN
#   (NP a/DT bad/JJ programmer—it/NN)
#   is/VBZ
#   (NP a/DT normal/JJ part/NN)
#   of/IN
#   (NP programming/NN)
#   ./.)
# (S
#   We/PRP
#   have/VBP
#   encountered/VBN
#   (NP a/DT first/JJ glimpse/NN)
#   of/IN
#   (NP inheritance/NN)
#   :/:
#   Classes/NNS
#   inherit/VBP
#   the/DT
#   methods/NNS
#   from/IN
#   their/PRP$
#   superclasses/NNS
#   ./.)
# (S
#   The/DT
#   Documentation/NNP
#   (NP view/NN)
#   of/IN
#   (NP a/DT class/NN)
#   gives/VBZ
#   us/PRP
#   (NP a/DT summary/NN)
#   of/IN
#   the/DT
#   methods/NNS
#   available/JJ
#   ./.)
# (S
#   And/CC
#   ,/,
#   very/RB
#   importantly/RB
#   ,/,
#   we/PRP
#   have/VBP
#   seen/VBN
#   how/WRB
#   to/TO
#   make/VB
#   decisions/NNS
#   :/:
#   We/PRP
#   have/VBP
#   used/VBN
#   an/DT
#   if-statement/JJ
#   for/IN
#   (NP conditional/JJ execution/NN)
#   ./.)
# (S
#   This/DT
#   went/VBD
#   (NP hand/NN)
#   in/IN
#   (NP hand/NN)
#   with/IN
#   (NP the/DT appearance/NN)
#   of/IN
#   (NP the/DT type/NN)
#   (NP boolean/NN)
#   ,/,
#   (NP a/DT value/NN)
#   that/WDT
#   can/MD
#   be/VB
#   true/JJ
#   or/CC
#   false/JJ
#   ./.)
# (S
#   26/CD
#   (NP |/JJ Chapter/NN)
#   2/CD
#   ■/IN
#   (NP The/DT first/JJ program/NN)
#   :/:
#   Little/JJ
#   Crab/NNP
#   Concept/NNP
#   summary/JJ
#   ■/VBD
#   (NP A/DT method/NN)
#   (NP call/NN)
#   is/VBZ
#   (NP an/DT instruction/NN)
#   that/WDT
#   tells/VBZ
#   (NP an/DT object/NN)
#   to/TO
#   perform/VB
#   (NP an/DT action/NN)
#   ./.)
# (S
#   (NP The/DT action/NN)
#   is/VBZ
#   defined/VBN
#   by/IN
#   (NP a/DT method/NN)
#   of/IN
#   (NP the/DT object/NN)
#   ./.)
# (S
#   ■/JJ
#   Additional/NNP
#   (NP information/NN)
#   can/MD
#   be/VB
#   passed/VBN
#   to/TO
#   some/DT
#   methods/NNS
#   within/IN
#   the/DT
#   parentheses/NNS
#   ./.)
# (S
#   (NP The/DT value/NN)
#   passed/VBN
#   is/VBZ
#   called/VBN
#   (NP a/DT parameter/NN)
#   ./.)
# (S
#   ■/JJ
#   Multiple/NNP
#   instructions/NNS
#   are/VBP
#   executed/VBN
#   in/IN
#   (NP sequence/NN)
#   ,/,
#   one/CD
#   after/IN
#   the/DT
#   other/JJ
#   ,/,
#   in/IN
#   (NP the/DT order/NN)
#   in/IN
#   which/WDT
#   they/PRP
#   are/VBP
#   written/VBN
#   ./.)
# (S
#   (NP ■/NN)
#   When/WRB
#   (NP a/DT class/NN)
#   is/VBZ
#   compiled/VBN
#   ,/,
#   (NP the/DT compiler/NN)
#   checks/NNS
#   to/TO
#   see/VB
#   whether/IN
#   there/EX
#   are/VBP
#   any/DT
#   errors/NNS
#   ./.)
# (S
#   If/IN
#   (NP an/DT error/NN)
#   is/VBZ
#   found/VBN
#   ,/,
#   (NP an/DT error/NN)
#   (NP message/NN)
#   is/VBZ
#   displayed/VBN
#   ./.)
# (S
#   ■/VB
#   A/NNP
#   (NP subclass/NN)
#   inherits/VBZ
#   all/PDT
#   the/DT
#   methods/NNS
#   from/IN
#   its/PRP$
#   (NP superclass/NN)
#   ./.)
# (S
#   That/DT
#   means/VBZ
#   that/IN
#   it/PRP
#   has/VBZ
#   ,/,
#   and/CC
#   can/MD
#   use/VB
#   ,/,
#   all/DT
#   methods/NNS
#   that/IN
#   its/PRP$
#   (NP superclass/NN)
#   defines/NNS
#   ./.)
# (S
#   (NP ■/NN)
#   Calling/VBG
#   (NP a/DT method/NN)
#   with/IN
#   (NP a/DT void/JJ return/NN)
#   (NP type/NN)
#   issues/NNS
#   (NP a/DT command/NN)
#   ./.)
# (S
#   Calling/VBG
#   (NP a/DT method/NN)
#   with/IN
#   (NP a/DT non-void/JJ return/NN)
#   (NP type/NN)
#   asks/VBZ
#   (NP a/DT question/NN)
#   ./.)
# (S
#   ■/VB
#   An/DT
#   if-statement/JJ
#   can/MD
#   be/VB
#   used/VBN
#   to/TO
#   write/VB
#   instructions/NNS
#   that/WDT
#   are/VBP
#   executed/VBN
#   only/RB
#   when/WRB
#   (NP a/DT certain/JJ condition/NN)
#   is/VBZ
#   true/JJ
#   ./.)

# %%
neResult = []
for s in sentences:
    neResult.append(nltk.ne_chunk(s,binary=True))
print(neResult)
# Out:
# [Tree('S', [('\ufeffCHAPTER', 'RB'), ('2', 'CD'), ('The', 'DT'), ('first', 'JJ'), ('program', 'NN'), (':', ':'), ('Little', 'JJ'), ('Crab', 'JJ'), ('topics', 'NNS'), (':', ':'), ('writing', 'VBG'), ('code', 'NN'), (':', ':'), ('movement', 'NN'), (',', ','), ('turning', 'VBG'), (',', ','), ('reacting', 'VBG'), ('to', 'TO'), ('the', 'DT'), ('screen', 'NN'), ('edges', 'VBZ'), ('concepts', 'NNS'), (':', ':'), ('source', 'NN'), ('code', 'NN'), (',', ','), ('method', 'NN'), ('call', 'NN'), (',', ','), ('parameter', 'NN'), (',', ','), ('sequence', 'NN'), (',', ','), ('if-statement', 'JJ'), ('Exercise', 'NN'), ('2.1', 'CD'), ('Start', 'NNP'), ('Greenfoot', 'NNP'), ('and', 'CC'), ('open', 'VB'), ('the', 'DT'), ('little-crab', 'JJ'), ('scenario', 'NN'), ('.', '.')]), Tree('S', [('Place', 'NN'), ('a', 'DT'), ('crab', 'NN'), ('into', 'IN'), ('the', 'DT'), ('world', 'NN'), ('and', 'CC'), ('run', 'VB'), ('the', 'DT'), ('program', 'NN'), ('(', '('), ('click', 'VB'), ('the', 'DT'), ('Run', 'NNP'), ('button', 'NN'), (')', ')'), ('.', '.')]), Tree('S', [('What', 'WP'), ('do', 'VBP'), ('you', 'PRP'), ('observe', 'VB'), ('?', '.')]), Tree('S', [('(', '('), ('Remember', 'VB'), (':', ':'), ('If', 'IN'), ('the', 'DT'), ('class', 'NN'), ('icons', 'NNS'), ('on', 'IN'), ('the', 'DT'), ('right', 'JJ'), ('appear', 'NN'), ('striped', 'VBD'), (',', ','), ('you', 'PRP'), ('have', 'VBP'), ('to', 'TO'), ('compile', 'VB'), ('the', 'DT'), ('project', 'NN'), ('first', 'RB'), ('.', '.'), (')', ')')]), Tree('S', [('On', 'IN'), ('the', 'DT'), ('right', 'NN'), (',', ','), ('you', 'PRP'), ('see', 'VBP'), ('the', 'DT'), ('classes', 'NNS'), ('in', 'IN'), ('this', 'DT'), ('scenario', 'NN'), ('(', '('), ('Figure', 'NNP'), ('2.2', 'CD'), (')', ')'), ('.', '.')]), Tree('S', [('We', 'PRP'), ('notice', 'VBP'), ('that', 'IN'), ('there', 'EX'), ('is', 'VBZ'), ('the', 'DT'), ('usual', 'JJ'), Tree('NE', [('Greenfoot', 'NNP'), ('Actor', 'NNP')]), ('class', 'NN'), (',', ','), ('a', 'DT'), ('class', 'NN'), ('called', 'VBN'), Tree('NE', [('Animal', 'NNP')]), (',', ','), ('and', 'CC'), ('the', 'DT'), Tree('NE', [('Crab', 'NNP')]), ('class', 'NN'), ('.', '.')]), Tree('S', [('The', 'DT'), ('hierarchy', 'NN'), ('(', '('), ('denoted', 'VBN'), ('by', 'IN'), ('the', 'DT'), ('arrows', 'NNS'), (')', ')'), ('indicates', 'VBZ'), ('an', 'DT'), ('is-a', 'JJ'), ('relationship', 'NN'), ('(', '('), ('also', 'RB'), ('called', 'VBN'), ('inheritance', 'NN'), (')', ')'), (':', ':'), ('A', 'DT'), ('crab', 'NN'), ('is', 'VBZ'), ('an', 'DT'), ('animal', 'NN'), (',', ','), ('and', 'CC'), ('an', 'DT'), ('animal', 'NN'), ('is', 'VBZ'), ('an', 'DT'), ('actor', 'NN'), ('.', '.')]), Tree('S', [('(', '('), ('It', 'PRP'), ('follows', 'VBZ'), ('then', 'RB'), (',', ','), ('that', 'IN'), ('a', 'DT'), ('crab', 'NN'), ('also', 'RB'), ('is', 'VBZ'), ('an', 'DT'), ('actor', 'NN'), ('.', '.'), (')', ')')]), Tree('S', [('Initially', 'RB'), (',', ','), ('we', 'PRP'), ('will', 'MD'), ('work', 'VB'), ('only', 'RB'), ('with', 'IN'), ('the', 'DT'), Tree('NE', [('Crab', 'NNP')]), ('class', 'NN'), ('.', '.')]), Tree('S', [('We', 'PRP'), ('will', 'MD'), ('talk', 'VB'), ('a', 'DT'), ('little', 'RB'), ('more', 'RBR'), ('about', 'IN'), ('the', 'DT'), ('Actor', 'NNP'), ('and', 'CC'), Tree('NE', [('Animal', 'NNP')]), ('classes', 'NNS'), ('later', 'RB'), ('on', 'IN'), ('.', '.')]), Tree('S', [('If', 'IN'), ('you', 'PRP'), ('have', 'VBP'), ('done', 'VBN'), ('the', 'DT'), ('exercise', 'NN'), ('above', 'IN'), (',', ','), ('then', 'RB'), ('you', 'PRP'), ('know', 'VBP'), ('the', 'DT'), ('answer', 'NN'), ('to', 'TO'), ('the', 'DT'), ('question', 'NN'), ('“What', 'WP'), ('do', 'VBP'), ('you', 'PRP'), ('observe', 'VB'), ('?', '.'), ('”', 'VB'), ('It', 'PRP'), ('is', 'VBZ'), (':', ':'), ('“nothing”', 'NN'), ('.', '.')]), Tree('S', [('2.1', 'CD'), ('The', 'DT'), Tree('NE', [('Little', 'JJ'), ('Crab', 'NNP')]), ('scenario', 'NN'), ('|', 'VBZ'), ('17', 'CD'), ('Figure', 'NN'), ('2.1', 'CD'), ('The', 'DT'), Tree('NE', [('Little', 'JJ'), ('Crab', 'N ...

# %%
is_noun = lambda pos: pos[:2] == 'NN'

nouns = [word for (word, pos) in nltk.pos_tag(nltk.word_tokenize(data)) if is_noun(pos)] 
nouns
# Out:
# ['program',
#  'topics',
#  'code',
#  'movement',
#  'screen',
#  'concepts',
#  'source',
#  'code',
#  'method',
#  'call',
#  'parameter',
#  'sequence',
#  'Exercise',
#  'Start',
#  'Greenfoot',
#  'scenario',
#  'crab',
#  'world',
#  'program',
#  'Run',
#  'button',
#  'Remember',
#  'class',
#  'icons',
#  'appear',
#  'project',
#  'right',
#  'classes',
#  'scenario',
#  'Figure',
#  'Greenfoot',
#  'Actor',
#  'class',
#  'class',
#  'Animal',
#  'Crab',
#  'class',
#  'hierarchy',
#  'arrows',
#  'relationship',
#  'inheritance',
#  'crab',
#  'animal',
#  'animal',
#  'actor',
#  'crab',
#  'actor',
#  'Crab',
#  'class',
#  'Actor',
#  'Animal',
#  'classes',
#  'exercise',
#  'answer',
#  'question',
#  '“nothing”',
#  'Crab',
#  'scenario',
#  'Figure',
#  'Crab',
#  'scenario',
#  'Figure',
#  'Little',
#  'Crab',
#  'actor',
#  'crab',
#  'anything',
#  'Greenfoot',
#  'source',
#  'code',
#  'definition',
#  'Crab',
#  'class',
#  'crab',
#  'chapter',
#  'thing',
#  'crab',
#  'move',
#  'crab',
#  'move',
#  'Let',
#  'look',
#  'source',
#  'code',
#  'class',
#  'Crab',
#  'editor',
#  'Crab',
#  'source',
#  'Open',
#  'editor',
#  'function',
#  'class’s',
#  'popup',
#  'menu',
#  'class',
#  'source',
#  'code',
#  'Code',
#  'Chapter',
#  'program',
#  'Crab',
#  'Code',
#  'version',
#  'Crab',
#  'class',
#  'import',
#  'greenfoot',
#  '*',
#  '//',
#  'World',
#  'Actor',
#  'GreenfootImage',
#  'Greenfoot',
#  'class',
#  'crab',
#  'Crabs',
#  'beach',
#  'class',
#  'Crab',
#  'Animal',
#  'void',
#  'act',
#  'Add',
#  'action',
#  'code',
#  'here.',
#  'Java',
#  'class',
#  'definition',
#  'text',
#  'crab',
#  'detail',
#  'crab',
#  'class',
#  'definition',
#  'act',
#  'method',
#  'void',
#  'act',
#  'Add',
#  'action',
#  'code',
#  'here.',
#  'line',
#  'signature',
#  'method',
#  'brackets',
#  'anything',
#  'them—is',
#  'body',
#  'method',
#  'code',
#  'actions',
#  'crab',
#  'text',
#  'middle',
#  'command',
#  'command',
#  'move',
#  'parentheses',
#  'semicolon',
#  'act',
#  'method',
#  'void',
#  'act',
#  'move',
#  'Exercise',
#  'Change',
#  'act',
#  'method',
#  'crab',
#  'class',
#  'move',
#  'instruction',
#  'scenario',
#  'Compile',
#  'All',
#  'button',
#  'place',
#  'crab',
#  'world',
#  'Act',
#  'Run',
#  'buttons',
#  'Exercise',
#  'Place',
#  'crabs',
#  'world',
#  'scenario',
#  'Concept',
#  'method',
#  'call',
#  'instruction',
#  'object',
#  'action',
#  'action',
#  'method',
#  'object',
#  'crab',
#  'screen',
#  'move',
#  'instruction',
#  'move',
#  'bit',
#  'right',
#  'Act',
#  'button',
#  'Greenfoot',
#  'window',
#  'act',
#  'method',
#  'instruction',
#  'act',
#  'method',
#  'Run',
#  'button',
#  'Act',
#  'times',
#  'act',
#  'method',
#  'Pause',
#  'Terminology',
#  'instruction',
#  'move',
#  'method',
#  'call',
#  'method',
#  'action',
#  'object',
#  'object',
#  'crab',
#  'method',
#  'call',
#  'instruction',
#  'crab',
#  'parentheses',
#  'part',
#  'method',
#  'call',
#  'Instructions',
#  'end',
#  'semicolon',
#  'Concept',
#  'information',
#  'methods',
#  'parentheses',
#  'value',
#  'parameter',
#  'instructions',
#  'crab',
#  'turn',
#  'instruction',
#  'turn',
#  'number',
#  'instruction',
#  'crab',
#  'parameter',
#  'numbers',
#  'example',
#  'turn',
#  'degree',
#  'value',
#  'degrees',
#  'value',
#  'degrees',
#  'way',
#  'degrees',
#  'move',
#  'instruction',
#  'turn',
#  'instruction',
#  'act',
#  'method',
#  'void',
#  'act',
#  'turn',
#  'Exercise',
#  'Replace',
#  'move',
#  'turn',
#  'scenario',
#  'values',
#  'Remember',
#  'time',
#  'source',
#  'code',
#  'Exercise',
#  'crab',
#  'turn',
#  'Concept',
#  'instructions',
#  'sequence',
#  'order',
#  'Chapter',
#  'program',
#  'Crab',
#  'Code',
#  'crab',
#  'move',
#  'turn',
#  'import',
#  'greenfoot',
#  '*',
#  '//',
#  'World',
#  'Actor',
#  'GreenfootImage',
#  'Greenfoot',
#  'class',
#  'crab',
#  'Crabs',
#  'beach',
#  'class',
#  'Crab',
#  'Animal',
#  'void',
#  'act',
#  'move',
#  'turn',
#  'thing',
#  'move',
#  'turn',
#  'act',
#  'method',
#  'instruction—we',
#  'instructions',
#  'row',
#  'Code',
#  'Crab',
#  'class',
#  'case',
#  'step',
#  'crab',
#  'actions',
#  'time',
#  'Exercise',
#  'Use',
#  'move',
#  'turn',
#  'N',
#  'instruction',
#  'crab’s',
#  'act',
#  'method',
#  'values',
#  'N.',
#  'Terminology',
#  'number',
#  'parentheses',
#  'turn',
#  'instruction—that',
#  'turn',
#  '—is',
#  'parameter',
#  'parameter',
#  'bit',
#  'information',
#  'methods',
#  'methods',
#  'move',
#  'parameters',
#  'move',
#  'instruction',
#  'methods',
#  'turn',
#  'information',
#  'case',
#  'information',
#  'form',
#  'parameter',
#  'value',
#  'parentheses',
#  'instance',
#  'turn',
#  'edges',
#  'Concept',
#  'class',
#  'compiler',
#  'checks',
#  'errors',
#  'error',
#  'error',
#  'message',
#  'note',
#  'Errors',
#  'source',
#  'code',
#  'character',
#  'counts',
#  'thing',
#  'program',
#  'programs',
#  'mistakes',
#  'example',
#  'semicolon',
#  'move',
#  'instruction',
#  'Exercise',
#  'Open',
#  'editor',
#  'crab’s',
#  'source',
#  'code',
#  'semicolon',
#  'move',
#  'compile',
#  'errors',
#  'move',
#  'changes',
#  'code',
#  'Make',
#  'exercise',
#  'Exercise',
#  'Make',
#  'changes',
#  'error',
#  'messages',
#  'Find',
#  'error',
#  'messages',
#  'Write',
#  'error',
#  'message',
#  'change',
#  'error',
#  'Tip',
#  'error',
#  'message',
#  'bottom',
#  'editor',
#  'window',
#  'question',
#  'mark',
#  'button',
#  'right',
#  'button',
#  'information',
#  'error',
#  'message',
#  'exercise',
#  'detail',
#  'Greenfoot',
#  'editor',
#  'line',
#  'message',
#  'bottom',
#  'editor',
#  'window',
#  'message',
#  'error',
#  'messages',
#  'accuracy',
#  'usefulness',
#  'problem',
#  'line',
#  'line',
#  'problem',
#  'line',
#  'problem',
#  'example',
#  '“',
#  'message',
#  'semicolon',
#  'fact',
#  'line',
#  'line',
#  'messages',
#  'time',
#  'message',
#  'code',
#  'everything',
#  'edges',
#  'move',
#  'turn',
#  'sections',
#  'edge',
#  'screen',
#  'Greenfoot',
#  'actors',
#  'world',
#  'edge',
#  'behavior',
#  'crab',
#  'world',
#  'edge',
#  'question',
#  'Chapter',
#  'program',
#  'Crab',
#  'Exercise',
#  'Open',
#  'editor',
#  'Animal',
#  'class',
#  'Documentation',
#  'view',
#  'list',
#  'methods',
#  'class',
#  '“Method',
#  'Summary”',
#  'methods',
#  'class',
#  'Above',
#  'move',
#  'turn',
#  'methods',
#  'method',
#  'goal',
#  'fact',
#  'move',
#  'turn',
#  'methods',
#  'Animal',
#  'class',
#  'crab',
#  'animal',
#  'arrow',
#  'Crab',
#  'Animal',
#  'class',
#  'diagram',
#  'animal',
#  'class',
#  'crab',
#  'inheritance',
#  'Crab',
#  'class',
#  'abilities',
#  'methods',
#  'Animal',
#  'class',
#  'question',
#  'animals',
#  'editor',
#  'Animal',
#  'class',
#  'editor',
#  'views',
#  'source',
#  'code',
#  'Crab',
#  'class',
#  'documentation',
#  'view',
#  'selection',
#  'menu',
#  'right',
#  'corner',
#  'editor',
#  'window',
#  'Animal',
#  'class',
#  'Documentation',
#  'view',
#  'Figure',
#  'Method',
#  'View',
#  'switch',
#  'Figure',
#  'Documentation',
#  'view',
#  'method',
#  'summary',
#  'Animal',
#  'class',
#  'Concept',
#  'subclass',
#  'methods',
#  'superclass',
#  'methods',
#  'superclass',
#  'defines',
#  'edges',
#  'method',
#  'summary',
#  'methods',
#  'Animal',
#  'class',
#  'methods',
#  'moment',
#  'atWorldEdge',
#  'edges',
#  'world',
#  'move',
#  'Move',
#  'direction',
#  'turn',
#  'angle',
#  'Turn',
#  '“angle”',
#  'right',
#  'clockwise',
#  'signatures',
#  'methods',
#  'Chapter',
#  'method',
#  'signature',
#  'return',
#  'type',
#  'method',
#  'name',
#  'parameter',
#  'list',
#  'comment',
#  'method',
#  'method',
#  'names',
#  'atWorldEdge',
#  'move',
#  'turn',
#  'move',
#  'turn',
#  'methods',
#  'ones',
#  'sections',
#  'parameter',
#  'lists',
#  'move',
#  'parameters',
#  'parentheses',
#  'parameter',
#  'type',
#  'int',
#  'number',
#  'angle',
#  'Section',
#  'parameter',
#  'lists',
#  'move',
#  'turn',
#  'methods',
#  'return',
#  'type',
#  'method',
#  'value',
#  'object',
#  'animal',
#  'command',
#  'answer',
#  'signature',
#  'atWorldEdge',
#  'atWorldEdge',
#  'method',
#  'parameters',
#  'nothing',
#  'parentheses',
#  'return',
#  'value',
#  'boolean',
#  'type',
#  'Section',
#  'type',
#  'values',
#  'methods',
#  'values',
#  'return',
#  'type',
#  'command',
#  'question',
#  'atWorldEdge',
#  'method',
#  'method',
#  'method',
#  'edge',
#  'world',
#  'Exercise',
#  'Create',
#  'crab',
#  'atWorldEdge',
#  'method',
#  'Animal',
#  'submenu',
#  'crab',
#  'method',
#  'Animal',
#  'class',
#  'method',
#  'Exercise',
#  'Let',
#  'crab',
#  'run',
#  'edge',
#  'screen',
#  'atWorldEdge',
#  'method',
#  'Concept',
#  'method',
#  'return',
#  'type',
#  'issues',
#  'command',
#  'method',
#  'return',
#  'type',
#  'question',
#  'Concept',
#  'instructions',
#  'condition',
#  'Chapter',
#  'program',
#  'Crab',
#  'Code',
#  'edge',
#  'world',
#  'import',
#  'greenfoot',
#  '*',
#  '//',
#  'World',
#  'Actor',
#  'GreenfootImage',
#  'Greenfoot',
#  'class',
#  'crab',
#  'Crabs',
#  'beach',
#  'class',
#  'Crab',
#  'Animal',
#  'void',
#  'act',
#  'atWorldEdge',
#  'turn',
#  'part',
#  'Java',
#  'language',
#  'commands',
#  'condition',
#  'example',
#  'edge',
#  'world',
#  'code',
#  'atWorldEdge',
#  'turn',
#  'form',
#  'if-statement',
#  'condition',
#  'instruction',
#  'instruction',
#  'place',
#  'condition',
#  'expression',
#  'atWorldEdge',
#  'call',
#  'instructions',
#  'condition',
#  'instructions',
#  'condition',
#  'instructions',
#  'execution',
#  'closing',
#  'bracket',
#  'Note',
#  'move',
#  'method',
#  'call',
#  'case',
#  'words',
#  'edge',
#  'world',
#  'edge',
#  'world',
#  'method',
#  'code',
#  'Code',
#  'Summary',
#  'techniques',
#  'Exercise',
#  'Try',
#  'Type',
#  'code',
#  'crabs',
#  'turn',
#  'edge',
#  'screen',
#  'Pay',
#  'attention',
#  'opening',
#  'closing',
#  'brackets—it',
#  'Exercise',
#  'Experiment',
#  'values',
#  'parameter',
#  'turn',
#  'method',
#  'one',
#  'Exercise',
#  'Place',
#  'move',
#  'statement',
#  'effect',
#  'behavior',
#  'Tip',
#  'Greenfoot',
#  'editor',
#  'cursor',
#  'opening',
#  'closing',
#  'bracket',
#  'Greenfoot',
#  'closing',
#  'bracket',
#  'brackets',
#  'Indentation',
#  'code',
#  'instance',
#  'Code',
#  'indentation',
#  'time',
#  'bracket',
#  'opens',
#  'lines',
#  'level',
#  'ones',
#  'bracket',
#  'closes',
#  'indentation',
#  'level',
#  'closing',
#  'bracket',
#  'opening',
#  'bracket',
#  'matching',
#  'bracket',
#  'spaces',
#  'level',
#  'indentation',
#  'Tab',
#  'key',
#  'spaces',
#  'editor',
#  'level',
#  'indentation',
#  'care',
#  'indentation',
#  'code',
#  'errors',
#  'brackets',
#  'indentation',
#  'errors',
#  'Summary',
#  'techniques',
#  'book',
#  'perspective',
#  'programming',
#  'techniques',
#  'scenarios',
#  'programming',
#  'techniques',
#  'end',
#  'chapter',
#  'discussion',
#  'order',
#  'chapter',
#  'methods',
#  'move',
#  'parameters',
#  'basis',
#  'Java',
#  'programming',
#  'body',
#  'act',
#  'method—this',
#  'instructions',
#  'error',
#  'messages',
#  'programming',
#  'endeavors',
#  'mistakes',
#  'error',
#  'messages',
#  'sign',
#  'programmer—it',
#  'part',
#  'glimpse',
#  'inheritance',
#  'Classes',
#  'methods',
#  'superclasses',
#  'Documentation',
#  'view',
#  'class',
#  'summary',
#  'methods',
#  'decisions',
#  'execution',
#  'hand',
#  'hand',
#  'appearance',
#  'type',
#  'boolean',
#  'value',
#  'Chapter',
#  'program',
#  'Crab',
#  'Concept',
#  'method',
#  'call',
#  'instruction',
#  'object',
#  'action',
#  'action',
#  'method',
#  'object',
#  'information',
#  'methods',
#  'parentheses',
#  'value',
#  'parameter',
#  'instructions',
#  'sequence',
#  'order',
#  'class',
#  'compiler',
#  'checks',
#  'errors',
#  'error',
#  'error',
#  'message',
#  'subclass',
#  'methods',
#  'superclass',
#  'methods',
#  'superclass',
#  'defines',
#  'method',
#  'return',
#  'type',
#  'issues',
#  'command',
#  'method',
#  'return',
#  'type',
#  'question',
#  'instructions',
#  'condition']

# %%
0.9*len(sentences)
# Out:
# 194.4

# %%
train = sentences[:int(0.9*len(sentences))]
test = sentences[int(0.9*len(sentences)):]

# %%
tagger = UnigramTagger(train)
tagger.evaluate(test)
# Out:
# 0.827893175074184

# %%
tagger = BigramTagger(train)
tagger.evaluate(test)
# Out:
# 0.22255192878338279

# %% [markdown]
# ###### Regex:
# r =  ved ikke
# ' = start på string
# . = any character, except for a new line
# * = match 0 or MORE repetitions
# \b = space around whole words
# in = part of sentence
# \b = space around whole words
# ( = part of sentence
# ? = match 0 or 1 repetitions.
# ! = donno prob part of sentence
# \b = space around whole words
# . = any character, except for a new line
# + = match 1 or more repetitions
# ing = part of sentence
# ) = part of sentence
# ' = end of string

# %%
IN = re.compile(r'.*\bin\b(?!\b.+ing)')
for rel in nltk.sem.extract_rels('DT', 'NN', sentences, pattern = IN):
    print(nltk.sem.rtuple(rel))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-95-db8909d3361d> in <module>()
#       1
#       2 IN = re.compile(r'.*\bin\b(?!\b.+ing)')
# ----> 3 for rel in nltk.sem.extract_rels('DT', 'NN', sentences, pattern = IN):
#       4     print(nltk.sem.rtuple(rel))
#
# C:\Users\Martin\Anaconda3\lib\site-packages\nltk\sem\relextract.py in extract_rels(subjclass, objclass, doc, corpus, pattern, window)
#     204             subjclass = _expand(subjclass)
#     205         else:
# --> 206             raise ValueError("your value for the subject type has not been recognized: %s" % subjclass)
#     207     if objclass and objclass not in NE_CLASSES[corpus]:
#     208         if _expand(objclass) in NE_CLASSES[corpus]:
#
# ValueError: your value for the subject type has not been recognized: DT

# %%
IN = re.compile(r'.*\bin\b(?!\b.+ing)')
for doc in nltk.corpus.ieer.parsed_docs('NYT_19980315'):
    for rel in nltk.sem.extract_rels('ORG', 'LOC', doc,
                                      corpus='ieer', pattern = IN):
        print(nltk.sem.rtuple(rel))
# Out:
# [ORG: 'WHYY'] 'in' [LOC: 'Philadelphia']
# [ORG: 'McGlashan &AMP; Sarrail'] 'firm in' [LOC: 'San Mateo']
# [ORG: 'Freedom Forum'] 'in' [LOC: 'Arlington']
# [ORG: 'Brookings Institution'] ', the research group in' [LOC: 'Washington']
# [ORG: 'Idealab'] ', a self-described business incubator based in' [LOC: 'Los Angeles']
# [ORG: 'Open Text'] ', based in' [LOC: 'Waterloo']
# [ORG: 'WGBH'] 'in' [LOC: 'Boston']
# [ORG: 'Bastille Opera'] 'in' [LOC: 'Paris']
# [ORG: 'Omnicom'] 'in' [LOC: 'New York']
# [ORG: 'DDB Needham'] 'in' [LOC: 'New York']
# [ORG: 'Kaplan Thaler Group'] 'in' [LOC: 'New York']
# [ORG: 'BBDO South'] 'in' [LOC: 'Atlanta']
# [ORG: 'Georgia-Pacific'] 'in' [LOC: 'Atlanta']

# %%
for doc in nltk.corpus.ieer.parsed_docs('NYT_19980315'):
    print(doc)
# Out:
# <IEERDocument NYT19980315.0063: 'PUBLIC RADIO HOSTS DROP IN AND MAYBE STAY TOO LONG'>
# <IEERDocument NYT19980315.0064: 'IN CYBERSPACE, IS THERE LAW WHERE THERE IS NO LAND?'>
# <IEERDocument NYT19980315.0067: 'THE SITES: TUNING INTO MUSIC ON THE WEB'>
# <IEERDocument NYT19980315.0069: 'ANALYSIS: TAXING INTERNET SALES _ GOVERNORS VS. TAX FREEDOM ACT'>
# <IEERDocument NYT19980315.0070: 'A SEARCH ENGINE THAT CHARGES FOR TOP BILLING'>
# <IEERDocument NYT19980315.0071: 'COMING SOON: TV DOCUMENTARIES TO A BOOKSTORE NEAR YOU'>
# <IEERDocument NYT19980315.0072: 'WEATHER'>
# <IEERDocument NYT19980315.0073: 'DICAPRIO , CHARISMATIC STAR, BALKS AT TEEN IDOL IMAGE'>
# <IEERDocument NYT19980315.0074: "You've read the book? Now see the television program. Inspired by ``Angela's...">
# <IEERDocument NYT19980315.0084: 'A DIRECTOR WHO DARES, AND TAKES THE HEAT'>
# <IEERDocument NYT19980315.0085: 'ADVERTISING: AFTER 32 YEARS , WELLS BDDP WILL CLOSE'>
# <IEERDocument NYT19980315.0086: "`THE GIFTS OF THE JEWS': DESERT NOMADS CHANGED THE WORLD WITH THE">
# <IEERDocument NYT19980315.0087: 'MUSICIANS ON BROADWAY TO VOTE ON A CONTRACT'>

# %%
# Out:
# [<IEERDocument NYT19980315.0063: 'PUBLIC RADIO HOSTS DROP IN AND MAYBE STAY TOO LONG'>, <IEERDocument NYT19980315.0064: 'IN CYBERSPACE, IS THERE LAW WHERE THERE IS NO LAND?'>, ...]
